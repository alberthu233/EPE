# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import pandas as pd
import sys
path = '/Work/EPE/ML4pi/'
sys.path.append(path)
import util.ml_util as mu
from util.ml_util import cell_meta

# %%
path_prefix = '/Work/EPE/ML4pi/'
plotpath = path_prefix+'plots/'
modelpath_c = path_prefix+''
modelpath = path_prefix+''
data_path = path_prefix + "v7/"

# %%
import sys
sys.path.append(path_prefix)

# %%
stmc_x = np.load(data_path + "X_img_pfn.npz")
stmc_y = np.load(data_path + "Y_img_pfn.npz")

# %%
xraw = stmc_x.f.arr_0
yraw = stmc_y.f.arr_0

# %%
X = xraw[:300000,:,:4]
Y = yraw[:300000]
print(X.shape)
print(Y.shape)
# Out:
# (300000, 636, 4)
# (300000,)

# %%
target_zero_mask = Y > .05
Ylog = np.log(Y[target_zero_mask])
print('Any targets below 50 GeV: '+str(np.count_nonzero(np.invert(target_zero_mask))))
print('Number of events: '+str(len(Y)))
# Out:
# Any targets below 50 GeV: 104
# Number of events: 300000

# %%
rPerp_mask = X[:,:,3] != 0
X[:,:,3][rPerp_mask] = X[:,:,3][rPerp_mask]/3630.

## Energy Values that are not zero!
E_nonZeroMask = X[:,:,0] != 0
X[:,:,0][E_nonZeroMask] = np.log(X[:,:,0][E_nonZeroMask])
cellE_mean = np.mean(X[:,:,0][E_nonZeroMask])
cellE_std = np.std(X[:,:,0][E_nonZeroMask])
X[:,:,0][E_nonZeroMask] = (X[:,:,0][E_nonZeroMask] - cellE_mean)/cellE_std

## Eta and Phi
# do nothing for now as a control and check performance
eta_mask = X[:,:,1] != 0
X[:,:,1][eta_mask] = X[:,:,1][eta_mask]/.7

phi_mask = X[:,:,2] != 0
X[:,:,2][phi_mask] = X[:,:,2][phi_mask]/.7

# %%
import energyflow as ef
from energyflow.archs import PFN

# %%
def tvt_num(_data, _tvt=(75, 10, 15)):
    ''' Function designed to output appropriate numbers for traning validation and testing given
    a variable length input. TVT expressed as ratios and do not need to add to 100. '''
    _tot = len(_data)
    _train, _val, _test = _tvt
    _tvt_sum = _train + _val + _test
    
    _train_rtrn = round(_train*_tot/_tvt_sum)
    _val_rtrn = round(_val*_tot/_tvt_sum)
    _test_rtrn = _tot - _train_rtrn - _val_rtrn
    
    return _train_rtrn, _val_rtrn, _test_rtrn

def normalize_input1d(arr, mask):
    ''' Note that non masked values are left alone i.e. zeros if mask = arr != 0'''
    len_arr = arr.shape[0]
    mean = np.repeat(np.mean(arr, where=mask), len_arr)
    std_dev = np.repeat(np.std(arr, where=mask), len_arr)
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev!=0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

def normalize_input2d(arr, mask):
    ''' Truth value is where to perform the operation, exclude False vals.
    returns: Array with the shape of arr with normalization carried out with mask '''
    len_ax1 = arr.shape[1]
    mean = np.tile(np.mean(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    std_dev = np.tile(np.std(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev != 0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

# %%
############
## ENERGY ##
############
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
ebins = np.linspace(-6,7, 50, endpoint=True)
plt.hist(X[:,:,0][E_nonZeroMask], color='plum', bins=ebins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Energy Inputs', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(np.min(ebins),np.max(ebins))
plt.ylim(0,.55)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_tracks_multipleClusters_med_Einputs_2020-07-01.png', format='png')
plt.show()

#########
## ETA ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
etabins = np.linspace(-1.1,1.1, 100, endpoint=True)
plt.hist(X[:,:,1][eta_mask], color='chocolate', bins=etabins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Eta Inputs', fontsize=16)
plt.xlabel('Eta', fontsize=14)
plt.xlim(np.min(etabins),np.max(etabins))
plt.ylim(0,4.5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_tracks_multipleClusters_med_EtaInputs_2021-07-08.png', format='png')
plt.show()

#########
## PHI ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
phibins = np.linspace(-np.pi/4,np.pi/4,100, endpoint=True)
plt.hist(X[:,:,2][phi_mask], color='olive', bins=phibins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Phi Inputs Flattened', fontsize=16)
plt.xlabel('Phi', fontsize=14)
plt.xlim(np.min(phibins),np.max(phibins))
plt.ylim(0,5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_tracks_multipleClusters_med_PhiInputs_2021-07-08.png', format='png')
plt.show()

###########
## RPERP ##
###########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
Rbins = np.linspace(-0,1.2,100, endpoint=True)
plt.hist(X[:,:,3][rPerp_mask], color='gold', bins=Rbins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell rPerp Inputs Flattened', fontsize=16)
plt.xlabel('rPerp', fontsize=14)
plt.xlim(np.min(Rbins),np.max(Rbins))
plt.ylim(0,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_tracks_multipleClusters_med_rPerpInputs_2021-07-08.png', format='png')
plt.show()

# %%
# EFN regression example uses 75/10/15 split for 100,000 samples
train, val, test = tvt_num(X[target_zero_mask], _tvt=(90, 10, 0))
print('train -- val -- test')
print(str(train)+' -- '+str(val)+' -- '+str(test))

# network architecture parameters
Phi_sizes, F_sizes = (100, 100, 128), (100, 100, 100)
output_act, output_dim = 'linear', 1
loss = 'mse'

# network training parameters
num_epoch = 1500
batch_size = 1000
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17440/3720911032.py in <module>
#       1 # EFN regression example uses 75/10/15 split for 100,000 samples
# ----> 2 train, val, test = tvt_num(X[target_zero_mask], _tvt=(90, 10, 0))
#       3 print('train -- val -- test')
#       4 print(str(train)+' -- '+str(val)+' -- '+str(test))
#       5
#
# MemoryError: Unable to allocate 5.68 GiB for an array with shape (299896, 636, 4) and data type float64

# %%
X[target_zero_mask].shape
# Out:
# (299896, 636, 4)

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, Y))
(x_train, x_val, x_test,
 y_train, y_val, y_test) = ef.utils.data_split(X[target_zero_mask], Ylog, val=val, test=test)

# Print out tensor shapes
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (269906, 636, 4)
# (269906,)

# %%
from tensorflow.keras import regularizers
from tensorflow.keras import Sequential
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf
from tensorflow.keras.models import load_model
import keras.backend as kb

# %%
kb.clear_session()
netOpt = tf.keras.optimizers.Adam(learning_rate=0.001)

pfn = PFN(input_dim=4, Phi_sizes=Phi_sizes, F_sizes=F_sizes, 
            output_act=output_act, output_dim=output_dim, loss=loss,
            optimizer=netOpt, metrics=[])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 4)]    0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 100)    500         input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, 100)    0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 100)    10100       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           tdist_1[0][0]
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            101         activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1)            0           output[0][0]
# ==================================================================================================
# Total params: 56,729
# Trainable params: 56,729
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('pfn_regressor_image_3.h5', monitor='val_loss', verbose=1, save_best_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=300, verbose=0, restore_best_weights=True)
history_ct = pfn.fit(x_train, y_train,
        epochs=num_epoch,
        batch_size=1000,
        validation_data=(x_val, y_val),
        verbose=0,
        callbacks=[chkpoint, earlystop])
# Out:
# Epoch 00001: val_loss improved from inf to 1.47920, saving model to pfn_regressor_image_3.h5
#
# Epoch 00002: val_loss improved from 1.47920 to 0.64120, saving model to pfn_regressor_image_3.h5
#
# Epoch 00003: val_loss did not improve from 0.64120
#
# Epoch 00004: val_loss improved from 0.64120 to 0.47292, saving model to pfn_regressor_image_3.h5
#
# Epoch 00005: val_loss did not improve from 0.47292
#
# Epoch 00006: val_loss did not improve from 0.47292
#
# Epoch 00007: val_loss improved from 0.47292 to 0.37348, saving model to pfn_regressor_image_3.h5
#
# Epoch 00008: val_loss did not improve from 0.37348
#
# Epoch 00009: val_loss did not improve from 0.37348
#
# Epoch 00010: val_loss improved from 0.37348 to 0.32502, saving model to pfn_regressor_image_3.h5
#
# Epoch 00011: val_loss did not improve from 0.32502
#
# Epoch 00012: val_loss did not improve from 0.32502
#
# Epoch 00013: val_loss did not improve from 0.32502
#
# Epoch 00014: val_loss improved from 0.32502 to 0.31286, saving model to pfn_regressor_image_3.h5
#
# Epoch 00015: val_loss did not improve from 0.31286
#
# Epoch 00016: val_loss did not improve from 0.31286
#
# Epoch 00017: val_loss did not improve from 0.31286
#
# Epoch 00018: val_loss improved from 0.31286 to 0.28973, saving model to pfn_regressor_image_3.h5
#
# Epoch 00019: val_loss did not improve from 0.28973
#
# Epoch 00020: val_loss did not improve from 0.28973
#
# Epoch 00021: val_loss did not improve from 0.28973
#
# Epoch 00022: val_loss did not improve from 0.28973
#
# Epoch 00023: val_loss did not improve from 0.28973
#
# Epoch 00024: val_loss improved from 0.28973 to 0.28092, saving model to pfn_regressor_image_3.h5
#
# Epoch 00025: val_loss did not improve from 0.28092
#
# Epoch 00026: val_loss did not improve from 0.28092
#
# Epoch 00027: val_loss improved from 0.28092 to 0.26742, saving model to pfn_regressor_image_3.h5
#
# Epoch 00028: val_loss did not improve from 0.26742
#
# Epoch 00029: val_loss improved from 0.26742 to 0.26733, saving model to pfn_regressor_image_3.h5
#
# Epoch 00030: val_loss did not improve from 0.26733
#
# Epoch 00031: val_loss did not improve from 0.26733
#
# Epoch 00032: val_loss did not improve from 0.26733
#
# Epoch 00033: val_loss improved from 0.26733 to 0.25408, saving model to pfn_regressor_image_3.h5
#
# Epoch 00034: val_loss did not improve from 0.25408
#
# Epoch 00035: val_loss did not improve from 0.25408
#
# Epoch 00036: val_loss improved from 0.25408 to 0.25350, saving model to pfn_regressor_image_3.h5
#
# Epoch 00037: val_loss improved from 0.25350 to 0.25290, saving model to pfn_regressor_image_3.h5
#
# Epoch 00038: val_loss did not improve from 0.25290
#
# Epoch 00039: val_loss did not improve from 0.25290
#
# Epoch 00040: val_loss did not improve from 0.25290
#
# Epoch 00041: val_loss did not improve from 0.25290
#
# Epoch 00042: val_loss did not improve from 0.25290
#
# Epoch 00043: val_loss did not improve from 0.25290
#
# Epoch 00044: val_loss did not improve from 0.25290
#
# Epoch 00045: val_loss improved from 0.25290 to 0.25135, saving model to pfn_regressor_image_3.h5
#
# Epoch 00046: val_loss improved from 0.25135 to 0.24990, saving model to pfn_regressor_image_3.h5
#
# Epoch 00047: val_loss improved from 0.24990 to 0.24423, saving model to pfn_regressor_image_3.h5
#
# Epoch 00048: val_loss did not improve from 0.24423
#
# Epoch 00049: val_loss did not improve from 0.24423
#
# Epoch 00050: val_loss did not improve from 0.24423
#
# Epoch 00051: val_loss did not improve from 0.24423
#
# Epoch 00052: val_loss improved from 0.24423 to 0.24411, saving model to pfn_regressor_image_3.h5
#
# Epoch 00053: val_loss did not improve from 0.24411
#
# Epoch 00054: val_loss did not improve from 0.24411
#
# Epoch 00055: val_loss did not improve from 0.24411
#
# Epoch 00056: val_loss did not improve from 0.24411
#
# Epoch 00057: val_loss improved from 0.24411 to 0.24241, saving model to pfn_regressor_image_3.h5
#
# Epoch 00058: val_loss did not improve from 0.24241
#
# Epoch 00059: val_loss improved from 0.24241 to 0.24056, saving model to pfn_regressor_image_3.h5
#
# Epoch 00060: val_loss improved from 0.24056 to 0.23938, saving model to pfn_regressor_image_3.h5
#
# Epoch 00061: val_loss improved from 0.23938 to 0.23763, saving model to pfn_regressor_image_3.h5
#
# Epoch 00062: val_loss did not improve from 0.23763
#
# Epoch 00063: val_loss did not improve from 0.23763
#
# Epoch 00064: val_loss did not improve from 0.23763
#
# Epoch 00065: val_loss did not improve from 0.23763
#
# Epoch 00066: val_loss did not improve from 0.23763
#
# Epoch 00067: val_loss did not improve from 0.23763
#
# Epoch 00068: val_loss did not improve from 0.23763
#
# Epoch 00069: val_loss did not improve from 0.23763
#
# Epoch 00070: val_loss did not improve from 0.23763
#
# Epoch 00071: val_loss did not improve from 0.23763
#
# Epoch 00072: val_loss did not improve from 0.23763
#
# Epoch 00073: val_loss did not improve from 0.23763
#
# Epoch 00074: val_loss did not improve from 0.23763
#
# Epoch 00075: val_loss did not improve from 0.23763
#
# Epoch 00076: val_loss improved from 0.23763 to 0.23671, saving model to pfn_regressor_image_3.h5
#
# Epoch 00077: val_loss improved from 0.23671 to 0.23509, saving model to pfn_regressor_image_3.h5
#
# Epoch 00078: val_loss did not improve from 0.23509
#
# Epoch 00079: val_loss did not improve from 0.23509
#
# Epoch 00080: val_loss did not improve from 0.23509
#
# Epoch 00081: val_loss did not improve from 0.23509
#
# Epoch 00082: val_loss did not improve from 0.23509
#
# Epoch 00083: val_loss did not improve from 0.23509
#
# Epoch 00084: val_loss did not improve from 0.23509
#
# Epoch 00085: val_loss improved from 0.23509 to 0.23138, saving model to pfn_regressor_image_3.h5
#
# Epoch 00086: val_loss improved from 0.23138 to 0.23112, saving model to pfn_regressor_image_3.h5
#
# Epoch 00087: val_loss did not improve from 0.23112
#
# Epoch 00088: val_loss did not improve from 0.23112
#
# Epoch 00089: val_loss did not improve from 0.23112
#
# Epoch 00090: val_loss did not improve from 0.23112
#
# Epoch 00091: val_loss did not improve from 0.23112
#
# Epoch 00092: val_loss improved from 0.23112 to 0.23002, saving model to pfn_regressor_image_3.h5
#
# Epoch 00093: val_loss did not improve from 0.23002
#
# Epoch 00094: val_loss did not improve from 0.23002
#
# Epoch 00095: val_loss did not improve from 0.23002
#
# Epoch 00096: val_loss did not improve from 0.23002
#
# Epoch 00097: val_loss did not improve from 0.23002
#
# Epoch 00098: val_loss did not improve from 0.23002
#
# Epoch 00099: val_loss did not improve from 0.23002
#
# Epoch 00100: val_loss did not improve from 0.23002
#
# Epoch 00101: val_loss improved from 0.23002 to 0.22853, saving model to pfn_regressor_image_3.h5
#
# Epoch 00102: val_loss did not improve from 0.22853
#
# Epoch 00103: val_loss did not improve from 0.22853
#
# Epoch 00104: val_loss did not improve from 0.22853
#
# Epoch 00105: val_loss improved from 0.22853 to 0.22630, saving model to pfn_regressor_image_3.h5
#
# Epoch 00106: val_loss did not improve from 0.22630
#
# Epoch 00107: val_loss did not improve from 0.22630
#
# Epoch 00108: val_loss did not improve from 0.22630
#
# Epoch 00109: val_loss did not improve from 0.22630
#
# Epoch 00110: val_loss did not improve from 0.22630
#
# Epoch 00111: val_loss improved from 0.22630 to 0.22440, saving model to pfn_regressor_image_3.h5
#
# Epoch 00112: val_loss did not improve from 0.22440
#
# Epoch 00113: val_loss did not improve from 0.22440
#
# Epoch 00114: val_loss did not improve from 0.22440
#
# Epoch 00115: val_loss did not improve from 0.22440
#
# Epoch 00116: val_loss did not improve from 0.22440
#
# Epoch 00117: val_loss improved from 0.22440 to 0.22247, saving model to pfn_regressor_image_3.h5
#
# Epoch 00118: val_loss did not improve from 0.22247
#
# Epoch 00119: val_loss did not improve from 0.22247
#
# Epoch 00120: val_loss did not improve from 0.22247
#
# Epoch 00121: val_loss did not improve from 0.22247
#
# Epoch 00122: val_loss did not improve from 0.22247
#
# Epoch 00123: val_loss did not improve from 0.22247
#
# Epoch 00124: val_loss did not improve from 0.22247
#
# Epoch 00125: val_loss did not improve from 0.22247
#
# Epoch 00126: val_loss did not improve from 0.22247
#
# Epoch 00127: val_loss did not improve from 0.22247
#
# Epoch 00128: val_loss did not improve from 0.22247
#
# Epoch 00129: val_loss did not improve from 0.22247
#
# Epoch 00130: val_loss improved from 0.22247 to 0.22236, saving model to pfn_regressor_image_3.h5
#
# Epoch 00131: val_loss did not improve from 0.22236
#
# Epoch 00132: val_loss did not improve from 0.22236
#
# Epoch 00133: val_loss did not improve from 0.22236
#
# Epoch 00134: val_loss improved from 0.22236 to 0.22128, saving model to pfn_regressor_image_3.h5
#
# Epoch 00135: val_loss did not improve from 0.22128
#
# Epoch 00136: val_loss did not improve from 0.22128
#
# Epoch 00137: val_loss did not improve from 0.22128
#
# Epoch 00138: val_loss did not improve from 0.22128
#
# Epoch 00139: val_loss did not improve from 0.22128
#
# Epoch 00140: val_loss did not improve from 0.22128
#
# Epoch 00141: val_loss did not improve from 0.22128
#
# Epoch 00142: val_loss did not improve from 0.22128
#
# Epoch 00143: val_loss did not improve from 0.22128
#
# Epoch 00144: val_loss did not improve from 0.22128
#
# Epoch 00145: val_loss did not improve from 0.22128
#
# Epoch 00146: val_loss did not improve from 0.22128
#
# Epoch 00147: val_loss did not improve from 0.22128
#
# Epoch 00148: val_loss did not improve from 0.22128
#
# Epoch 00149: val_loss improved from 0.22128 to 0.21849, saving model to pfn_regressor_image_3.h5
#
# Epoch 00150: val_loss did not improve from 0.21849
#
# Epoch 00151: val_loss did not improve from 0.21849
#
# Epoch 00152: val_loss did not improve from 0.21849
#
# Epoch 00153: val_loss did not improve from 0.21849
#
# Epoch 00154: val_loss did not improve from 0.21849
#
# Epoch 00155: val_loss did not improve from 0.21849
#
# Epoch 00156: val_loss did not improve from 0.21849
#
# Epoch 00157: val_loss did not improve from 0.21849
#
# Epoch 00158: val_loss did not improve from 0.21849
#
# Epoch 00159: val_loss did not improve from 0.21849
#
# Epoch 00160: val_loss did not improve from 0.21849
#
# Epoch 00161: val_loss did not improve from 0.21849
#
# Epoch 00162: val_loss did not improve from 0.21849
#
# Epoch 00163: val_loss did not improve from 0.21849
#
# Epoch 00164: val_loss did not improve from 0.21849
#
# Epoch 00165: val_loss did not improve from 0.21849
#
# Epoch 00166: val_loss did not improve from 0.21849
#
# Epoch 00167: val_loss improved from 0.21849 to 0.21797, saving model to pfn_regressor_image_3.h5
#
# Epoch 00168: val_loss did not improve from 0.21797
#
# Epoch 00169: val_loss did not improve from 0.21797
#
# Epoch 00170: val_loss did not improve from 0.21797
#
# Epoch 00171: val_loss did not improve from 0.21797
#
# Epoch 00172: val_loss did not improve from 0.21797
#
# Epoch 00173: val_loss did not improve from 0.21797
#
# Epoch 00174: val_loss did not improve from 0.21797
#
# Epoch 00175: val_loss did not improve from 0.21797
#
# Epoch 00176: val_loss did not improve from 0.21797
#
# Epoch 00177: val_loss did not improve from 0.21797
#
# Epoch 00178: val_loss did not improve from 0.21797
#
# Epoch 00179: val_loss did not improve from 0.21797
#
# Epoch 00180: val_loss improved from 0.21797 to 0.21703, saving model to pfn_regressor_image_3.h5
#
# Epoch 00181: val_loss did not improve from 0.21703
#
# Epoch 00182: val_loss did not improve from 0.21703
#
# Epoch 00183: val_loss did not improve from 0.21703
#
# Epoch 00184: val_loss did not improve from 0.21703
#
# Epoch 00185: val_loss did not improve from 0.21703
#
# Epoch 00186: val_loss did not improve from 0.21703
#
# Epoch 00187: val_loss did not improve from 0.21703
#
# Epoch 00188: val_loss did not improve from 0.21703
#
# Epoch 00189: val_loss did not improve from 0.21703
#
# Epoch 00190: val_loss did not improve from 0.21703
#
# Epoch 00191: val_loss did not improve from 0.21703
#
# Epoch 00192: val_loss did not improve from 0.21703
#
# Epoch 00193: val_loss did not improve from 0.21703
#
# Epoch 00194: val_loss did not improve from 0.21703
#
# Epoch 00195: val_loss improved from 0.21703 to 0.21637, saving model to pfn_regressor_image_3.h5
#
# Epoch 00196: val_loss did not improve from 0.21637
#
# Epoch 00197: val_loss did not improve from 0.21637
#
# Epoch 00198: val_loss did not improve from 0.21637
#
# Epoch 00199: val_loss did not improve from 0.21637
#
# Epoch 00200: val_loss did not improve from 0.21637
#
# Epoch 00201: val_loss did not improve from 0.21637
#
# Epoch 00202: val_loss did not improve from 0.21637
#
# Epoch 00203: val_loss did not improve from 0.21637
#
# Epoch 00204: val_loss did not improve from 0.21637
#
# Epoch 00205: val_loss did not improve from 0.21637
#
# Epoch 00206: val_loss did not improve from 0.21637
#
# Epoch 00207: val_loss did not improve from 0.21637
#
# Epoch 00208: val_loss did not improve from 0.21637
#
# Epoch 00209: val_loss did not improve from 0.21637
#
# Epoch 00210: val_loss did not improve from 0.21637
#
# Epoch 00211: val_loss did not improve from 0.21637
#
# Epoch 00212: val_loss improved from 0.21637 to 0.21498, saving model to pfn_regressor_image_3.h5
#
# Epoch 00213: val_loss did not improve from 0.21498
#
# Epoch 00214: val_loss did not improve from 0.21498
#
# Epoch 00215: val_loss did not improve from 0.21498
#
# Epoch 00216: val_loss did not improve from 0.21498
#
# Epoch 00217: val_loss did not improve from 0.21498
#
# Epoch 00218: val_loss did not improve from 0.21498
#
# Epoch 00219: val_loss did not improve from 0.21498
#
# Epoch 00220: val_loss did not improve from 0.21498
#
# Epoch 00221: val_loss did not improve from 0.21498
#
# Epoch 00222: val_loss did not improve from 0.21498
#
# Epoch 00223: val_loss did not improve from 0.21498
#
# Epoch 00224: val_loss did not improve from 0.21498
#
# Epoch 00225: val_loss did not improve from 0.21498
#
# Epoch 00226: val_loss did not improve from 0.21498
#
# Epoch 00227: val_loss did not improve from 0.21498
#
# Epoch 00228: val_loss did not improve from 0.21498
#
# Epoch 00229: val_loss did not improve from 0.21498
#
# Epoch 00230: val_loss did not improve from 0.21498
#
# Epoch 00231: val_loss did not improve from 0.21498
#
# Epoch 00232: val_loss did not improve from 0.21498
#
# Epoch 00233: val_loss did not improve from 0.21498
#
# Epoch 00234: val_loss did not improve from 0.21498
#
# Epoch 00235: val_loss did not improve from 0.21498
#
# Epoch 00236: val_loss did not improve from 0.21498
#
# Epoch 00237: val_loss did not improve from 0.21498
#
# Epoch 00238: val_loss did not improve from 0.21498
#
# Epoch 00239: val_loss did not improve from 0.21498
#
# Epoch 00240: val_loss did not improve from 0.21498
#
# Epoch 00241: val_loss did not improve from 0.21498
#
# Epoch 00242: val_loss did not improve from 0.21498
#
# Epoch 00243: val_loss did not improve from 0.21498
#
# Epoch 00244: val_loss did not improve from 0.21498
#
# Epoch 00245: val_loss did not improve from 0.21498
#
# Epoch 00246: val_loss did not improve from 0.21498
#
# Epoch 00247: val_loss did not improve from 0.21498
#
# Epoch 00248: val_loss did not improve from 0.21498
#
# Epoch 00249: val_loss did not improve from 0.21498
#
# Epoch 00250: val_loss did not improve from 0.21498
#
# Epoch 00251: val_loss did not improve from 0.21498
#
# Epoch 00252: val_loss did not improve from 0.21498
#
# Epoch 00253: val_loss did not improve from 0.21498
#
# Epoch 00254: val_loss did not improve from 0.21498
#
# Epoch 00255: val_loss did not improve from 0.21498
#
# Epoch 00256: val_loss did not improve from 0.21498
#
# Epoch 00257: val_loss did not improve from 0.21498
#
# Epoch 00258: val_loss did not improve from 0.21498
#
# Epoch 00259: val_loss did not improve from 0.21498
#
# Epoch 00260: val_loss did not improve from 0.21498
#
# Epoch 00261: val_loss did not improve from 0.21498
#
# Epoch 00262: val_loss did not improve from 0.21498
#
# Epoch 00263: val_loss did not improve from 0.21498
#
# Epoch 00264: val_loss did not improve from 0.21498
#
# Epoch 00265: val_loss did not improve from 0.21498
#
# Epoch 00266: val_loss did not improve from 0.21498
#
# Epoch 00267: val_loss did not improve from 0.21498
#
# Epoch 00268: val_loss did not improve from 0.21498
#
# Epoch 00269: val_loss did not improve from 0.21498
#
# Epoch 00270: val_loss did not improve from 0.21498
#
# Epoch 00271: val_loss did not improve from 0.21498
#
# Epoch 00272: val_loss did not improve from 0.21498
#
# Epoch 00273: val_loss did not improve from 0.21498
#
# Epoch 00274: val_loss did not improve from 0.21498
#
# Epoch 00275: val_loss did not improve from 0.21498
#
# Epoch 00276: val_loss did not improve from 0.21498
#
# Epoch 00277: val_loss did not improve from 0.21498
#
# Epoch 00278: val_loss did not improve from 0.21498
#
# Epoch 00279: val_loss did not improve from 0.21498
#
# Epoch 00280: val_loss did not improve from 0.21498
#
# Epoch 00281: val_loss did not improve from 0.21498
#
# Epoch 00282: val_loss did not improve from 0.21498
#
# Epoch 00283: val_loss did not improve from 0.21498
#
# Epoch 00284: val_loss did not improve from 0.21498
#
# Epoch 00285: val_loss did not improve from 0.21498
#
# Epoch 00286: val_loss did not improve from 0.21498
#
# Epoch 00287: val_loss did not improve from 0.21498
#
# Epoch 00288: val_loss did not improve from 0.21498
#
# Epoch 00289: val_loss did not improve from 0.21498
#
# Epoch 00290: val_loss did not improve from 0.21498
#
# Epoch 00291: val_loss did not improve from 0.21498
#
# Epoch 00292: val_loss did not improve from 0.21498
#
# Epoch 00293: val_loss did not improve from 0.21498
#
# Epoch 00294: val_loss did not improve from 0.21498
#
# Epoch 00295: val_loss did not improve from 0.21498
#
# Epoch 00296: val_loss did not improve from 0.21498
#
# Epoch 00297: val_loss did not improve from 0.21498
#
# Epoch 00298: val_loss did not improve from 0.21498
#
# Epoch 00299: val_loss did not improve from 0.21498
#
# Epoch 00300: val_loss did not improve from 0.21498
#
# Epoch 00301: val_loss did not improve from 0.21498
#
# Epoch 00302: val_loss did not improve from 0.21498
#
# Epoch 00303: val_loss did not improve from 0.21498
#
# Epoch 00304: val_loss did not improve from 0.21498
#
# Epoch 00305: val_loss did not improve from 0.21498
#
# Epoch 00306: val_loss did not improve from 0.21498
#
# Epoch 00307: val_loss did not improve from 0.21498
#
# Epoch 00308: val_loss did not improve from 0.21498
#
# Epoch 00309: val_loss did not improve from 0.21498
#
# Epoch 00310: val_loss did not improve from 0.21498
#
# Epoch 00311: val_loss did not improve from 0.21498
#
# Epoch 00312: val_loss did not improve from 0.21498
#
# Epoch 00313: val_loss did not improve from 0.21498
#
# Epoch 00314: val_loss did not improve from 0.21498
#
# Epoch 00315: val_loss did not improve from 0.21498
#
# Epoch 00316: val_loss did not improve from 0.21498
#
# Epoch 00317: val_loss did not improve from 0.21498
#
# Epoch 00318: val_loss did not improve from 0.21498
#
# Epoch 00319: val_loss did not improve from 0.21498
#
# Epoch 00320: val_loss did not improve from 0.21498
#
# Epoch 00321: val_loss did not improve from 0.21498
#
# Epoch 00322: val_loss did not improve from 0.21498
#
# Epoch 00323: val_loss did not improve from 0.21498
#
# Epoch 00324: val_loss did not improve from 0.21498
#
# Epoch 00325: val_loss did not improve from 0.21498
#
# Epoch 00326: val_loss did not improve from 0.21498
#
# Epoch 00327: val_loss did not improve from 0.21498
#
# Epoch 00328: val_loss did not improve from 0.21498
#
# Epoch 00329: val_loss did not improve from 0.21498
#
# Epoch 00330: val_loss did not improve from 0.21498
#
# Epoch 00331: val_loss did not improve from 0.21498
#
# Epoch 00332: val_loss did not improve from 0.21498
#
# Epoch 00333: val_loss did not improve from 0.21498
#
# Epoch 00334: val_loss did not improve from 0.21498
#
# Epoch 00335: val_loss did not improve from 0.21498
#
# Epoch 00336: val_loss did not improve from 0.21498
#
# Epoch 00337: val_loss did not improve from 0.21498
#
# Epoch 00338: val_loss did not improve from 0.21498
#
# Epoch 00339: val_loss did not improve from 0.21498
#
# Epoch 00340: val_loss did not improve from 0.21498
#
# Epoch 00341: val_loss did not improve from 0.21498
#
# Epoch 00342: val_loss did not improve from 0.21498
#
# Epoch 00343: val_loss did not improve from 0.21498
#
# Epoch 00344: val_loss did not improve from 0.21498
#
# Epoch 00345: val_loss did not improve from 0.21498
#
# Epoch 00346: val_loss did not improve from 0.21498
#
# Epoch 00347: val_loss did not improve from 0.21498
#
# Epoch 00348: val_loss did not improve from 0.21498
#
# Epoch 00349: val_loss did not improve from 0.21498
#
# Epoch 00350: val_loss did not improve from 0.21498
#
# Epoch 00351: val_loss did not improve from 0.21498
#
# Epoch 00352: val_loss did not improve from 0.21498
#
# Epoch 00353: val_loss did not improve from 0.21498
#
# Epoch 00354: val_loss did not improve from 0.21498
#
# Epoch 00355: val_loss did not improve from 0.21498
#
# Epoch 00356: val_loss did not improve from 0.21498
#
# Epoch 00357: val_loss did not improve from 0.21498
#
# Epoch 00358: val_loss did not improve from 0.21498
#
# Epoch 00359: val_loss did not improve from 0.21498
#
# Epoch 00360: val_loss did not improve from 0.21498
#
# Epoch 00361: val_loss did not improve from 0.21498
#
# Epoch 00362: val_loss did not improve from 0.21498
#
# Epoch 00363: val_loss did not improve from 0.21498
#
# Epoch 00364: val_loss did not improve from 0.21498
#
# Epoch 00365: val_loss did not improve from 0.21498
#
# Epoch 00366: val_loss did not improve from 0.21498
#
# Epoch 00367: val_loss did not improve from 0.21498
#
# Epoch 00368: val_loss did not improve from 0.21498
#
# Epoch 00369: val_loss did not improve from 0.21498
#
# Epoch 00370: val_loss did not improve from 0.21498
#
# Epoch 00371: val_loss did not improve from 0.21498
#
# Epoch 00372: val_loss did not improve from 0.21498
#
# Epoch 00373: val_loss did not improve from 0.21498
#
# Epoch 00374: val_loss did not improve from 0.21498
#
# Epoch 00375: val_loss did not improve from 0.21498
#
# Epoch 00376: val_loss did not improve from 0.21498
#
# Epoch 00377: val_loss did not improve from 0.21498
#
# Epoch 00378: val_loss did not improve from 0.21498
#
# Epoch 00379: val_loss did not improve from 0.21498
#
# Epoch 00380: val_loss did not improve from 0.21498
#
# Epoch 00381: val_loss did not improve from 0.21498
#
# Epoch 00382: val_loss did not improve from 0.21498
#
# Epoch 00383: val_loss did not improve from 0.21498
#
# Epoch 00384: val_loss did not improve from 0.21498
#
# Epoch 00385: val_loss did not improve from 0.21498
#
# Epoch 00386: val_loss did not improve from 0.21498
#
# Epoch 00387: val_loss did not improve from 0.21498
#
# Epoch 00388: val_loss did not improve from 0.21498
#
# Epoch 00389: val_loss did not improve from 0.21498
#
# Epoch 00390: val_loss did not improve from 0.21498
#
# Epoch 00391: val_loss did not improve from 0.21498
#
# Epoch 00392: val_loss did not improve from 0.21498
#
# Epoch 00393: val_loss did not improve from 0.21498
#
# Epoch 00394: val_loss did not improve from 0.21498
#
# Epoch 00395: val_loss did not improve from 0.21498
#
# Epoch 00396: val_loss did not improve from 0.21498
#
# Epoch 00397: val_loss did not improve from 0.21498
#
# Epoch 00398: val_loss did not improve from 0.21498
#
# Epoch 00399: val_loss did not improve from 0.21498
#
# Epoch 00400: val_loss did not improve from 0.21498
#
# Epoch 00401: val_loss did not improve from 0.21498
#
# Epoch 00402: val_loss did not improve from 0.21498
#
# Epoch 00403: val_loss did not improve from 0.21498
#
# Epoch 00404: val_loss did not improve from 0.21498
#
# Epoch 00405: val_loss did not improve from 0.21498
#
# Epoch 00406: val_loss did not improve from 0.21498
#
# Epoch 00407: val_loss did not improve from 0.21498
#
# Epoch 00408: val_loss did not improve from 0.21498
#
# Epoch 00409: val_loss did not improve from 0.21498
#
# Epoch 00410: val_loss did not improve from 0.21498
#
# Epoch 00411: val_loss did not improve from 0.21498
#
# Epoch 00412: val_loss did not improve from 0.21498
#
# Epoch 00413: val_loss did not improve from 0.21498
#
# Epoch 00414: val_loss did not improve from 0.21498
#
# Epoch 00415: val_loss did not improve from 0.21498
#
# Epoch 00416: val_loss did not improve from 0.21498
#
# Epoch 00417: val_loss did not improve from 0.21498
#
# Epoch 00418: val_loss did not improve from 0.21498
#
# Epoch 00419: val_loss did not improve from 0.21498
#
# Epoch 00420: val_loss did not improve from 0.21498
#
# Epoch 00421: val_loss did not improve from 0.21498
#
# Epoch 00422: val_loss did not improve from 0.21498
#
# Epoch 00423: val_loss did not improve from 0.21498
#
# Epoch 00424: val_loss did not improve from 0.21498
#
# Epoch 00425: val_loss did not improve from 0.21498
#
# Epoch 00426: val_loss did not improve from 0.21498
#
# Epoch 00427: val_loss did not improve from 0.21498
#
# Epoch 00428: val_loss did not improve from 0.21498
#
# Epoch 00429: val_loss did not improve from 0.21498
#
# Epoch 00430: val_loss did not improve from 0.21498
#
# Epoch 00431: val_loss did not improve from 0.21498
#
# Epoch 00432: val_loss did not improve from 0.21498
#
# Epoch 00433: val_loss did not improve from 0.21498
#
# Epoch 00434: val_loss did not improve from 0.21498
#
# Epoch 00435: val_loss did not improve from 0.21498
#
# Epoch 00436: val_loss did not improve from 0.21498
#
# Epoch 00437: val_loss did not improve from 0.21498
#
# Epoch 00438: val_loss did not improve from 0.21498
#
# Epoch 00439: val_loss did not improve from 0.21498
#
# Epoch 00440: val_loss did not improve from 0.21498
#
# Epoch 00441: val_loss did not improve from 0.21498
#
# Epoch 00442: val_loss did not improve from 0.21498
#
# Epoch 00443: val_loss did not improve from 0.21498
#
# Epoch 00444: val_loss did not improve from 0.21498
#
# Epoch 00445: val_loss did not improve from 0.21498
#
# Epoch 00446: val_loss did not improve from 0.21498
#
# Epoch 00447: val_loss did not improve from 0.21498
#
# Epoch 00448: val_loss did not improve from 0.21498
#
# Epoch 00449: val_loss did not improve from 0.21498
#
# Epoch 00450: val_loss did not improve from 0.21498
#
# Epoch 00451: val_loss did not improve from 0.21498
#
# Epoch 00452: val_loss did not improve from 0.21498
#
# Epoch 00453: val_loss did not improve from 0.21498
#
# Epoch 00454: val_loss did not improve from 0.21498
#
# Epoch 00455: val_loss did not improve from 0.21498
#
# Epoch 00456: val_loss did not improve from 0.21498
#
# Epoch 00457: val_loss did not improve from 0.21498
#
# Epoch 00458: val_loss did not improve from 0.21498
#
# Epoch 00459: val_loss did not improve from 0.21498
#
# Epoch 00460: val_loss did not improve from 0.21498
#
# Epoch 00461: val_loss did not improve from 0.21498
#
# Epoch 00462: val_loss did not improve from 0.21498
#
# Epoch 00463: val_loss did not improve from 0.21498
#
# Epoch 00464: val_loss did not improve from 0.21498
#
# Epoch 00465: val_loss did not improve from 0.21498
#
# Epoch 00466: val_loss did not improve from 0.21498
#
# Epoch 00467: val_loss did not improve from 0.21498
#
# Epoch 00468: val_loss did not improve from 0.21498
#
# Epoch 00469: val_loss did not improve from 0.21498
#
# Epoch 00470: val_loss did not improve from 0.21498
#
# Epoch 00471: val_loss did not improve from 0.21498
#
# Epoch 00472: val_loss did not improve from 0.21498
#
# Epoch 00473: val_loss did not improve from 0.21498
#
# Epoch 00474: val_loss did not improve from 0.21498
#
# Epoch 00475: val_loss did not improve from 0.21498
#
# Epoch 00476: val_loss did not improve from 0.21498
#
# Epoch 00477: val_loss did not improve from 0.21498
#
# Epoch 00478: val_loss did not improve from 0.21498
#
# Epoch 00479: val_loss did not improve from 0.21498
#
# Epoch 00480: val_loss did not improve from 0.21498
#
# Epoch 00481: val_loss did not improve from 0.21498
#
# Epoch 00482: val_loss did not improve from 0.21498
#
# Epoch 00483: val_loss did not improve from 0.21498
#
# Epoch 00484: val_loss did not improve from 0.21498
#
# Epoch 00485: val_loss did not improve from 0.21498
#
# Epoch 00486: val_loss did not improve from 0.21498
#
# Epoch 00487: val_loss did not improve from 0.21498
#
# Epoch 00488: val_loss did not improve from 0.21498
#
# Epoch 00489: val_loss did not improve from 0.21498
#
# Epoch 00490: val_loss did not improve from 0.21498
#
# Epoch 00491: val_loss did not improve from 0.21498
#
# Epoch 00492: val_loss did not improve from 0.21498
#
# Epoch 00493: val_loss did not improve from 0.21498
#
# Epoch 00494: val_loss did not improve from 0.21498
#
# Epoch 00495: val_loss did not improve from 0.21498
#
# Epoch 00496: val_loss did not improve from 0.21498
#
# Epoch 00497: val_loss did not improve from 0.21498
#
# Epoch 00498: val_loss did not improve from 0.21498
#
# Epoch 00499: val_loss did not improve from 0.21498
#
# Epoch 00500: val_loss did not improve from 0.21498
#
# Epoch 00501: val_loss did not improve from 0.21498
#
# Epoch 00502: val_loss did not improve from 0.21498
#
# Epoch 00503: val_loss did not improve from 0.21498
#
# Epoch 00504: val_loss did not improve from 0.21498
#
# Epoch 00505: val_loss did not improve from 0.21498
#
# Epoch 00506: val_loss did not improve from 0.21498
#
# Epoch 00507: val_loss did not improve from 0.21498
#
# Epoch 00508: val_loss did not improve from 0.21498
#
# Epoch 00509: val_loss did not improve from 0.21498
#
# Epoch 00510: val_loss did not improve from 0.21498
#
# Epoch 00511: val_loss did not improve from 0.21498
#
# Epoch 00512: val_loss did not improve from 0.21498
