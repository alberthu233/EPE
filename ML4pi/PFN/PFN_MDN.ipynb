# %% [markdown]
# # Keras PFN and PFN with mdn layer

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib.colors import LogNorm
import time as t
from time import perf_counter as cput
import scipy.constants as spc
import matplotlib.ticker as ticker

# %%
path_prefix = 'D:/Work/EPE/ML4pi/'
plotpath = path_prefix+'plots/'
modelpath_c = path_prefix+''
modelpath = path_prefix+''
ext_path = "H:/EPE_file_storage/"
ext_modelpath = ext_path + "Model/"
ext_datapath = ext_path + "data_storage/STMC/"
ext_plotpath = ext_path + "plots/"

# %%
def tvt_num(_data, _tvt=(75, 10, 15)):
    ''' Function designed to output appropriate numbers for traning validation and testing given
    a variable length input. TVT expressed as ratios and do not need to add to 100. '''
    _tot = len(_data)
    _train, _val, _test = _tvt
    _tvt_sum = _train + _val + _test
    
    _train_rtrn = round(_train*_tot/_tvt_sum)
    _val_rtrn = round(_val*_tot/_tvt_sum)
    _test_rtrn = _tot - _train_rtrn - _val_rtrn
    
    return _train_rtrn, _val_rtrn, _test_rtrn

def normalize_input1d(arr, mask):
    ''' Note that non masked values are left alone i.e. zeros if mask = arr != 0'''
    len_arr = arr.shape[0]
    mean = np.repeat(np.mean(arr, where=mask), len_arr)
    std_dev = np.repeat(np.std(arr, where=mask), len_arr)
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev!=0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

def normalize_input2d(arr, mask):
    ''' Truth value is where to perform the operation, exclude False vals.
    returns: Array with the shape of arr with normalization carried out with mask '''
    len_ax1 = arr.shape[1]
    mean = np.tile(np.mean(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    std_dev = np.tile(np.std(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev != 0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

# %%
import sys
sys.path.append(path_prefix)
from util import resolution_util as ru
from util import plot_util as pu
from util import ml_util as mu
import uproot3 as ur
import os
import shutil

# %%
# load multiple into list of file names
train_filenames = []
test_filenames = []
# set number of files read
# maximum i = 38
i = 10 
for subdir, dirs, files in os.walk(ext_datapath): 
    files.sort()
    for file in files[:i]: 
        train_filenames.append(ext_datapath + file)
    for file in files[i:i+2]:
        test_filenames.append(ext_datapath + file)

# %%
print(train_filenames)
print(test_filenames)

# %%
# write custom generator for large dataset training input
import keras

class Custom_Generator(keras.utils.Sequence) :
 
    def __init__(self, filenames, targets, batch_size) :
        self.filenames = filenames
        self.targets = labels
        self.batch_size = batch_size
 
 
    def __len__(self) :
        return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
 
 
    def __getitem__(self, idx) :
        batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
    
    def on_epoch_end(self):
        
        self.indexes = np.arange(len(self.X_data))
        
        if self.shuffle: 
            np.random.shuffle(self.indexes)

# %%
stmc1 = np.load(ext_datapath + "STMC_1.npz")
stmc2 = np.load(ext_datapath + "STMC_2.npz")
stmc3 = np.load(ext_datapath + "STMC_3.npz")

# %%
Xraw1 = stmc1.f.x
Yraw1 = stmc1.f.y
Xraw2 = stmc2.f.x
Yraw2 = stmc2.f.y
Xraw3 = stmc3.f.x
Yraw3 = stmc3.f.y
Xraw = np.concatenate((Xraw1,Xraw2,Xraw3),axis=0)
Yraw = np.concatenate((Yraw1,Yraw2,Yraw3),axis=0)

# %%
X = np.lib.format.open_memmap(ext_datapath + "stmc_X_3f_2.npy",
                             mode='w+', dtype=np.float64, shape=(Xraw.shape[0], Xraw.shape[1], 5))
np.copyto(dst=X, src=Xraw[:,:,:5], casting='same_kind', where=True)

Y = np.lib.format.open_memmap(ext_datapath + "stmc_Y_3f_2.npy",
                             mode='w+', dtype=np.float64, shape=(Yraw.shape[0]))
np.copyto(dst=Y, src=Yraw[:,0], casting='same_kind', where=True)

print(X.shape)
print(Y.shape)
# Out:
# (123588, 1086, 5)
# (123588,)

# %%
# for PFN approach Y normalization
# the target energy values
# target_zero_mask, Y : 0 for truthPartE, 1 for truthTrackPt, 2 for cluster_eng_clib_tot
target_zero_mask = Y > .05
Ylog = np.log(Y[target_zero_mask])
print('Any targets below 50 GeV: '+str(np.count_nonzero(np.invert(target_zero_mask))))
print('Number of events: '+str(len(Y)))
# Out:
# Any targets below 50 GeV: 0
# Number of events: 123588

# %%
t0 = t.time()
## Normalize rPerp to 1/3630
rPerp_mask = X[:,:,3] != 0
X[:,:,3][rPerp_mask] = X[:,:,3][rPerp_mask]/3630.

isnan = np.isnan(X[:,:,0])
anytruth = np.any(isnan)
print(anytruth)

## Energy Values that are not zero!
E_nonZeroMask = X[:,:,0] != 0
X[:,:,0][E_nonZeroMask] = np.log(X[:,:,0][E_nonZeroMask])
cellE_mean = np.mean(X[:,:,0][E_nonZeroMask])
cellE_std = np.std(X[:,:,0][E_nonZeroMask])
X[:,:,0][E_nonZeroMask] = (X[:,:,0][E_nonZeroMask] - cellE_mean)/cellE_std

## Eta and Phi
# do nothing for now as a control and check performance
eta_mask = X[:,:,1] != 0
X[:,:,1][eta_mask] = X[:,:,1][eta_mask]/.7

phi_mask = X[:,:,2] != 0
cellPhi_std = np.std(X[:,:,2][phi_mask])
X[:,:,2][phi_mask] = X[:,:,2][phi_mask]/cellPhi_std
t1 = t.time()
print('Time to Normalize: '+str(t1-t0)+' (s)')
# Out:
# False
# Time to Normalize: 5.186001539230347 (s)

# %%
############
## ENERGY ##
############
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
ebins = np.linspace(-6,7, 50, endpoint=True)
plt.hist(X[:,:,0][E_nonZeroMask], color='plum', bins=ebins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Energy Inputs', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(np.min(ebins),np.max(ebins))
plt.ylim(0,.55)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_E_2021-07-26.png', format='png')
plt.show()

#########
## ETA ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
etabins = np.linspace(-1.1,1.1,50, endpoint=True)
plt.hist(X[:,:,1][eta_mask], color='chocolate', bins=etabins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Eta Inputs', fontsize=16)
plt.xlabel('Eta', fontsize=14)
plt.xlim(np.min(etabins),np.max(etabins))
plt.ylim(0,4.5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_Eta_2021-07-26.png', format='png')
plt.show()

#########
## PHI ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
phibins = np.linspace(-np.pi/4,np.pi/4,50, endpoint=True)
plt.hist(X[:,:,2][phi_mask], color='olive', bins=phibins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Phi Inputs Flattened', fontsize=16)
plt.xlabel('Phi', fontsize=14)
plt.xlim(np.min(phibins),np.max(phibins))
plt.ylim(0,5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_Phi_2021-07-26.png', format='png')
plt.show()

###########
## RPERP ##
###########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
Rbins = np.linspace(-0,1.2,50, endpoint=True)
plt.hist(X[:,:,3][rPerp_mask], color='gold', bins=Rbins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell rPerp Inputs Flattened', fontsize=16)
plt.xlabel('rPerp', fontsize=14)
plt.xlim(np.min(Rbins),np.max(Rbins))
plt.ylim(0,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_rPerp_2021-07-26.png', format='png')
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import Sequential
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.models import load_model
import keras.backend as Kb

# %%
import energyflow as ef
from energyflow.archs import PFN

# %% [markdown]
# # Models

# %%
# EFN regression example uses 75/10/15 split for 100,000 samples
train, val, test = tvt_num(X, _tvt=(75, 10, 15))
print('train -- val -- test')
print(str(train)+' -- '+str(val)+' -- '+str(test))

# network architecture parameters
Phi_sizes, F_sizes = (100, 100, 128), (100, 100, 100)
output_act, output_dim = 'linear', 1
loss = 'mse'

# network training parameters
num_epoch = 1500
batch_size = 1000

netOpt = tf.keras.optimizers.Adam(learning_rate=0.001)
RMS_prop = tf.keras.optimizers.RMSprop(learning_rate=0.001)
# Out:
# train -- val -- test
# 92691 -- 12359 -- 18538

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, Y))
(x_train, x_val, x_test,
 y_train, y_val, y_test) = ef.utils.data_split(X, Ylog, val=val, test=test)

# Print out tensor shapes
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (92691, 1086, 5)
# (92691,)

# %%
# luanch wandb init()
Kb.clear_session()

pfn = PFN(input_dim=5, Phi_sizes=Phi_sizes, F_sizes=F_sizes, 
          output_act=output_act, output_dim=output_dim, loss=loss,
          optimizer=netOpt, metrics=[])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 5)]    0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 100)    600         input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, 100)    0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 100)    10100       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           tdist_1[0][0]
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            101         activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1)            0           output[0][0]
# ==================================================================================================
# Total params: 56,829
# Trainable params: 56,829
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('pfn_regressor_3f.h5', monitor='val_loss', verbose=1, save_best_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=150, verbose=0, restore_best_weights=True)
t0 = t.time()
history_ct = pfn.fit(x_train, y_train,
        epochs=1000,
        batch_size=800,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=[chkpoint, earlystop])
t1 = t.time()
# Out:
# Epoch 1/1000
# 116/116 [==============================] - 10s 59ms/step - loss: 156.7703 - val_loss: 3.9594
#
# Epoch 00001: val_loss improved from inf to 3.95937, saving model to pfn_regressor_3f.h5
# Epoch 2/1000
# 116/116 [==============================] - 6s 54ms/step - loss: 3.1467 - val_loss: 1.8939
#
# Epoch 00002: val_loss improved from 3.95937 to 1.89389, saving model to pfn_regressor_3f.h5
# Epoch 3/1000
# 116/116 [==============================] - 6s 54ms/step - loss: 1.7560 - val_loss: 1.2894
#
# Epoch 00003: val_loss improved from 1.89389 to 1.28944, saving model to pfn_regressor_3f.h5
# Epoch 4/1000
# 116/116 [==============================] - 6s 55ms/step - loss: 1.4308 - val_loss: 1.0630
#
# Epoch 00004: val_loss improved from 1.28944 to 1.06298, saving model to pfn_regressor_3f.h5
# Epoch 5/1000
# 116/116 [==============================] - 6s 54ms/step - loss: 1.5124 - val_loss: 0.8811
#
# Epoch 00005: val_loss improved from 1.06298 to 0.88111, saving model to pfn_regressor_3f.h5
# Epoch 6/1000
# 116/116 [==============================] - 6s 55ms/step - loss: 0.8699 - val_loss: 0.6386
#
# Epoch 00006: val_loss improved from 0.88111 to 0.63857, saving model to pfn_regressor_3f.h5
# Epoch 7/1000
# 116/116 [==============================] - 7s 58ms/step - loss: 0.8365 - val_loss: 1.6355
#
# Epoch 00007: val_loss did not improve from 0.63857
# Epoch 8/1000
# 116/116 [==============================] - 7s 58ms/step - loss: 1.3599 - val_loss: 0.7673
#
# Epoch 00008: val_loss did not improve from 0.63857
# Epoch 9/1000
# 116/116 [==============================] - 7s 58ms/step - loss: 1.2643 - val_loss: 0.4687
#
# Epoch 00009: val_loss improved from 0.63857 to 0.46872, saving model to pfn_regressor_3f.h5
# Epoch 10/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.7075 - val_loss: 0.3750
#
# Epoch 00010: val_loss improved from 0.46872 to 0.37496, saving model to pfn_regressor_3f.h5
# Epoch 11/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.6310 - val_loss: 0.4907
#
# Epoch 00011: val_loss did not improve from 0.37496
# Epoch 12/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 1.0161 - val_loss: 1.5718
#
# Epoch 00012: val_loss did not improve from 0.37496
# Epoch 13/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.8500 - val_loss: 1.5596
#
# Epoch 00013: val_loss did not improve from 0.37496
# Epoch 14/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.5324 - val_loss: 0.4481
#
# Epoch 00014: val_loss did not improve from 0.37496
# Epoch 15/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.5639 - val_loss: 0.6610
#
# Epoch 00015: val_loss did not improve from 0.37496
# Epoch 16/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 1.7802 - val_loss: 0.5721
#
# Epoch 00016: val_loss did not improve from 0.37496
# Epoch 17/1000
# 116/116 [==============================] - 7s 58ms/step - loss: 0.5836 - val_loss: 0.5898
#
# Epoch 00017: val_loss did not improve from 0.37496
# Epoch 18/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.5004 - val_loss: 0.3030
#
# Epoch 00018: val_loss improved from 0.37496 to 0.30297, saving model to pfn_regressor_3f.h5
# Epoch 19/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.3854 - val_loss: 0.2581
#
# Epoch 00019: val_loss improved from 0.30297 to 0.25805, saving model to pfn_regressor_3f.h5
# Epoch 20/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 2.1857 - val_loss: 3.5860
#
# Epoch 00020: val_loss did not improve from 0.25805
# Epoch 21/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.7177 - val_loss: 0.3365
#
# Epoch 00021: val_loss did not improve from 0.25805
# Epoch 22/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.2658 - val_loss: 0.5196
#
# Epoch 00022: val_loss did not improve from 0.25805
# Epoch 23/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.3116 - val_loss: 0.2378
#
# Epoch 00023: val_loss improved from 0.25805 to 0.23782, saving model to pfn_regressor_3f.h5
# Epoch 24/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.2942 - val_loss: 0.2042
#
# Epoch 00024: val_loss improved from 0.23782 to 0.20421, saving model to pfn_regressor_3f.h5
# Epoch 25/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.2640 - val_loss: 0.1896
#
# Epoch 00025: val_loss improved from 0.20421 to 0.18960, saving model to pfn_regressor_3f.h5
# Epoch 26/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2943 - val_loss: 0.2457
#
# Epoch 00026: val_loss did not improve from 0.18960
# Epoch 27/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.3294 - val_loss: 0.6960
#
# Epoch 00027: val_loss did not improve from 0.18960
# Epoch 28/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.4797 - val_loss: 0.2119
#
# Epoch 00028: val_loss did not improve from 0.18960
# Epoch 29/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.6630 - val_loss: 0.4486
#
# Epoch 00029: val_loss did not improve from 0.18960
# Epoch 30/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.5060 - val_loss: 0.1961
#
# Epoch 00030: val_loss did not improve from 0.18960
# Epoch 31/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2542 - val_loss: 0.1643
#
# Epoch 00031: val_loss improved from 0.18960 to 0.16433, saving model to pfn_regressor_3f.h5
# Epoch 32/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2119 - val_loss: 0.1492
#
# Epoch 00032: val_loss improved from 0.16433 to 0.14917, saving model to pfn_regressor_3f.h5
# Epoch 33/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2314 - val_loss: 0.1142
#
# Epoch 00033: val_loss improved from 0.14917 to 0.11423, saving model to pfn_regressor_3f.h5
# Epoch 34/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1858 - val_loss: 0.1509
#
# Epoch 00034: val_loss did not improve from 0.11423
# Epoch 35/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2071 - val_loss: 0.4911
#
# Epoch 00035: val_loss did not improve from 0.11423
# Epoch 36/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.4280 - val_loss: 0.1927
#
# Epoch 00036: val_loss did not improve from 0.11423
# Epoch 37/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1447 - val_loss: 0.1420
#
# Epoch 00037: val_loss did not improve from 0.11423
# Epoch 38/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1285 - val_loss: 0.2040
#
# Epoch 00038: val_loss did not improve from 0.11423
# Epoch 39/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.3034 - val_loss: 0.1812
#
# Epoch 00039: val_loss did not improve from 0.11423
# Epoch 40/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.5440 - val_loss: 0.2030
#
# Epoch 00040: val_loss did not improve from 0.11423
# Epoch 41/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1270 - val_loss: 0.1838
#
# Epoch 00041: val_loss did not improve from 0.11423
# Epoch 42/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1122 - val_loss: 0.0902
#
# Epoch 00042: val_loss improved from 0.11423 to 0.09020, saving model to pfn_regressor_3f.h5
# Epoch 43/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1011 - val_loss: 0.0852
#
# Epoch 00043: val_loss improved from 0.09020 to 0.08519, saving model to pfn_regressor_3f.h5
# Epoch 44/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1149 - val_loss: 0.0802
#
# Epoch 00044: val_loss improved from 0.08519 to 0.08018, saving model to pfn_regressor_3f.h5
# Epoch 45/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1691 - val_loss: 0.0920
#
# Epoch 00045: val_loss did not improve from 0.08018
# Epoch 46/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0923 - val_loss: 0.0779
#
# Epoch 00046: val_loss improved from 0.08018 to 0.07786, saving model to pfn_regressor_3f.h5
# Epoch 47/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.2299 - val_loss: 0.1363
#
# Epoch 00047: val_loss did not improve from 0.07786
# Epoch 48/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.1972 - val_loss: 0.2284
#
# Epoch 00048: val_loss did not improve from 0.07786
# Epoch 49/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.2532 - val_loss: 0.0764
#
# Epoch 00049: val_loss improved from 0.07786 to 0.07642, saving model to pfn_regressor_3f.h5
# Epoch 50/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0675 - val_loss: 0.0545
#
# Epoch 00050: val_loss improved from 0.07642 to 0.05450, saving model to pfn_regressor_3f.h5
# Epoch 51/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0600 - val_loss: 0.0557
#
# Epoch 00051: val_loss did not improve from 0.05450
# Epoch 52/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0907 - val_loss: 0.0513
#
# Epoch 00052: val_loss improved from 0.05450 to 0.05126, saving model to pfn_regressor_3f.h5
# Epoch 53/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1305 - val_loss: 0.1391
#
# Epoch 00053: val_loss did not improve from 0.05126
# Epoch 54/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1005 - val_loss: 0.1258
#
# Epoch 00054: val_loss did not improve from 0.05126
# Epoch 55/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.1112 - val_loss: 0.0698
#
# Epoch 00055: val_loss did not improve from 0.05126
# Epoch 56/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0567 - val_loss: 0.0950
#
# Epoch 00056: val_loss did not improve from 0.05126
# Epoch 57/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1070 - val_loss: 0.0663
#
# Epoch 00057: val_loss did not improve from 0.05126
# Epoch 58/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0856 - val_loss: 0.0822
#
# Epoch 00058: val_loss did not improve from 0.05126
# Epoch 59/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0620 - val_loss: 0.1118
#
# Epoch 00059: val_loss did not improve from 0.05126
# Epoch 60/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0624 - val_loss: 0.0441
#
# Epoch 00060: val_loss improved from 0.05126 to 0.04415, saving model to pfn_regressor_3f.h5
# Epoch 61/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0638 - val_loss: 0.0701
#
# Epoch 00061: val_loss did not improve from 0.04415
# Epoch 62/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2524 - val_loss: 0.1460
#
# Epoch 00062: val_loss did not improve from 0.04415
# Epoch 63/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0995 - val_loss: 0.0701
#
# Epoch 00063: val_loss did not improve from 0.04415
# Epoch 64/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.0509 - val_loss: 0.0445
#
# Epoch 00064: val_loss did not improve from 0.04415
# Epoch 65/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0530 - val_loss: 0.0569
#
# Epoch 00065: val_loss did not improve from 0.04415
# Epoch 66/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.0669 - val_loss: 0.1314
#
# Epoch 00066: val_loss did not improve from 0.04415
# Epoch 67/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0480 - val_loss: 0.0408
#
# Epoch 00067: val_loss improved from 0.04415 to 0.04081, saving model to pfn_regressor_3f.h5
# Epoch 68/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1628 - val_loss: 0.2473
#
# Epoch 00068: val_loss did not improve from 0.04081
# Epoch 69/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.1294 - val_loss: 0.0677
#
# Epoch 00069: val_loss did not improve from 0.04081
# Epoch 70/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0481 - val_loss: 0.0942
#
# Epoch 00070: val_loss did not improve from 0.04081
# Epoch 71/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.1249 - val_loss: 0.0613
#
# Epoch 00071: val_loss did not improve from 0.04081
# Epoch 72/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0592 - val_loss: 0.0451
#
# Epoch 00072: val_loss did not improve from 0.04081
# Epoch 73/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0453 - val_loss: 0.0341
#
# Epoch 00073: val_loss improved from 0.04081 to 0.03409, saving model to pfn_regressor_3f.h5
# Epoch 74/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0524 - val_loss: 0.0493
#
# Epoch 00074: val_loss did not improve from 0.03409
# Epoch 75/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0416 - val_loss: 0.0282
#
# Epoch 00075: val_loss improved from 0.03409 to 0.02823, saving model to pfn_regressor_3f.h5
# Epoch 76/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0448 - val_loss: 0.0366
#
# Epoch 00076: val_loss did not improve from 0.02823
# Epoch 77/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0447 - val_loss: 0.0419
#
# Epoch 00077: val_loss did not improve from 0.02823
# Epoch 78/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0446 - val_loss: 0.0300
#
# Epoch 00078: val_loss did not improve from 0.02823
# Epoch 79/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.0398 - val_loss: 0.0414
#
# Epoch 00079: val_loss did not improve from 0.02823
# Epoch 80/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0354 - val_loss: 0.0443
#
# Epoch 00080: val_loss did not improve from 0.02823
# Epoch 81/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0314 - val_loss: 0.0333
#
# Epoch 00081: val_loss did not improve from 0.02823
# Epoch 82/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0526 - val_loss: 0.1713
#
# Epoch 00082: val_loss did not improve from 0.02823
# Epoch 83/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0532 - val_loss: 0.0270
#
# Epoch 00083: val_loss improved from 0.02823 to 0.02697, saving model to pfn_regressor_3f.h5
# Epoch 84/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0351 - val_loss: 0.0350
#
# Epoch 00084: val_loss did not improve from 0.02697
# Epoch 85/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0360 - val_loss: 0.0282
#
# Epoch 00085: val_loss did not improve from 0.02697
# Epoch 86/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0299 - val_loss: 0.0317
#
# Epoch 00086: val_loss did not improve from 0.02697
# Epoch 87/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0287 - val_loss: 0.0420
#
# Epoch 00087: val_loss did not improve from 0.02697
# Epoch 88/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0462 - val_loss: 0.0416
#
# Epoch 00088: val_loss did not improve from 0.02697
# Epoch 89/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.0513 - val_loss: 0.0369
#
# Epoch 00089: val_loss did not improve from 0.02697
# Epoch 90/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0298 - val_loss: 0.0351
#
# Epoch 00090: val_loss did not improve from 0.02697
# Epoch 91/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0271 - val_loss: 0.0237
#
# Epoch 00091: val_loss improved from 0.02697 to 0.02374, saving model to pfn_regressor_3f.h5
# Epoch 92/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0272 - val_loss: 0.0280
#
# Epoch 00092: val_loss did not improve from 0.02374
# Epoch 93/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0339 - val_loss: 0.0720
#
# Epoch 00093: val_loss did not improve from 0.02374
# Epoch 94/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0263 - val_loss: 0.0236
#
# Epoch 00094: val_loss improved from 0.02374 to 0.02356, saving model to pfn_regressor_3f.h5
# Epoch 95/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0269 - val_loss: 0.0309
#
# Epoch 00095: val_loss did not improve from 0.02356
# Epoch 96/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 22.5950 - val_loss: 0.5830
#
# Epoch 00096: val_loss did not improve from 0.02356
# Epoch 97/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.2402 - val_loss: 0.1512
#
# Epoch 00097: val_loss did not improve from 0.02356
# Epoch 98/1000
# 116/116 [==============================] - 7s 59ms/step - loss: 0.1316 - val_loss: 0.0978
#
# Epoch 00098: val_loss did not improve from 0.02356
# Epoch 99/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0858 - val_loss: 0.0761
#
# Epoch 00099: val_loss did not improve from 0.02356
# Epoch 100/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0741 - val_loss: 0.0720
#
# Epoch 00100: val_loss did not improve from 0.02356
# Epoch 101/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0695 - val_loss: 0.0670
#
# Epoch 00101: val_loss did not improve from 0.02356
# Epoch 102/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0588 - val_loss: 0.0585
#
# Epoch 00102: val_loss did not improve from 0.02356
# Epoch 103/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0553 - val_loss: 0.0540
#
# Epoch 00103: val_loss did not improve from 0.02356
# Epoch 104/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0545 - val_loss: 0.0842
#
# Epoch 00104: val_loss did not improve from 0.02356
# Epoch 105/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0497 - val_loss: 0.0478
#
# Epoch 00105: val_loss did not improve from 0.02356
# Epoch 106/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0524 - val_loss: 0.0499
#
# Epoch 00106: val_loss did not improve from 0.02356
# Epoch 107/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0448 - val_loss: 0.0517
#
# Epoch 00107: val_loss did not improve from 0.02356
# Epoch 108/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0446 - val_loss: 0.0460
#
# Epoch 00108: val_loss did not improve from 0.02356
# Epoch 109/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0429 - val_loss: 0.0452
#
# Epoch 00109: val_loss did not improve from 0.02356
# Epoch 110/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0411 - val_loss: 0.0391
#
# Epoch 00110: val_loss did not improve from 0.02356
# Epoch 111/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0397 - val_loss: 0.0496
#
# Epoch 00111: val_loss did not improve from 0.02356
# Epoch 112/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0422 - val_loss: 0.0483
#
# Epoch 00112: val_loss did not improve from 0.02356
# Epoch 113/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0374 - val_loss: 0.0361
#
# Epoch 00113: val_loss did not improve from 0.02356
# Epoch 114/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0411 - val_loss: 0.0400
#
# Epoch 00114: val_loss did not improve from 0.02356
# Epoch 115/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0384 - val_loss: 0.0633
#
# Epoch 00115: val_loss did not improve from 0.02356
# Epoch 116/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0365 - val_loss: 0.0333
#
# Epoch 00116: val_loss did not improve from 0.02356
# Epoch 117/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0341 - val_loss: 0.0355
#
# Epoch 00117: val_loss did not improve from 0.02356
# Epoch 118/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0408 - val_loss: 0.0310
#
# Epoch 00118: val_loss did not improve from 0.02356
# Epoch 119/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0377 - val_loss: 0.0400
#
# Epoch 00119: val_loss did not improve from 0.02356
# Epoch 120/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0324 - val_loss: 0.0313
#
# Epoch 00120: val_loss did not improve from 0.02356
# Epoch 121/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0363 - val_loss: 0.0307
#
# Epoch 00121: val_loss did not improve from 0.02356
# Epoch 122/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0388 - val_loss: 0.0341
#
# Epoch 00122: val_loss did not improve from 0.02356
# Epoch 123/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0359 - val_loss: 0.0324
#
# Epoch 00123: val_loss did not improve from 0.02356
# Epoch 124/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0378 - val_loss: 0.0291
#
# Epoch 00124: val_loss did not improve from 0.02356
# Epoch 125/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0304 - val_loss: 0.0320
#
# Epoch 00125: val_loss did not improve from 0.02356
# Epoch 126/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0322 - val_loss: 0.0354
#
# Epoch 00126: val_loss did not improve from 0.02356
# Epoch 127/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0347 - val_loss: 0.0294
#
# Epoch 00127: val_loss did not improve from 0.02356
# Epoch 128/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0357 - val_loss: 0.0275
#
# Epoch 00128: val_loss did not improve from 0.02356
# Epoch 129/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0288 - val_loss: 0.0397
#
# Epoch 00129: val_loss did not improve from 0.02356
# Epoch 130/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0346 - val_loss: 0.0274
#
# Epoch 00130: val_loss did not improve from 0.02356
# Epoch 131/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0352 - val_loss: 0.0367
#
# Epoch 00131: val_loss did not improve from 0.02356
# Epoch 132/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0319 - val_loss: 0.0278
#
# Epoch 00132: val_loss did not improve from 0.02356
# Epoch 133/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0463 - val_loss: 0.0313
#
# Epoch 00133: val_loss did not improve from 0.02356
# Epoch 134/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0291 - val_loss: 0.0307
#
# Epoch 00134: val_loss did not improve from 0.02356
# Epoch 135/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0260 - val_loss: 0.0391
#
# Epoch 00135: val_loss did not improve from 0.02356
# Epoch 136/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0460 - val_loss: 0.0360
#
# Epoch 00136: val_loss did not improve from 0.02356
# Epoch 137/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0281 - val_loss: 0.0248
#
# Epoch 00137: val_loss did not improve from 0.02356
# Epoch 138/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0287 - val_loss: 0.0267
#
# Epoch 00138: val_loss did not improve from 0.02356
# Epoch 139/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0277 - val_loss: 0.0323
#
# Epoch 00139: val_loss did not improve from 0.02356
# Epoch 140/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0273 - val_loss: 0.0237
#
# Epoch 00140: val_loss did not improve from 0.02356
# Epoch 141/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0253 - val_loss: 0.0324
#
# Epoch 00141: val_loss did not improve from 0.02356
# Epoch 142/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0279 - val_loss: 0.0313
#
# Epoch 00142: val_loss did not improve from 0.02356
# Epoch 143/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0385 - val_loss: 0.0444
#
# Epoch 00143: val_loss did not improve from 0.02356
# Epoch 144/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0322 - val_loss: 0.0325
#
# Epoch 00144: val_loss did not improve from 0.02356
# Epoch 145/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0345 - val_loss: 0.0279
#
# Epoch 00145: val_loss did not improve from 0.02356
# Epoch 146/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0249 - val_loss: 0.0277
#
# Epoch 00146: val_loss did not improve from 0.02356
# Epoch 147/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0256 - val_loss: 0.0232
#
# Epoch 00147: val_loss improved from 0.02356 to 0.02316, saving model to pfn_regressor_3f.h5
# Epoch 148/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0239 - val_loss: 0.0372
#
# Epoch 00148: val_loss did not improve from 0.02316
# Epoch 149/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0293 - val_loss: 0.0228
#
# Epoch 00149: val_loss improved from 0.02316 to 0.02285, saving model to pfn_regressor_3f.h5
# Epoch 150/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0216 - val_loss: 0.0238
#
# Epoch 00150: val_loss did not improve from 0.02285
# Epoch 151/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0291 - val_loss: 0.0321
#
# Epoch 00151: val_loss did not improve from 0.02285
# Epoch 152/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0251 - val_loss: 0.0294
#
# Epoch 00152: val_loss did not improve from 0.02285
# Epoch 153/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0219 - val_loss: 0.0225
#
# Epoch 00153: val_loss improved from 0.02285 to 0.02248, saving model to pfn_regressor_3f.h5
# Epoch 154/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0200 - val_loss: 0.0192
#
# Epoch 00154: val_loss improved from 0.02248 to 0.01921, saving model to pfn_regressor_3f.h5
# Epoch 155/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0304 - val_loss: 0.0221
#
# Epoch 00155: val_loss did not improve from 0.01921
# Epoch 156/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0248 - val_loss: 0.0242
#
# Epoch 00156: val_loss did not improve from 0.01921
# Epoch 157/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0200 - val_loss: 0.0205
#
# Epoch 00157: val_loss did not improve from 0.01921
# Epoch 158/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0292 - val_loss: 0.0237
#
# Epoch 00158: val_loss did not improve from 0.01921
# Epoch 159/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0232 - val_loss: 0.0265
#
# Epoch 00159: val_loss did not improve from 0.01921
# Epoch 160/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0203 - val_loss: 0.0191
#
# Epoch 00160: val_loss improved from 0.01921 to 0.01912, saving model to pfn_regressor_3f.h5
# Epoch 161/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0205 - val_loss: 0.0196
#
# Epoch 00161: val_loss did not improve from 0.01912
# Epoch 162/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0212 - val_loss: 0.0251
#
# Epoch 00162: val_loss did not improve from 0.01912
# Epoch 163/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0252 - val_loss: 0.0188
#
# Epoch 00163: val_loss improved from 0.01912 to 0.01877, saving model to pfn_regressor_3f.h5
# Epoch 164/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0226 - val_loss: 0.0196
#
# Epoch 00164: val_loss did not improve from 0.01877
# Epoch 165/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0210 - val_loss: 0.0204
#
# Epoch 00165: val_loss did not improve from 0.01877
# Epoch 166/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0181 - val_loss: 0.0228
#
# Epoch 00166: val_loss did not improve from 0.01877
# Epoch 167/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0218 - val_loss: 0.0260
#
# Epoch 00167: val_loss did not improve from 0.01877
# Epoch 168/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0224 - val_loss: 0.0174
#
# Epoch 00168: val_loss improved from 0.01877 to 0.01736, saving model to pfn_regressor_3f.h5
# Epoch 169/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0180 - val_loss: 0.0190
#
# Epoch 00169: val_loss did not improve from 0.01736
# Epoch 170/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0223 - val_loss: 0.0231
#
# Epoch 00170: val_loss did not improve from 0.01736
# Epoch 171/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0223 - val_loss: 0.0167
#
# Epoch 00171: val_loss improved from 0.01736 to 0.01669, saving model to pfn_regressor_3f.h5
# Epoch 172/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0206 - val_loss: 0.0190
#
# Epoch 00172: val_loss did not improve from 0.01669
# Epoch 173/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0201 - val_loss: 0.0209
#
# Epoch 00173: val_loss did not improve from 0.01669
# Epoch 174/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0194 - val_loss: 0.0196
#
# Epoch 00174: val_loss did not improve from 0.01669
# Epoch 175/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0204 - val_loss: 0.0200
#
# Epoch 00175: val_loss did not improve from 0.01669
# Epoch 176/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0172 - val_loss: 0.0163
#
# Epoch 00176: val_loss improved from 0.01669 to 0.01629, saving model to pfn_regressor_3f.h5
# Epoch 177/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0194 - val_loss: 0.0162
#
# Epoch 00177: val_loss improved from 0.01629 to 0.01618, saving model to pfn_regressor_3f.h5
# Epoch 178/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0171 - val_loss: 0.0206
#
# Epoch 00178: val_loss did not improve from 0.01618
# Epoch 179/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0192 - val_loss: 0.0158
#
# Epoch 00179: val_loss improved from 0.01618 to 0.01577, saving model to pfn_regressor_3f.h5
# Epoch 180/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0168 - val_loss: 0.0174
#
# Epoch 00180: val_loss did not improve from 0.01577
# Epoch 181/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0159 - val_loss: 0.0181
#
# Epoch 00181: val_loss did not improve from 0.01577
# Epoch 182/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0204 - val_loss: 0.0259
#
# Epoch 00182: val_loss did not improve from 0.01577
# Epoch 183/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0178 - val_loss: 0.0236
#
# Epoch 00183: val_loss did not improve from 0.01577
# Epoch 184/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0174 - val_loss: 0.0176
#
# Epoch 00184: val_loss did not improve from 0.01577
# Epoch 185/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0154 - val_loss: 0.0155
#
# Epoch 00185: val_loss improved from 0.01577 to 0.01552, saving model to pfn_regressor_3f.h5
# Epoch 186/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0158 - val_loss: 0.0146
#
# Epoch 00186: val_loss improved from 0.01552 to 0.01457, saving model to pfn_regressor_3f.h5
# Epoch 187/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0179 - val_loss: 0.0193
#
# Epoch 00187: val_loss did not improve from 0.01457
# Epoch 188/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0178 - val_loss: 0.0274
#
# Epoch 00188: val_loss did not improve from 0.01457
# Epoch 189/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0158 - val_loss: 0.0166
#
# Epoch 00189: val_loss did not improve from 0.01457
# Epoch 190/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0190 - val_loss: 0.0157
#
# Epoch 00190: val_loss did not improve from 0.01457
# Epoch 191/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0157 - val_loss: 0.0159
#
# Epoch 00191: val_loss did not improve from 0.01457
# Epoch 192/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0164 - val_loss: 0.0200
#
# Epoch 00192: val_loss did not improve from 0.01457
# Epoch 193/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0147 - val_loss: 0.0161
#
# Epoch 00193: val_loss did not improve from 0.01457
# Epoch 194/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0147 - val_loss: 0.0143
#
# Epoch 00194: val_loss improved from 0.01457 to 0.01435, saving model to pfn_regressor_3f.h5
# Epoch 195/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0148 - val_loss: 0.0213
#
# Epoch 00195: val_loss did not improve from 0.01435
# Epoch 196/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0162 - val_loss: 0.0169
#
# Epoch 00196: val_loss did not improve from 0.01435
# Epoch 197/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0179 - val_loss: 0.0164
#
# Epoch 00197: val_loss did not improve from 0.01435
# Epoch 198/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0155 - val_loss: 0.0160
#
# Epoch 00198: val_loss did not improve from 0.01435
# Epoch 199/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0144 - val_loss: 0.0229
#
# Epoch 00199: val_loss did not improve from 0.01435
# Epoch 200/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0163 - val_loss: 0.0156
#
# Epoch 00200: val_loss did not improve from 0.01435
# Epoch 201/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0143 - val_loss: 0.0173
#
# Epoch 00201: val_loss did not improve from 0.01435
# Epoch 202/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0153 - val_loss: 0.0169
#
# Epoch 00202: val_loss did not improve from 0.01435
# Epoch 203/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0136 - val_loss: 0.0159
#
# Epoch 00203: val_loss did not improve from 0.01435
# Epoch 204/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0140 - val_loss: 0.0201
#
# Epoch 00204: val_loss did not improve from 0.01435
# Epoch 205/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0176 - val_loss: 0.0208
#
# Epoch 00205: val_loss did not improve from 0.01435
# Epoch 206/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0146 - val_loss: 0.0144
#
# Epoch 00206: val_loss did not improve from 0.01435
# Epoch 207/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0138 - val_loss: 0.0148
#
# Epoch 00207: val_loss did not improve from 0.01435
# Epoch 208/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0132 - val_loss: 0.0148
#
# Epoch 00208: val_loss did not improve from 0.01435
# Epoch 209/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0147 - val_loss: 0.0175
#
# Epoch 00209: val_loss did not improve from 0.01435
# Epoch 210/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0140 - val_loss: 0.0155
#
# Epoch 00210: val_loss did not improve from 0.01435
# Epoch 211/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0165 - val_loss: 0.0147
#
# Epoch 00211: val_loss did not improve from 0.01435
# Epoch 212/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0129 - val_loss: 0.0183
#
# Epoch 00212: val_loss did not improve from 0.01435
# Epoch 213/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0138 - val_loss: 0.0148
#
# Epoch 00213: val_loss did not improve from 0.01435
# Epoch 214/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0131 - val_loss: 0.0134
#
# Epoch 00214: val_loss improved from 0.01435 to 0.01336, saving model to pfn_regressor_3f.h5
# Epoch 215/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0131 - val_loss: 0.0132
#
# Epoch 00215: val_loss improved from 0.01336 to 0.01324, saving model to pfn_regressor_3f.h5
# Epoch 216/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0122 - val_loss: 0.0153
#
# Epoch 00216: val_loss did not improve from 0.01324
# Epoch 217/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0131 - val_loss: 0.0149
#
# Epoch 00217: val_loss did not improve from 0.01324
# Epoch 218/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0142 - val_loss: 0.0141
#
# Epoch 00218: val_loss did not improve from 0.01324
# Epoch 219/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0167 - val_loss: 0.0241
#
# Epoch 00219: val_loss did not improve from 0.01324
# Epoch 220/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0167 - val_loss: 0.0189
#
# Epoch 00220: val_loss did not improve from 0.01324
# Epoch 221/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0135 - val_loss: 0.0174
#
# Epoch 00221: val_loss did not improve from 0.01324
# Epoch 222/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0117 - val_loss: 0.0129
#
# Epoch 00222: val_loss improved from 0.01324 to 0.01292, saving model to pfn_regressor_3f.h5
# Epoch 223/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0146 - val_loss: 0.0131
#
# Epoch 00223: val_loss did not improve from 0.01292
# Epoch 224/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0113 - val_loss: 0.0121
#
# Epoch 00224: val_loss improved from 0.01292 to 0.01214, saving model to pfn_regressor_3f.h5
# Epoch 225/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0128 - val_loss: 0.0130
#
# Epoch 00225: val_loss did not improve from 0.01214
# Epoch 226/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0116 - val_loss: 0.0135
#
# Epoch 00226: val_loss did not improve from 0.01214
# Epoch 227/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0118 - val_loss: 0.0121
#
# Epoch 00227: val_loss improved from 0.01214 to 0.01212, saving model to pfn_regressor_3f.h5
# Epoch 228/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0128 - val_loss: 0.0143
#
# Epoch 00228: val_loss did not improve from 0.01212
# Epoch 229/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0122 - val_loss: 0.0136
#
# Epoch 00229: val_loss did not improve from 0.01212
# Epoch 230/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0126 - val_loss: 0.0144
#
# Epoch 00230: val_loss did not improve from 0.01212
# Epoch 231/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0121 - val_loss: 0.0169
#
# Epoch 00231: val_loss did not improve from 0.01212
# Epoch 232/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0108 - val_loss: 0.0179
#
# Epoch 00232: val_loss did not improve from 0.01212
# Epoch 233/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0115 - val_loss: 0.0133
#
# Epoch 00233: val_loss did not improve from 0.01212
# Epoch 234/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0125 - val_loss: 0.0129
#
# Epoch 00234: val_loss did not improve from 0.01212
# Epoch 235/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0117 - val_loss: 0.0129
#
# Epoch 00235: val_loss did not improve from 0.01212
# Epoch 236/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0112 - val_loss: 0.0133
#
# Epoch 00236: val_loss did not improve from 0.01212
# Epoch 237/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0118 - val_loss: 0.0187
#
# Epoch 00237: val_loss did not improve from 0.01212
# Epoch 238/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0126 - val_loss: 0.0123
#
# Epoch 00238: val_loss did not improve from 0.01212
# Epoch 239/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0117 - val_loss: 0.0151
#
# Epoch 00239: val_loss did not improve from 0.01212
# Epoch 240/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0131 - val_loss: 0.0194
#
# Epoch 00240: val_loss did not improve from 0.01212
# Epoch 241/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0142 - val_loss: 0.0139
#
# Epoch 00241: val_loss did not improve from 0.01212
# Epoch 242/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0116 - val_loss: 0.0122
#
# Epoch 00242: val_loss did not improve from 0.01212
# Epoch 243/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0104 - val_loss: 0.0112
#
# Epoch 00243: val_loss improved from 0.01212 to 0.01120, saving model to pfn_regressor_3f.h5
# Epoch 244/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0104 - val_loss: 0.0108
#
# Epoch 00244: val_loss improved from 0.01120 to 0.01083, saving model to pfn_regressor_3f.h5
# Epoch 245/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0135 - val_loss: 0.0139
#
# Epoch 00245: val_loss did not improve from 0.01083
# Epoch 246/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0111 - val_loss: 0.0119
#
# Epoch 00246: val_loss did not improve from 0.01083
# Epoch 247/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0124 - val_loss: 0.0149
#
# Epoch 00247: val_loss did not improve from 0.01083
# Epoch 248/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0110 - val_loss: 0.0144
#
# Epoch 00248: val_loss did not improve from 0.01083
# Epoch 249/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0110 - val_loss: 0.0130
#
# Epoch 00249: val_loss did not improve from 0.01083
# Epoch 250/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0100 - val_loss: 0.0116
#
# Epoch 00250: val_loss did not improve from 0.01083
# Epoch 251/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0113 - val_loss: 0.0131
#
# Epoch 00251: val_loss did not improve from 0.01083
# Epoch 252/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0096 - val_loss: 0.0128
#
# Epoch 00252: val_loss did not improve from 0.01083
# Epoch 253/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0098 - val_loss: 0.0137
#
# Epoch 00253: val_loss did not improve from 0.01083
# Epoch 254/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0114 - val_loss: 0.0113
#
# Epoch 00254: val_loss did not improve from 0.01083
# Epoch 255/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0099 - val_loss: 0.0103
#
# Epoch 00255: val_loss improved from 0.01083 to 0.01029, saving model to pfn_regressor_3f.h5
# Epoch 256/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0087 - val_loss: 0.0160
#
# Epoch 00256: val_loss did not improve from 0.01029
# Epoch 257/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0112 - val_loss: 0.0158
#
# Epoch 00257: val_loss did not improve from 0.01029
# Epoch 258/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0102 - val_loss: 0.0109
#
# Epoch 00258: val_loss did not improve from 0.01029
# Epoch 259/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0097 - val_loss: 0.0123
#
# Epoch 00259: val_loss did not improve from 0.01029
# Epoch 260/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0096 - val_loss: 0.0128
#
# Epoch 00260: val_loss did not improve from 0.01029
# Epoch 261/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0092 - val_loss: 0.0105
#
# Epoch 00261: val_loss did not improve from 0.01029
# Epoch 262/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0099 - val_loss: 0.0233
#
# Epoch 00262: val_loss did not improve from 0.01029
# Epoch 263/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0102 - val_loss: 0.0156
#
# Epoch 00263: val_loss did not improve from 0.01029
# Epoch 264/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0105 - val_loss: 0.0117
#
# Epoch 00264: val_loss did not improve from 0.01029
# Epoch 265/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0103 - val_loss: 0.0100
#
# Epoch 00265: val_loss improved from 0.01029 to 0.01003, saving model to pfn_regressor_3f.h5
# Epoch 266/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0086 - val_loss: 0.0106
#
# Epoch 00266: val_loss did not improve from 0.01003
# Epoch 267/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0085 - val_loss: 0.0094
#
# Epoch 00267: val_loss improved from 0.01003 to 0.00942, saving model to pfn_regressor_3f.h5
# Epoch 268/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0080 - val_loss: 0.0098
#
# Epoch 00268: val_loss did not improve from 0.00942
# Epoch 269/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0096 - val_loss: 0.0099
#
# Epoch 00269: val_loss did not improve from 0.00942
# Epoch 270/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0100 - val_loss: 0.0101
#
# Epoch 00270: val_loss did not improve from 0.00942
# Epoch 271/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0087 - val_loss: 0.0110
#
# Epoch 00271: val_loss did not improve from 0.00942
# Epoch 272/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0085 - val_loss: 0.0091
#
# Epoch 00272: val_loss improved from 0.00942 to 0.00912, saving model to pfn_regressor_3f.h5
# Epoch 273/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0086 - val_loss: 0.0099
#
# Epoch 00273: val_loss did not improve from 0.00912
# Epoch 274/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0089 - val_loss: 0.0105
#
# Epoch 00274: val_loss did not improve from 0.00912
# Epoch 275/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0094 - val_loss: 0.0088
#
# Epoch 00275: val_loss improved from 0.00912 to 0.00878, saving model to pfn_regressor_3f.h5
# Epoch 276/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0091 - val_loss: 0.0093
#
# Epoch 00276: val_loss did not improve from 0.00878
# Epoch 277/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0079 - val_loss: 0.0091
#
# Epoch 00277: val_loss did not improve from 0.00878
# Epoch 278/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0076 - val_loss: 0.0108
#
# Epoch 00278: val_loss did not improve from 0.00878
# Epoch 279/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0080 - val_loss: 0.0099
#
# Epoch 00279: val_loss did not improve from 0.00878
# Epoch 280/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0084 - val_loss: 0.0109
#
# Epoch 00280: val_loss did not improve from 0.00878
# Epoch 281/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0079 - val_loss: 0.0095
#
# Epoch 00281: val_loss did not improve from 0.00878
# Epoch 282/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0085 - val_loss: 0.0094
#
# Epoch 00282: val_loss did not improve from 0.00878
# Epoch 283/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0078 - val_loss: 0.0089
#
# Epoch 00283: val_loss did not improve from 0.00878
# Epoch 284/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0073 - val_loss: 0.0083
#
# Epoch 00284: val_loss improved from 0.00878 to 0.00828, saving model to pfn_regressor_3f.h5
# Epoch 285/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0075 - val_loss: 0.0105
#
# Epoch 00285: val_loss did not improve from 0.00828
# Epoch 286/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0076 - val_loss: 0.0084
#
# Epoch 00286: val_loss did not improve from 0.00828
# Epoch 287/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0080 - val_loss: 0.0094
#
# Epoch 00287: val_loss did not improve from 0.00828
# Epoch 288/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0074 - val_loss: 0.0086
#
# Epoch 00288: val_loss did not improve from 0.00828
# Epoch 289/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0073 - val_loss: 0.0143
#
# Epoch 00289: val_loss did not improve from 0.00828
# Epoch 290/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0084 - val_loss: 0.0108
#
# Epoch 00290: val_loss did not improve from 0.00828
# Epoch 291/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0067 - val_loss: 0.0087
#
# Epoch 00291: val_loss did not improve from 0.00828
# Epoch 292/1000
# ...
#
# Epoch 00571: val_loss did not improve from 0.00534
# Epoch 572/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0036 - val_loss: 0.0061
#
# Epoch 00572: val_loss did not improve from 0.00534
# Epoch 573/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0062
#
# Epoch 00573: val_loss did not improve from 0.00534
# Epoch 574/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0057
#
# Epoch 00574: val_loss did not improve from 0.00534
# Epoch 575/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0034 - val_loss: 0.0058
#
# Epoch 00575: val_loss did not improve from 0.00534
# Epoch 576/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0033 - val_loss: 0.0068
#
# Epoch 00576: val_loss did not improve from 0.00534
# Epoch 577/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0065
#
# Epoch 00577: val_loss did not improve from 0.00534
# Epoch 578/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00578: val_loss did not improve from 0.00534
# Epoch 579/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0059
#
# Epoch 00579: val_loss did not improve from 0.00534
# Epoch 580/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0032 - val_loss: 0.0057
#
# Epoch 00580: val_loss did not improve from 0.00534
# Epoch 581/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0053
#
# Epoch 00581: val_loss improved from 0.00534 to 0.00531, saving model to pfn_regressor_3f.h5
# Epoch 582/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0057
#
# Epoch 00582: val_loss did not improve from 0.00531
# Epoch 583/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0033 - val_loss: 0.0062
#
# Epoch 00583: val_loss did not improve from 0.00531
# Epoch 584/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0038 - val_loss: 0.0057
#
# Epoch 00584: val_loss did not improve from 0.00531
# Epoch 585/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0055
#
# Epoch 00585: val_loss did not improve from 0.00531
# Epoch 586/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0031 - val_loss: 0.0056
#
# Epoch 00586: val_loss did not improve from 0.00531
# Epoch 587/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0041 - val_loss: 0.0062
#
# Epoch 00587: val_loss did not improve from 0.00531
# Epoch 588/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0052 - val_loss: 0.0067
#
# Epoch 00588: val_loss did not improve from 0.00531
# Epoch 589/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0044 - val_loss: 0.0068
#
# Epoch 00589: val_loss did not improve from 0.00531
# Epoch 590/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0072 - val_loss: 0.0076
#
# Epoch 00590: val_loss did not improve from 0.00531
# Epoch 591/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0055 - val_loss: 0.0069
#
# Epoch 00591: val_loss did not improve from 0.00531
# Epoch 592/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0041 - val_loss: 0.0064
#
# Epoch 00592: val_loss did not improve from 0.00531
# Epoch 593/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0037 - val_loss: 0.0069
#
# Epoch 00593: val_loss did not improve from 0.00531
# Epoch 594/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0037 - val_loss: 0.0061
#
# Epoch 00594: val_loss did not improve from 0.00531
# Epoch 595/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0038 - val_loss: 0.0068
#
# Epoch 00595: val_loss did not improve from 0.00531
# Epoch 596/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0059
#
# Epoch 00596: val_loss did not improve from 0.00531
# Epoch 597/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0032 - val_loss: 0.0060
#
# Epoch 00597: val_loss did not improve from 0.00531
# Epoch 598/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0058
#
# Epoch 00598: val_loss did not improve from 0.00531
# Epoch 599/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00599: val_loss did not improve from 0.00531
# Epoch 600/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0030 - val_loss: 0.0061
#
# Epoch 00600: val_loss did not improve from 0.00531
# Epoch 601/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0057
#
# Epoch 00601: val_loss did not improve from 0.00531
# Epoch 602/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0060
#
# Epoch 00602: val_loss did not improve from 0.00531
# Epoch 603/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00603: val_loss did not improve from 0.00531
# Epoch 604/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0055
#
# Epoch 00604: val_loss did not improve from 0.00531
# Epoch 605/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0037 - val_loss: 0.0068
#
# Epoch 00605: val_loss did not improve from 0.00531
# Epoch 606/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0057
#
# Epoch 00606: val_loss did not improve from 0.00531
# Epoch 607/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0029 - val_loss: 0.0060
#
# Epoch 00607: val_loss did not improve from 0.00531
# Epoch 608/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0056
#
# Epoch 00608: val_loss did not improve from 0.00531
# Epoch 609/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0056
#
# Epoch 00609: val_loss did not improve from 0.00531
# Epoch 610/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0060
#
# Epoch 00610: val_loss did not improve from 0.00531
# Epoch 611/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0059
#
# Epoch 00611: val_loss did not improve from 0.00531
# Epoch 612/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0069
#
# Epoch 00612: val_loss did not improve from 0.00531
# Epoch 613/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0030 - val_loss: 0.0063
#
# Epoch 00613: val_loss did not improve from 0.00531
# Epoch 614/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00614: val_loss did not improve from 0.00531
# Epoch 615/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0034 - val_loss: 0.0062
#
# Epoch 00615: val_loss did not improve from 0.00531
# Epoch 616/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0034 - val_loss: 0.0070
#
# Epoch 00616: val_loss did not improve from 0.00531
# Epoch 617/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0034 - val_loss: 0.0057
#
# Epoch 00617: val_loss did not improve from 0.00531
# Epoch 618/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0056
#
# Epoch 00618: val_loss did not improve from 0.00531
# Epoch 619/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0059
#
# Epoch 00619: val_loss did not improve from 0.00531
# Epoch 620/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0033 - val_loss: 0.0061
#
# Epoch 00620: val_loss did not improve from 0.00531
# Epoch 621/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0035 - val_loss: 0.0077
#
# Epoch 00621: val_loss did not improve from 0.00531
# Epoch 622/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0060
#
# Epoch 00622: val_loss did not improve from 0.00531
# Epoch 623/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0031 - val_loss: 0.0072
#
# Epoch 00623: val_loss did not improve from 0.00531
# Epoch 624/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0034 - val_loss: 0.0059
#
# Epoch 00624: val_loss did not improve from 0.00531
# Epoch 625/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0033 - val_loss: 0.0059
#
# Epoch 00625: val_loss did not improve from 0.00531
# Epoch 626/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0031 - val_loss: 0.0059
#
# Epoch 00626: val_loss did not improve from 0.00531
# Epoch 627/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0032 - val_loss: 0.0071
#
# Epoch 00627: val_loss did not improve from 0.00531
# Epoch 628/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0035 - val_loss: 0.0063
#
# Epoch 00628: val_loss did not improve from 0.00531
# Epoch 629/1000
# 116/116 [==============================] - 6s 60ms/step - loss: 0.0030 - val_loss: 0.0058
#
# Epoch 00629: val_loss did not improve from 0.00531
# Epoch 630/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0072
#
# Epoch 00630: val_loss did not improve from 0.00531
# Epoch 631/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0036 - val_loss: 0.0076
#
# Epoch 00631: val_loss did not improve from 0.00531
# Epoch 632/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00632: val_loss did not improve from 0.00531
# Epoch 633/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0066
#
# Epoch 00633: val_loss did not improve from 0.00531
# Epoch 634/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0056
#
# Epoch 00634: val_loss did not improve from 0.00531
# Epoch 635/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0058
#
# Epoch 00635: val_loss did not improve from 0.00531
# Epoch 636/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0066
#
# Epoch 00636: val_loss did not improve from 0.00531
# Epoch 637/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0035 - val_loss: 0.0061
#
# Epoch 00637: val_loss did not improve from 0.00531
# Epoch 638/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0055
#
# Epoch 00638: val_loss did not improve from 0.00531
# Epoch 639/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0031 - val_loss: 0.0065
#
# Epoch 00639: val_loss did not improve from 0.00531
# Epoch 640/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0042 - val_loss: 0.0070
#
# Epoch 00640: val_loss did not improve from 0.00531
# Epoch 641/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0032 - val_loss: 0.0077
#
# Epoch 00641: val_loss did not improve from 0.00531
# Epoch 642/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0031 - val_loss: 0.0057
#
# Epoch 00642: val_loss did not improve from 0.00531
# Epoch 643/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0045 - val_loss: 0.0063
#
# Epoch 00643: val_loss did not improve from 0.00531
# Epoch 644/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0040 - val_loss: 0.0066
#
# Epoch 00644: val_loss did not improve from 0.00531
# Epoch 645/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0035 - val_loss: 0.0059
#
# Epoch 00645: val_loss did not improve from 0.00531
# Epoch 646/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0029 - val_loss: 0.0064
#
# Epoch 00646: val_loss did not improve from 0.00531
# Epoch 647/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0028 - val_loss: 0.0061
#
# Epoch 00647: val_loss did not improve from 0.00531
# Epoch 648/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0035 - val_loss: 0.0070
#
# Epoch 00648: val_loss did not improve from 0.00531
# Epoch 649/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0069
#
# Epoch 00649: val_loss did not improve from 0.00531
# Epoch 650/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0030 - val_loss: 0.0055
#
# Epoch 00650: val_loss did not improve from 0.00531
# Epoch 651/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0029 - val_loss: 0.0061
#
# Epoch 00651: val_loss did not improve from 0.00531
# Epoch 652/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0028 - val_loss: 0.0057
#
# Epoch 00652: val_loss did not improve from 0.00531
# Epoch 653/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0027 - val_loss: 0.0058
#
# Epoch 00653: val_loss did not improve from 0.00531
# Epoch 654/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0026 - val_loss: 0.0059
#
# Epoch 00654: val_loss did not improve from 0.00531
# Epoch 655/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0027 - val_loss: 0.0061
#
# Epoch 00655: val_loss did not improve from 0.00531
# Epoch 656/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0028 - val_loss: 0.0065
#
# Epoch 00656: val_loss did not improve from 0.00531
# Epoch 657/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0028 - val_loss: 0.0055
#
# Epoch 00657: val_loss did not improve from 0.00531
# Epoch 658/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0034 - val_loss: 0.0062
#
# Epoch 00658: val_loss did not improve from 0.00531
# Epoch 659/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0028 - val_loss: 0.0065
#
# Epoch 00659: val_loss did not improve from 0.00531
# Epoch 660/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0026 - val_loss: 0.0056
#
# Epoch 00660: val_loss did not improve from 0.00531
# Epoch 661/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0026 - val_loss: 0.0058
#
# Epoch 00661: val_loss did not improve from 0.00531
# Epoch 662/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0030 - val_loss: 0.0058
#
# Epoch 00662: val_loss did not improve from 0.00531
# Epoch 663/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0028 - val_loss: 0.0064
#
# Epoch 00663: val_loss did not improve from 0.00531
# Epoch 664/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0027 - val_loss: 0.0055
#
# Epoch 00664: val_loss did not improve from 0.00531
# Epoch 665/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00665: val_loss did not improve from 0.00531
# Epoch 666/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00666: val_loss did not improve from 0.00531
# Epoch 667/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0048 - val_loss: 0.0068
#
# Epoch 00667: val_loss did not improve from 0.00531
# Epoch 668/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0046 - val_loss: 0.0071
#
# Epoch 00668: val_loss did not improve from 0.00531
# Epoch 669/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0037 - val_loss: 0.0081
#
# Epoch 00669: val_loss did not improve from 0.00531
# Epoch 670/1000
# 116/116 [==============================] - 7s 60ms/step - loss: 0.0033 - val_loss: 0.0061
#
# Epoch 00670: val_loss did not improve from 0.00531
# Epoch 671/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0029 - val_loss: 0.0067
#
# Epoch 00671: val_loss did not improve from 0.00531
# Epoch 672/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0027 - val_loss: 0.0063
#
# Epoch 00672: val_loss did not improve from 0.00531

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(history_ct.history['val_loss'], label="Validation")
plt.plot(history_ct.history['loss'], label="Training")
plt.yscale('log')
plt.ylim(.001,10)
plt.yticks(fontsize=13)
plt.xlim(0,1000)
plt.xticks(fontsize=13)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right', ncol=1)
plt.text(1000, 1.5, 'LR=1e-3', fontsize=13)
plt.text(1000, 1, 'Batch: 1500', fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_lossCurves_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
model = tf.keras.models.load_model("pfn_regressor_2g_fs.h5")

# %%
def eval_generator(data, batch_size):
     batches = (len(data) + batch_size - 1)//batch_size
     for i in range(batches):
          X = data[i*batch_size : (i+1)*batch_size]
          yield (X)

# %%
preds = np.exp(pfn.predict(eval_generator(x_test,500)).flatten())
print(preds.shape)
# Out:
# (18538,)

# %%
## PREDICTIONS AND TRUTH ##
bins = np.linspace(0,8,50, endpoint=True)
fig = plt.figure(figsize=(6,6))
plt.hist(np.exp(y_test), color='steelblue', bins=bins, density=True, alpha=.5, edgecolor='black', label='target')
plt.hist(preds, color='coral', bins=bins, density=True, alpha=.5, edgecolor='black', label='network')
plt.title('Regression Output and Target', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(0,8)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(loc='upper left')
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_targetPreds_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
xcenter, medDNN = ru.responsePlot(x=np.exp(y_test), y=preds/np.exp(y_test),
                 atlas_x = 0.46, atlas_y = 0.95, simulation = True,
                 textlist = [{'x': 0.46, 'y': 0.85, 'text': 'Single $\pi^{+}$, Track+Clusters'},
                             {'x': 0.46, 'y': 0.8,  'text': 'keras_pfn'}])

# %%
import scipy.stats as stats
# from . import plot_util as pu
from util import plot_util as pu

def _iqrOverMed(x):
    # get the IQR via the percentile function
    # 84 is median + 1 sigma, 16 is median - 1 sigma
    q16, q84 = np.percentile(x, [16, 84])
    return (q84 - q16) / (2 * np.median(x))

def resolutionPlot(x, y, figfile='',
                   xlabel='True Energy [GeV]', ylabel='Response IQR / (2 x Median)',
                   atlas_x=-1, atlas_y=-1, simulation=False,
                   xlim=(0.3,1000), ylim=(0,1), 
                   textlist=[]):
    xbin = [10**exp for exp in  np.arange(-1.0, 3.1, 0.1)]
    xcenter = [(xbin[i] + xbin[i+1]) / 2 for i in range(len(xbin)-1)]

    resolution = stats.binned_statistic(x, y, bins=xbin, statistic=_iqrOverMed).statistic
    
    plt.cla(); plt.clf()
    fig = plt.figure()
    fig.patch.set_facecolor('white')
    plt.plot(xcenter, resolution)
    plt.xscale('log')
    plt.xlim(xlim)
    plt.ylim(ylim)
    pu.ampl.set_xlabel(xlabel)
    pu.ampl.set_ylabel(ylabel)

    pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

    if figfile != '':
        plt.savefig(figfile)
    plt.show()

    return xcenter, resolution

# %%
xcenter, iqrMDN3 = resolutionPlot(np.exp(y_test), preds,
                        atlas_x = 0.56, atlas_y = 0.95, simulation = True,
                        textlist = [{'x': 0.56, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
                                    {'x': 0.56, 'y': 0.8,  'text': 'keras_pfn'}])

# %%
resp_plot = ru.resolutionPlot(x=np.exp(y_test), y=preds/np.exp(y_test),
                    figfile='',
                    statistic='std', xlabel='Particle Truth Energy', ylabel='Energy IQR over Median',
                    atlas_x=-1, atlas_y=-1, simulation=False,
                    textlist=[])

# %%
resid_DNN = preds - np.exp(y_test)

n_bins = 500
plt.cla(); plt.clf()
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.hist(resid_DNN,bins = n_bins,alpha=0.75)
plt.yscale('log')
plt.xlabel('Learned - True Energy')
plt.ylabel('Clusters')
plt.xlim(-3000,3000)
plt.legend()

atlas_x = 0.55
atlas_y = 0.95
simulation = True
textlist = [{'x': 0.55, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
            {'x': 0.55, 'y': 0.8,  'text': 'keras_pfn'}]
pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

plt.show()

# %%
def histogramSlices(x, ylist, labels=[''], xstep=0.2, statistic='iqr', title = 'Response',
                 xlabel='Predicted Energy / True Energy', ylabel='Clusters', alpha=1.,
                 xlim=(0.3,1000.), ylim=(0.,3.1), binsize=0.05, baseline=False, logscale=False, density=False,
                 atlas_x=-1, atlas_y=-1, simulation=False,
                 textlist=[]):
    
    if type(ylist) != type([]):
        ylist = [ylist]

    xbin = [10**exp for exp in np.arange(-1.0, 3.1, xstep)]
    last_xbin = [10**exp for exp in np.arange(-1.0, 3.1, xstep)]
    
    ybin = np.arange(ylim[0], ylim[1], binsize)

    plt.cla()
    plt.clf()

    for xbin_left,xbin_right in zip(last_xbin,xbin[1:]):
        fig = plt.figure()
        val_mask = np.logical_and(x > xbin_left, x < xbin_right)

        for y,label in zip(ylist,labels):
            if statistic == 'iqr':
                med = np.median(y[val_mask])
                iqr = np.percentile(y[val_mask], q=84) - np.percentile(y[val_mask], q=16)
                plt.hist(y[val_mask], bins=ybin, density=density, 
                        label = label + ' Median = {:.2f}, IQR = {:.2f}'.format(med, iqr),
                         alpha=alpha)
            elif statistic == 'std':
                mu = np.mean(y[val_mask])
                sig = np.std(y[val_mask])
                plt.hist(y[val_mask], bins=ybin, density=density, 
                        label = label + ' Mean = {:.2f}, Std. Dev. = {:.2f}'.format(mu, sig),
                         alpha=alpha)
            else:
                plt.hist(y[val_mask], bins=ybin, density=density,
                         label = label,
                         alpha=alpha)
            
            if baseline:
                x1 = np.linspace(-6,6,100)
                pdf = stats.norm.pdf(x1)
                plt.plot(x1, pdf, label='Unit Normal')

        if len(textlist) >= 2:
            textlist[1]['text'] = '{:.4g} - {:.4g} GeV Clusters'.format(xbin_left, xbin_right)
            pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

        if logscale:
            plt.yscale('log')

        # plt.title(title + ' {:.4g} - {:.4g} GeV'.format(xbin_left, xbin_right))
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.xlim(ylim)
        plt.legend()
        plt.show()

# %%
preds

# %%
np.exp(y_test)

# %%
import tensorflow_probability as tfp

# %%
def point_mask_fn(X, mask_val=0.):
    return Kb.cast(Kb.any(Kb.not_equal(X, mask_val), axis=-1), Kb.dtype(X))

def convert_to_tensor(X):
    return tf.concat([tfp.distributions.Distribution.mean(X), tfp.distributions.Distribution.stddev(X)],1)

def ParticleFlow_MDN(num_features, name="PFN_MDN_Network"):
    
    event_shape = [1]
    num_components = 3
    params_size = tfp.layers.MixtureNormal.params_size(num_components, event_shape)


    inputs = keras.Input(shape=(None, num_features), name='input')

    dense_0 = layers.Dense(100)
    t_dist_0 = layers.TimeDistributed(dense_0, name='t_dist_0')(inputs)
    activation_0 = layers.Activation('relu', name="activation_0")(t_dist_0)
    
    dense_1 = layers.Dense(100)
    t_dist_1 = layers.TimeDistributed(dense_1, name='t_dist_1')(activation_0)
    activation_1 = layers.Activation('relu', name='activation_1')(t_dist_1)
    
    dense_2 = layers.Dense(128)
    t_dist_2 = layers.TimeDistributed(dense_2, name='t_dist_2')(activation_1)
    activation_2 = layers.Activation('relu', name='activation_2')(t_dist_2)
    
    lambda_layer = layers.Lambda(point_mask_fn, output_shape=(None, None),
                                mask=None,
                                name='mask')(inputs)

    sum_layer = layers.Dot(axes=(1,1), name='sum')([lambda_layer, activation_2])
    
    dense_3 = layers.Dense(100, name='dense_0')(sum_layer)
    activation_3 = layers.Activation('relu', name="activation_3")(dense_3)
    
    dense_4 = layers.Dense(100, name='dense_1')(activation_3)
    activation_4 = layers.Activation('relu', name="activation_4")(dense_4)
    
    dense_5 = layers.Dense(100, name='dense_2')(activation_4)
    activation_5 = layers.Activation('relu', name="activation_5")(dense_5)
    
    dense_6 = layers.Dense(units=params_size, activation=lambda x: tf.clip_by_value(x, -30., 30.))(activation_5)

    
    mdn_0 = tfp.layers.MixtureNormal(num_components, event_shape, validate_args=True,
                                          convert_to_tensor_fn=convert_to_tensor)(dense_6)
    
    return keras.Model(inputs=inputs, outputs=mdn_0, name=name)

# %%
Kb.clear_session()

PFN_mdn = ParticleFlow_MDN(num_features=5)
PFN_mdn.compile(optimizer = netOpt, loss="mse")
PFN_mdn.summary()
# Out:
# Model: "PFN_MDN_Network"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 5)]    0
# __________________________________________________________________________________________________
# t_dist_0 (TimeDistributed)      (None, None, 100)    600         input[0][0]
# __________________________________________________________________________________________________
# activation_0 (Activation)       (None, None, 100)    0           t_dist_0[0][0]
# __________________________________________________________________________________________________
# t_dist_1 (TimeDistributed)      (None, None, 100)    10100       activation_0[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           t_dist_1[0][0]
# __________________________________________________________________________________________________
# t_dist_2 (TimeDistributed)      (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           t_dist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 9)            909         activation_5[0][0]
# __________________________________________________________________________________________________
# mixture_normal (MixtureNormal)  multiple             0           dense_3[0][0]
# ==================================================================================================
# Total params: 57,637
# Trainable params: 57,637
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(PFN_mdn, show_shapes=True, show_layer_names=True,)

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('PFN_MDN_regressor_weight_1.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=150, verbose=0, restore_best_weights=True)
t0 = t.time()
history_ct = PFN_mdn.fit(x_train, y_train,
        epochs=1000,
        batch_size=800,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=[chkpoint, earlystop])
t1 = t.time()
# Out:
# Epoch 1/1000
# 116/116 [==============================] - 12s 75ms/step - loss: 3.0769 - val_loss: 0.3696
#
# Epoch 00001: val_loss improved from inf to 0.36958, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 2/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.2674 - val_loss: 0.1393
#
# Epoch 00002: val_loss improved from 0.36958 to 0.13935, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 3/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.1913 - val_loss: 0.1353
#
# Epoch 00003: val_loss improved from 0.13935 to 0.13528, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 4/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0852 - val_loss: 0.0594
#
# Epoch 00004: val_loss improved from 0.13528 to 0.05941, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 5/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0577 - val_loss: 0.0466
#
# Epoch 00005: val_loss improved from 0.05941 to 0.04664, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 6/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0471 - val_loss: 0.0679
#
# Epoch 00006: val_loss did not improve from 0.04664
# Epoch 7/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0417 - val_loss: 0.0431
#
# Epoch 00007: val_loss improved from 0.04664 to 0.04310, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 8/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0473 - val_loss: 0.0485
#
# Epoch 00008: val_loss did not improve from 0.04310
# Epoch 9/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0390 - val_loss: 0.0718
#
# Epoch 00009: val_loss did not improve from 0.04310
# Epoch 10/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0400 - val_loss: 0.0484
#
# Epoch 00010: val_loss did not improve from 0.04310
# Epoch 11/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0426 - val_loss: 0.0649
#
# Epoch 00011: val_loss did not improve from 0.04310
# Epoch 12/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0341 - val_loss: 0.0317
#
# Epoch 00012: val_loss improved from 0.04310 to 0.03173, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 13/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0345 - val_loss: 0.0336
#
# Epoch 00013: val_loss did not improve from 0.03173
# Epoch 14/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0358 - val_loss: 0.0317
#
# Epoch 00014: val_loss did not improve from 0.03173
# Epoch 15/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0313 - val_loss: 0.0308
#
# Epoch 00015: val_loss improved from 0.03173 to 0.03085, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 16/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0325 - val_loss: 0.0301
#
# Epoch 00016: val_loss improved from 0.03085 to 0.03013, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 17/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0287 - val_loss: 0.0283
#
# Epoch 00017: val_loss improved from 0.03013 to 0.02827, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 18/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0434 - val_loss: 0.0292
#
# Epoch 00018: val_loss did not improve from 0.02827
# Epoch 19/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0292 - val_loss: 0.0272
#
# Epoch 00019: val_loss improved from 0.02827 to 0.02721, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 20/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0291 - val_loss: 0.0325
#
# Epoch 00020: val_loss did not improve from 0.02721
# Epoch 21/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0315 - val_loss: 0.0397
#
# Epoch 00021: val_loss did not improve from 0.02721
# Epoch 22/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0273 - val_loss: 0.0258
#
# Epoch 00022: val_loss improved from 0.02721 to 0.02579, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 23/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0272 - val_loss: 0.0278
#
# Epoch 00023: val_loss did not improve from 0.02579
# Epoch 24/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0303 - val_loss: 0.0273
#
# Epoch 00024: val_loss did not improve from 0.02579
# Epoch 25/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0262 - val_loss: 0.1348
#
# Epoch 00025: val_loss did not improve from 0.02579
# Epoch 26/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0324 - val_loss: 0.0239
#
# Epoch 00026: val_loss improved from 0.02579 to 0.02391, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 27/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0233 - val_loss: 0.0263
#
# Epoch 00027: val_loss did not improve from 0.02391
# Epoch 28/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0263 - val_loss: 0.0269
#
# Epoch 00028: val_loss did not improve from 0.02391
# Epoch 29/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0254 - val_loss: 0.0263
#
# Epoch 00029: val_loss did not improve from 0.02391
# Epoch 30/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0221 - val_loss: 0.0225
#
# Epoch 00030: val_loss improved from 0.02391 to 0.02253, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 31/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0266 - val_loss: 0.0247
#
# Epoch 00031: val_loss did not improve from 0.02253
# Epoch 32/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0241 - val_loss: 0.0244
#
# Epoch 00032: val_loss did not improve from 0.02253
# Epoch 33/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0236 - val_loss: 0.0219
#
# Epoch 00033: val_loss improved from 0.02253 to 0.02189, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 34/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0231 - val_loss: 0.0236
#
# Epoch 00034: val_loss did not improve from 0.02189
# Epoch 35/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0208 - val_loss: 0.0205
#
# Epoch 00035: val_loss improved from 0.02189 to 0.02052, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 36/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0208 - val_loss: 0.0562
#
# Epoch 00036: val_loss did not improve from 0.02052
# Epoch 37/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0252 - val_loss: 0.0255
#
# Epoch 00037: val_loss did not improve from 0.02052
# Epoch 38/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0199 - val_loss: 0.0194
#
# Epoch 00038: val_loss improved from 0.02052 to 0.01937, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 39/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0187 - val_loss: 0.0223
#
# Epoch 00039: val_loss did not improve from 0.01937
# Epoch 40/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0193 - val_loss: 0.0193
#
# Epoch 00040: val_loss improved from 0.01937 to 0.01930, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 41/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0177 - val_loss: 0.0191
#
# Epoch 00041: val_loss improved from 0.01930 to 0.01908, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 42/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0173 - val_loss: 0.0191
#
# Epoch 00042: val_loss did not improve from 0.01908
# Epoch 43/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0203 - val_loss: 0.0187
#
# Epoch 00043: val_loss improved from 0.01908 to 0.01867, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 44/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0176 - val_loss: 0.0208
#
# Epoch 00044: val_loss did not improve from 0.01867
# Epoch 45/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0169 - val_loss: 0.0184
#
# Epoch 00045: val_loss improved from 0.01867 to 0.01838, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 46/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0171 - val_loss: 0.0171
#
# Epoch 00046: val_loss improved from 0.01838 to 0.01706, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 47/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0169 - val_loss: 0.0217
#
# Epoch 00047: val_loss did not improve from 0.01706
# Epoch 48/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0181 - val_loss: 0.0203
#
# Epoch 00048: val_loss did not improve from 0.01706
# Epoch 49/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0168 - val_loss: 0.0169
#
# Epoch 00049: val_loss improved from 0.01706 to 0.01686, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 50/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0173 - val_loss: 0.0168
#
# Epoch 00050: val_loss improved from 0.01686 to 0.01684, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 51/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0170 - val_loss: 0.0197
#
# Epoch 00051: val_loss did not improve from 0.01684
# Epoch 52/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0157 - val_loss: 0.0183
#
# Epoch 00052: val_loss did not improve from 0.01684
# Epoch 53/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0149 - val_loss: 0.0169
#
# Epoch 00053: val_loss did not improve from 0.01684
# Epoch 54/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0156 - val_loss: 0.0196
#
# Epoch 00054: val_loss did not improve from 0.01684
# Epoch 55/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0153 - val_loss: 0.0179
#
# Epoch 00055: val_loss did not improve from 0.01684
# Epoch 56/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0141 - val_loss: 0.0184
#
# Epoch 00056: val_loss did not improve from 0.01684
# Epoch 57/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0154 - val_loss: 0.0222
#
# Epoch 00057: val_loss did not improve from 0.01684
# Epoch 58/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0148 - val_loss: 0.0159
#
# Epoch 00058: val_loss improved from 0.01684 to 0.01590, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 59/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0158 - val_loss: 0.0202
#
# Epoch 00059: val_loss did not improve from 0.01590
# Epoch 60/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0140 - val_loss: 0.0166
#
# Epoch 00060: val_loss did not improve from 0.01590
# Epoch 61/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0153 - val_loss: 0.0153
#
# Epoch 00061: val_loss improved from 0.01590 to 0.01532, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 62/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0141 - val_loss: 0.0180
#
# Epoch 00062: val_loss did not improve from 0.01532
# Epoch 63/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0151 - val_loss: 0.0139
#
# Epoch 00063: val_loss improved from 0.01532 to 0.01390, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 64/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0150 - val_loss: 0.0171
#
# Epoch 00064: val_loss did not improve from 0.01390
# Epoch 65/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0137 - val_loss: 0.0143
#
# Epoch 00065: val_loss did not improve from 0.01390
# Epoch 66/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0139 - val_loss: 0.0216
#
# Epoch 00066: val_loss did not improve from 0.01390
# Epoch 67/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0145 - val_loss: 0.0169
#
# Epoch 00067: val_loss did not improve from 0.01390
# Epoch 68/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0125 - val_loss: 0.0160
#
# Epoch 00068: val_loss did not improve from 0.01390
# Epoch 69/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0132 - val_loss: 0.0148
#
# Epoch 00069: val_loss did not improve from 0.01390
# Epoch 70/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0124 - val_loss: 0.0152
#
# Epoch 00070: val_loss did not improve from 0.01390
# Epoch 71/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0123 - val_loss: 0.0132
#
# Epoch 00071: val_loss improved from 0.01390 to 0.01318, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 72/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0134 - val_loss: 0.0199
#
# Epoch 00072: val_loss did not improve from 0.01318
# Epoch 73/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0121 - val_loss: 0.0140
#
# Epoch 00073: val_loss did not improve from 0.01318
# Epoch 74/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0132 - val_loss: 0.0134
#
# Epoch 00074: val_loss did not improve from 0.01318
# Epoch 75/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0124 - val_loss: 0.0178
#
# Epoch 00075: val_loss did not improve from 0.01318
# Epoch 76/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0119 - val_loss: 0.0154
#
# Epoch 00076: val_loss did not improve from 0.01318
# Epoch 77/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0120 - val_loss: 0.0150
#
# Epoch 00077: val_loss did not improve from 0.01318
# Epoch 78/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0114 - val_loss: 0.0126
#
# Epoch 00078: val_loss improved from 0.01318 to 0.01265, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 79/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0112 - val_loss: 0.0128
#
# Epoch 00079: val_loss did not improve from 0.01265
# Epoch 80/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0135 - val_loss: 0.0126
#
# Epoch 00080: val_loss improved from 0.01265 to 0.01259, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 81/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0116 - val_loss: 0.0115
#
# Epoch 00081: val_loss improved from 0.01259 to 0.01152, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 82/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0100 - val_loss: 0.0120
#
# Epoch 00082: val_loss did not improve from 0.01152
# Epoch 83/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0110 - val_loss: 0.0118
#
# Epoch 00083: val_loss did not improve from 0.01152
# Epoch 84/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0108 - val_loss: 0.0123
#
# Epoch 00084: val_loss did not improve from 0.01152
# Epoch 85/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0113 - val_loss: 0.0124
#
# Epoch 00085: val_loss did not improve from 0.01152
# Epoch 86/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0103 - val_loss: 0.0118
#
# Epoch 00086: val_loss did not improve from 0.01152
# Epoch 87/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0108 - val_loss: 0.0106
#
# Epoch 00087: val_loss improved from 0.01152 to 0.01055, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 88/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0105 - val_loss: 0.0108
#
# Epoch 00088: val_loss did not improve from 0.01055
# Epoch 89/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0106 - val_loss: 0.0105
#
# Epoch 00089: val_loss improved from 0.01055 to 0.01049, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 90/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0104 - val_loss: 0.0107
#
# Epoch 00090: val_loss did not improve from 0.01049
# Epoch 91/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0105 - val_loss: 0.0114
#
# Epoch 00091: val_loss did not improve from 0.01049
# Epoch 92/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0086 - val_loss: 0.0120
#
# Epoch 00092: val_loss did not improve from 0.01049
# Epoch 93/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0094 - val_loss: 0.0104
#
# Epoch 00093: val_loss improved from 0.01049 to 0.01036, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 94/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0087 - val_loss: 0.0115
#
# Epoch 00094: val_loss did not improve from 0.01036
# Epoch 95/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0098 - val_loss: 0.0103
#
# Epoch 00095: val_loss improved from 0.01036 to 0.01027, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 96/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0094 - val_loss: 0.0091
#
# Epoch 00096: val_loss improved from 0.01027 to 0.00906, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 97/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0085 - val_loss: 0.0105
#
# Epoch 00097: val_loss did not improve from 0.00906
# Epoch 98/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0089 - val_loss: 0.0160
#
# Epoch 00098: val_loss did not improve from 0.00906
# Epoch 99/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0098 - val_loss: 0.0150
#
# Epoch 00099: val_loss did not improve from 0.00906
# Epoch 100/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0096 - val_loss: 0.0108
#
# Epoch 00100: val_loss did not improve from 0.00906
# Epoch 101/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0084 - val_loss: 0.0118
#
# Epoch 00101: val_loss did not improve from 0.00906
# Epoch 102/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0099 - val_loss: 0.0105
#
# Epoch 00102: val_loss did not improve from 0.00906
# Epoch 103/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0089 - val_loss: 0.0092
#
# Epoch 00103: val_loss did not improve from 0.00906
# Epoch 104/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0074 - val_loss: 0.0097
#
# Epoch 00104: val_loss did not improve from 0.00906
# Epoch 105/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0079 - val_loss: 0.0114
#
# Epoch 00105: val_loss did not improve from 0.00906
# Epoch 106/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0082 - val_loss: 0.0122
#
# Epoch 00106: val_loss did not improve from 0.00906
# Epoch 107/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0086 - val_loss: 0.0093
#
# Epoch 00107: val_loss did not improve from 0.00906
# Epoch 108/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0078 - val_loss: 0.0090
#
# Epoch 00108: val_loss improved from 0.00906 to 0.00903, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 109/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0079
#
# Epoch 00109: val_loss improved from 0.00903 to 0.00790, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 110/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0100
#
# Epoch 00110: val_loss did not improve from 0.00790
# Epoch 111/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0074 - val_loss: 0.0107
#
# Epoch 00111: val_loss did not improve from 0.00790
# Epoch 112/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0076 - val_loss: 0.0102
#
# Epoch 00112: val_loss did not improve from 0.00790
# Epoch 113/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0077 - val_loss: 0.0097
#
# Epoch 00113: val_loss did not improve from 0.00790
# Epoch 114/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0074 - val_loss: 0.0085
#
# Epoch 00114: val_loss did not improve from 0.00790
# Epoch 115/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0091
#
# Epoch 00115: val_loss did not improve from 0.00790
# Epoch 116/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0093
#
# Epoch 00116: val_loss did not improve from 0.00790
# Epoch 117/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0070 - val_loss: 0.0093
#
# Epoch 00117: val_loss did not improve from 0.00790
# Epoch 118/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0091 - val_loss: 0.0116
#
# Epoch 00118: val_loss did not improve from 0.00790
# Epoch 119/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0095 - val_loss: 0.0085
#
# Epoch 00119: val_loss did not improve from 0.00790
# Epoch 120/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0077 - val_loss: 0.0083
#
# Epoch 00120: val_loss did not improve from 0.00790
# Epoch 121/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0086
#
# Epoch 00121: val_loss did not improve from 0.00790
# Epoch 122/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0067 - val_loss: 0.0101
#
# Epoch 00122: val_loss did not improve from 0.00790
# Epoch 123/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0069 - val_loss: 0.0083
#
# Epoch 00123: val_loss did not improve from 0.00790
# Epoch 124/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0073 - val_loss: 0.0088
#
# Epoch 00124: val_loss did not improve from 0.00790
# Epoch 125/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0070 - val_loss: 0.0082
#
# Epoch 00125: val_loss did not improve from 0.00790
# Epoch 126/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0083 - val_loss: 0.0080
#
# Epoch 00126: val_loss did not improve from 0.00790
# Epoch 127/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0067 - val_loss: 0.0083
#
# Epoch 00127: val_loss did not improve from 0.00790
# Epoch 128/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0062 - val_loss: 0.0083
#
# Epoch 00128: val_loss did not improve from 0.00790
# Epoch 129/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0080
#
# Epoch 00129: val_loss did not improve from 0.00790
# Epoch 130/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0072 - val_loss: 0.0092
#
# Epoch 00130: val_loss did not improve from 0.00790
# Epoch 131/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0083
#
# Epoch 00131: val_loss did not improve from 0.00790
# Epoch 132/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0066 - val_loss: 0.0074
#
# Epoch 00132: val_loss improved from 0.00790 to 0.00742, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 133/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0065 - val_loss: 0.0087
#
# Epoch 00133: val_loss did not improve from 0.00742
# Epoch 134/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0098 - val_loss: 0.0103
#
# Epoch 00134: val_loss did not improve from 0.00742
# Epoch 135/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0075 - val_loss: 0.0090
#
# Epoch 00135: val_loss did not improve from 0.00742
# Epoch 136/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0081 - val_loss: 0.0097
#
# Epoch 00136: val_loss did not improve from 0.00742
# Epoch 137/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0072 - val_loss: 0.0085
#
# Epoch 00137: val_loss did not improve from 0.00742
# Epoch 138/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0065 - val_loss: 0.0072
#
# Epoch 00138: val_loss improved from 0.00742 to 0.00723, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 139/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0082
#
# Epoch 00139: val_loss did not improve from 0.00723
# Epoch 140/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0068 - val_loss: 0.0081
#
# Epoch 00140: val_loss did not improve from 0.00723
# Epoch 141/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0066 - val_loss: 0.0127
#
# Epoch 00141: val_loss did not improve from 0.00723
# Epoch 142/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0068 - val_loss: 0.0083
#
# Epoch 00142: val_loss did not improve from 0.00723
# Epoch 143/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0062 - val_loss: 0.0082
#
# Epoch 00143: val_loss did not improve from 0.00723
# Epoch 144/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0069 - val_loss: 0.0086
#
# Epoch 00144: val_loss did not improve from 0.00723
# Epoch 145/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0060 - val_loss: 0.0077
#
# Epoch 00145: val_loss did not improve from 0.00723
# Epoch 146/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0073
#
# Epoch 00146: val_loss did not improve from 0.00723
# Epoch 147/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0068 - val_loss: 0.0075
#
# Epoch 00147: val_loss did not improve from 0.00723
# Epoch 148/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0081 - val_loss: 0.0088
#
# Epoch 00148: val_loss did not improve from 0.00723
# Epoch 149/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0075 - val_loss: 0.0079
#
# Epoch 00149: val_loss did not improve from 0.00723
# Epoch 150/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0064 - val_loss: 0.0079
#
# Epoch 00150: val_loss did not improve from 0.00723
# Epoch 151/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0079
#
# Epoch 00151: val_loss did not improve from 0.00723
# Epoch 152/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0082
#
# Epoch 00152: val_loss did not improve from 0.00723
# Epoch 153/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0074
#
# Epoch 00153: val_loss did not improve from 0.00723
# Epoch 154/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0071 - val_loss: 0.0092
#
# Epoch 00154: val_loss did not improve from 0.00723
# Epoch 155/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0076
#
# Epoch 00155: val_loss did not improve from 0.00723
# Epoch 156/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0080
#
# Epoch 00156: val_loss did not improve from 0.00723
# Epoch 157/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0064 - val_loss: 0.0072
#
# Epoch 00157: val_loss improved from 0.00723 to 0.00720, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 158/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0072
#
# Epoch 00158: val_loss did not improve from 0.00720
# Epoch 159/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0078
#
# Epoch 00159: val_loss did not improve from 0.00720
# Epoch 160/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0078
#
# Epoch 00160: val_loss did not improve from 0.00720
# Epoch 161/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0073
#
# Epoch 00161: val_loss did not improve from 0.00720
# Epoch 162/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0060 - val_loss: 0.0084
#
# Epoch 00162: val_loss did not improve from 0.00720
# Epoch 163/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0059 - val_loss: 0.0072
#
# Epoch 00163: val_loss improved from 0.00720 to 0.00716, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 164/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0060 - val_loss: 0.0075
#
# Epoch 00164: val_loss did not improve from 0.00716
# Epoch 165/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0074
#
# Epoch 00165: val_loss did not improve from 0.00716
# Epoch 166/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0068
#
# Epoch 00166: val_loss improved from 0.00716 to 0.00685, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 167/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0074
#
# Epoch 00167: val_loss did not improve from 0.00685
# Epoch 168/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0057 - val_loss: 0.0068
#
# Epoch 00168: val_loss improved from 0.00685 to 0.00683, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 169/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0105
#
# Epoch 00169: val_loss did not improve from 0.00683
# Epoch 170/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0106
#
# Epoch 00170: val_loss did not improve from 0.00683
# Epoch 171/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0079
#
# Epoch 00171: val_loss did not improve from 0.00683
# Epoch 172/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0077
#
# Epoch 00172: val_loss did not improve from 0.00683
# Epoch 173/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0061 - val_loss: 0.0087
#
# Epoch 00173: val_loss did not improve from 0.00683
# Epoch 174/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0072 - val_loss: 0.0096
#
# Epoch 00174: val_loss did not improve from 0.00683
# Epoch 175/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0070 - val_loss: 0.0087
#
# Epoch 00175: val_loss did not improve from 0.00683
# Epoch 176/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0097
#
# Epoch 00176: val_loss did not improve from 0.00683
# Epoch 177/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0068 - val_loss: 0.0078
#
# Epoch 00177: val_loss did not improve from 0.00683
# Epoch 178/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0066 - val_loss: 0.0085
#
# Epoch 00178: val_loss did not improve from 0.00683
# Epoch 179/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0060 - val_loss: 0.0117
#
# Epoch 00179: val_loss did not improve from 0.00683
# Epoch 180/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0058 - val_loss: 0.0073
#
# Epoch 00180: val_loss did not improve from 0.00683
# Epoch 181/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0063
#
# Epoch 00181: val_loss improved from 0.00683 to 0.00633, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 182/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0055 - val_loss: 0.0067
#
# Epoch 00182: val_loss did not improve from 0.00633
# Epoch 183/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0075
#
# Epoch 00183: val_loss did not improve from 0.00633
# Epoch 184/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0055 - val_loss: 0.0071
#
# Epoch 00184: val_loss did not improve from 0.00633
# Epoch 185/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0071
#
# Epoch 00185: val_loss did not improve from 0.00633
# Epoch 186/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0073
#
# Epoch 00186: val_loss did not improve from 0.00633
# Epoch 187/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0069
#
# Epoch 00187: val_loss did not improve from 0.00633
# Epoch 188/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0076
#
# Epoch 00188: val_loss did not improve from 0.00633
# Epoch 189/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0075
#
# Epoch 00189: val_loss did not improve from 0.00633
# Epoch 190/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0080
#
# Epoch 00190: val_loss did not improve from 0.00633
# Epoch 191/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0079
#
# Epoch 00191: val_loss did not improve from 0.00633
# Epoch 192/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0069
#
# Epoch 00192: val_loss did not improve from 0.00633
# Epoch 193/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0070
#
# Epoch 00193: val_loss did not improve from 0.00633
# Epoch 194/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0067
#
# Epoch 00194: val_loss did not improve from 0.00633
# Epoch 195/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0077
#
# Epoch 00195: val_loss did not improve from 0.00633
# Epoch 196/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0076
#
# Epoch 00196: val_loss did not improve from 0.00633
# Epoch 197/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0073
#
# Epoch 00197: val_loss did not improve from 0.00633
# Epoch 198/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0079
#
# Epoch 00198: val_loss did not improve from 0.00633
# Epoch 199/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0066
#
# Epoch 00199: val_loss did not improve from 0.00633
# Epoch 200/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0073
#
# Epoch 00200: val_loss did not improve from 0.00633
# Epoch 201/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0061
#
# Epoch 00201: val_loss improved from 0.00633 to 0.00614, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 202/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0052 - val_loss: 0.0070
#
# Epoch 00202: val_loss did not improve from 0.00614
# Epoch 203/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0057 - val_loss: 0.0066
#
# Epoch 00203: val_loss did not improve from 0.00614
# Epoch 204/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0072
#
# Epoch 00204: val_loss did not improve from 0.00614
# Epoch 205/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0055 - val_loss: 0.0074
#
# Epoch 00205: val_loss did not improve from 0.00614
# Epoch 206/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0062
#
# Epoch 00206: val_loss did not improve from 0.00614
# Epoch 207/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0065
#
# Epoch 00207: val_loss did not improve from 0.00614
# Epoch 208/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0073 - val_loss: 0.0076
#
# Epoch 00208: val_loss did not improve from 0.00614
# Epoch 209/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0084 - val_loss: 0.0111
#
# Epoch 00209: val_loss did not improve from 0.00614
# Epoch 210/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0069 - val_loss: 0.0072
#
# Epoch 00210: val_loss did not improve from 0.00614
# Epoch 211/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0059 - val_loss: 0.0081
#
# Epoch 00211: val_loss did not improve from 0.00614
# Epoch 212/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0082
#
# Epoch 00212: val_loss did not improve from 0.00614
# Epoch 213/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0069
#
# Epoch 00213: val_loss did not improve from 0.00614
# Epoch 214/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0056 - val_loss: 0.0062
#
# Epoch 00214: val_loss did not improve from 0.00614
# Epoch 215/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0050 - val_loss: 0.0073
#
# Epoch 00215: val_loss did not improve from 0.00614
# Epoch 216/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0076
#
# Epoch 00216: val_loss did not improve from 0.00614
# Epoch 217/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0066
#
# Epoch 00217: val_loss did not improve from 0.00614
# Epoch 218/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0075
#
# Epoch 00218: val_loss did not improve from 0.00614
# Epoch 219/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0067
#
# Epoch 00219: val_loss did not improve from 0.00614
# Epoch 220/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0066
#
# Epoch 00220: val_loss did not improve from 0.00614
# Epoch 221/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0050 - val_loss: 0.0070
#
# Epoch 00221: val_loss did not improve from 0.00614
# Epoch 222/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0075
#
# Epoch 00222: val_loss did not improve from 0.00614
# Epoch 223/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0066
#
# Epoch 00223: val_loss did not improve from 0.00614
# Epoch 224/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0056 - val_loss: 0.0066
#
# Epoch 00224: val_loss did not improve from 0.00614
# Epoch 225/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0088
#
# Epoch 00225: val_loss did not improve from 0.00614
# Epoch 226/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0067
#
# Epoch 00226: val_loss did not improve from 0.00614
# Epoch 227/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0061
#
# Epoch 00227: val_loss improved from 0.00614 to 0.00610, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 228/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0087
#
# Epoch 00228: val_loss did not improve from 0.00610
# Epoch 229/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00229: val_loss did not improve from 0.00610
# Epoch 230/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0071
#
# Epoch 00230: val_loss did not improve from 0.00610
# Epoch 231/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00231: val_loss did not improve from 0.00610
# Epoch 232/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0060
#
# Epoch 00232: val_loss improved from 0.00610 to 0.00597, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 233/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0076
#
# Epoch 00233: val_loss did not improve from 0.00597
# Epoch 234/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0057
#
# Epoch 00234: val_loss improved from 0.00597 to 0.00570, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 235/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0064
#
# Epoch 00235: val_loss did not improve from 0.00570
# Epoch 236/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0063
#
# Epoch 00236: val_loss did not improve from 0.00570
# Epoch 237/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0059
#
# Epoch 00237: val_loss did not improve from 0.00570
# Epoch 238/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00238: val_loss did not improve from 0.00570
# Epoch 239/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0077
#
# Epoch 00239: val_loss did not improve from 0.00570
# Epoch 240/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0057 - val_loss: 0.0072
#
# Epoch 00240: val_loss did not improve from 0.00570
# Epoch 241/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0050 - val_loss: 0.0069
#
# Epoch 00241: val_loss did not improve from 0.00570
# Epoch 242/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0071
#
# Epoch 00242: val_loss did not improve from 0.00570
# Epoch 243/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0052 - val_loss: 0.0065
#
# Epoch 00243: val_loss did not improve from 0.00570
# Epoch 244/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0073
#
# Epoch 00244: val_loss did not improve from 0.00570
# Epoch 245/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0049 - val_loss: 0.0076
#
# Epoch 00245: val_loss did not improve from 0.00570
# Epoch 246/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0067
#
# Epoch 00246: val_loss did not improve from 0.00570
# Epoch 247/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00247: val_loss did not improve from 0.00570
# Epoch 248/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0073
#
# Epoch 00248: val_loss did not improve from 0.00570
# Epoch 249/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0069
#
# Epoch 00249: val_loss did not improve from 0.00570
# Epoch 250/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0046 - val_loss: 0.0066
#
# Epoch 00250: val_loss did not improve from 0.00570
# Epoch 251/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0047 - val_loss: 0.0070
#
# Epoch 00251: val_loss did not improve from 0.00570
# Epoch 252/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0046 - val_loss: 0.0065
#
# Epoch 00252: val_loss did not improve from 0.00570
# Epoch 253/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0094
#
# Epoch 00253: val_loss did not improve from 0.00570
# Epoch 254/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0073
#
# Epoch 00254: val_loss did not improve from 0.00570
# Epoch 255/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00255: val_loss did not improve from 0.00570
# Epoch 256/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0053 - val_loss: 0.0058
#
# Epoch 00256: val_loss did not improve from 0.00570
# Epoch 257/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0049 - val_loss: 0.0077
#
# Epoch 00257: val_loss did not improve from 0.00570
# Epoch 258/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0060
#
# Epoch 00258: val_loss did not improve from 0.00570
# Epoch 259/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0057
#
# Epoch 00259: val_loss did not improve from 0.00570
# Epoch 260/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0048 - val_loss: 0.0058
#
# Epoch 00260: val_loss did not improve from 0.00570
# Epoch 261/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0074
#
# Epoch 00261: val_loss did not improve from 0.00570
# Epoch 262/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0052 - val_loss: 0.0080
#
# Epoch 00262: val_loss did not improve from 0.00570
# Epoch 263/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00263: val_loss did not improve from 0.00570
# Epoch 264/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0047 - val_loss: 0.0069
#
# Epoch 00264: val_loss did not improve from 0.00570
# Epoch 265/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0083
#
# Epoch 00265: val_loss did not improve from 0.00570
# Epoch 266/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0065
#
# Epoch 00266: val_loss did not improve from 0.00570
# Epoch 267/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0068
#
# Epoch 00267: val_loss did not improve from 0.00570
# Epoch 268/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0074
#
# Epoch 00268: val_loss did not improve from 0.00570
# Epoch 269/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0062
#
# Epoch 00269: val_loss did not improve from 0.00570
# Epoch 270/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0079
#
# Epoch 00270: val_loss did not improve from 0.00570
# Epoch 271/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0096
#
# Epoch 00271: val_loss did not improve from 0.00570
# Epoch 272/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0057 - val_loss: 0.0083
#
# Epoch 00272: val_loss did not improve from 0.00570
# Epoch 273/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0043 - val_loss: 0.0066
#
# Epoch 00273: val_loss did not improve from 0.00570
# Epoch 274/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0044 - val_loss: 0.0078
#
# Epoch 00274: val_loss did not improve from 0.00570
# Epoch 275/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0068
#
# Epoch 00275: val_loss did not improve from 0.00570
# Epoch 276/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0045 - val_loss: 0.0067
#
# Epoch 00276: val_loss did not improve from 0.00570
# Epoch 277/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0043 - val_loss: 0.0071
#
# Epoch 00277: val_loss did not improve from 0.00570
# Epoch 278/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0045 - val_loss: 0.0067
#
# Epoch 00278: val_loss did not improve from 0.00570
# Epoch 279/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0041 - val_loss: 0.0083
#
# Epoch 00279: val_loss did not improve from 0.00570
# Epoch 280/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0044 - val_loss: 0.0088
#
# Epoch 00280: val_loss did not improve from 0.00570
# Epoch 281/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0038 - val_loss: 0.0066
#
# Epoch 00281: val_loss did not improve from 0.00570
# Epoch 282/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0077
#
# Epoch 00282: val_loss did not improve from 0.00570
# Epoch 283/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0041 - val_loss: 0.0076
#
# Epoch 00283: val_loss did not improve from 0.00570
# Epoch 284/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0084
#
# Epoch 00284: val_loss did not improve from 0.00570
# Epoch 285/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0074
#
# Epoch 00285: val_loss did not improve from 0.00570
# Epoch 286/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0121
#
# Epoch 00286: val_loss did not improve from 0.00570
# Epoch 287/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0069
#
# Epoch 00287: val_loss did not improve from 0.00570
# Epoch 288/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0044 - val_loss: 0.0068
#
# Epoch 00288: val_loss did not improve from 0.00570
# Epoch 289/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0066
#
# Epoch 00289: val_loss did not improve from 0.00570
# Epoch 290/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0042 - val_loss: 0.0078
#
# Epoch 00290: val_loss did not improve from 0.00570
# Epoch 291/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0039 - val_loss: 0.0067
#
# Epoch 00291: val_loss did not improve from 0.00570
# Epoch 292/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0035 - val_loss: 0.0060
#
# Epoch 00292: val_loss did not improve from 0.00570
# Epoch 293/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0035 - val_loss: 0.0073
#
# Epoch 00293: val_loss did not improve from 0.00570
# Epoch 294/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0072
#
# Epoch 00294: val_loss did not improve from 0.00570
# Epoch 295/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0069
#
# Epoch 00295: val_loss did not improve from 0.00570
# Epoch 296/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0035 - val_loss: 0.0077
#
# Epoch 00296: val_loss did not improve from 0.00570
# Epoch 297/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0040 - val_loss: 0.0070
#
# Epoch 00297: val_loss did not improve from 0.00570
# Epoch 298/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0036 - val_loss: 0.0077
#
# Epoch 00298: val_loss did not improve from 0.00570
# Epoch 299/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0033 - val_loss: 0.0064
#
# Epoch 00299: val_loss did not improve from 0.00570
# Epoch 300/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0035 - val_loss: 0.0066
#
# Epoch 00300: val_loss did not improve from 0.00570
# Epoch 301/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0034 - val_loss: 0.0071
#
# Epoch 00301: val_loss did not improve from 0.00570
# Epoch 302/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0143
#
# Epoch 00302: val_loss did not improve from 0.00570
# Epoch 303/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0079 - val_loss: 0.0109
#
# Epoch 00303: val_loss did not improve from 0.00570
# Epoch 304/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0084 - val_loss: 0.0092
#
# Epoch 00304: val_loss did not improve from 0.00570
# Epoch 305/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0080
#
# Epoch 00305: val_loss did not improve from 0.00570
# Epoch 306/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0065 - val_loss: 0.0077
#
# Epoch 00306: val_loss did not improve from 0.00570
# Epoch 307/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0085
#
# Epoch 00307: val_loss did not improve from 0.00570
# Epoch 308/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0072
#
# Epoch 00308: val_loss did not improve from 0.00570
# Epoch 309/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0057 - val_loss: 0.0069
#
# Epoch 00309: val_loss did not improve from 0.00570
# Epoch 310/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0048 - val_loss: 0.0074
#
# Epoch 00310: val_loss did not improve from 0.00570
# Epoch 311/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0050 - val_loss: 0.0071
#
# Epoch 00311: val_loss did not improve from 0.00570
# Epoch 312/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0051 - val_loss: 0.0066
#
# Epoch 00312: val_loss did not improve from 0.00570
# Epoch 313/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0038 - val_loss: 0.0081
#
# Epoch 00313: val_loss did not improve from 0.00570
# Epoch 314/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0039 - val_loss: 0.0062
#
# Epoch 00314: val_loss did not improve from 0.00570
# Epoch 315/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0062
#
# Epoch 00315: val_loss did not improve from 0.00570
# Epoch 316/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0034 - val_loss: 0.0067
#
# Epoch 00316: val_loss did not improve from 0.00570
# Epoch 317/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0057
#
# Epoch 00317: val_loss did not improve from 0.00570
# Epoch 318/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00318: val_loss did not improve from 0.00570
# Epoch 319/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0058
#
# Epoch 00319: val_loss did not improve from 0.00570
# Epoch 320/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0035 - val_loss: 0.0062
#
# Epoch 00320: val_loss did not improve from 0.00570
# Epoch 321/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00321: val_loss did not improve from 0.00570
# Epoch 322/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0065 - val_loss: 0.0083
#
# Epoch 00322: val_loss did not improve from 0.00570
# Epoch 323/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0050 - val_loss: 0.0069
#
# Epoch 00323: val_loss did not improve from 0.00570
# Epoch 324/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0046 - val_loss: 0.0068
#
# Epoch 00324: val_loss did not improve from 0.00570
# Epoch 325/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00325: val_loss did not improve from 0.00570
# Epoch 326/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0038 - val_loss: 0.0063
#
# Epoch 00326: val_loss did not improve from 0.00570
# Epoch 327/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0036 - val_loss: 0.0061
#
# Epoch 00327: val_loss did not improve from 0.00570
# Epoch 328/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00328: val_loss did not improve from 0.00570
# Epoch 329/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00329: val_loss did not improve from 0.00570
# Epoch 330/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0064
#
# Epoch 00330: val_loss did not improve from 0.00570
# Epoch 331/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0067
#
# Epoch 00331: val_loss did not improve from 0.00570
# Epoch 332/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00332: val_loss did not improve from 0.00570
# Epoch 333/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0066
#
# Epoch 00333: val_loss did not improve from 0.00570
# Epoch 334/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0065
#
# Epoch 00334: val_loss did not improve from 0.00570
# Epoch 335/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00335: val_loss did not improve from 0.00570
# Epoch 336/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00336: val_loss did not improve from 0.00570
# Epoch 337/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0074
#
# Epoch 00337: val_loss did not improve from 0.00570
# Epoch 338/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00338: val_loss did not improve from 0.00570
# Epoch 339/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0038 - val_loss: 0.0083
#
# Epoch 00339: val_loss did not improve from 0.00570
# Epoch 340/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00340: val_loss did not improve from 0.00570
# Epoch 341/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0040 - val_loss: 0.0078
#
# Epoch 00341: val_loss did not improve from 0.00570
# Epoch 342/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0042 - val_loss: 0.0069
#
# Epoch 00342: val_loss did not improve from 0.00570
# Epoch 343/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0036 - val_loss: 0.0066
#
# Epoch 00343: val_loss did not improve from 0.00570
# Epoch 344/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0038 - val_loss: 0.0086
#
# Epoch 00344: val_loss did not improve from 0.00570
# Epoch 345/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0061
#
# Epoch 00345: val_loss did not improve from 0.00570
# Epoch 346/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00346: val_loss did not improve from 0.00570
# Epoch 347/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00347: val_loss did not improve from 0.00570
# Epoch 348/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00348: val_loss did not improve from 0.00570
# Epoch 349/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0040 - val_loss: 0.0078
#
# Epoch 00349: val_loss did not improve from 0.00570
# Epoch 350/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0049 - val_loss: 0.0076
#
# Epoch 00350: val_loss did not improve from 0.00570
# Epoch 351/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0055 - val_loss: 0.0081
#
# Epoch 00351: val_loss did not improve from 0.00570
# Epoch 352/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0042 - val_loss: 0.0063
#
# Epoch 00352: val_loss did not improve from 0.00570
# Epoch 353/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0061
#
# Epoch 00353: val_loss did not improve from 0.00570
# Epoch 354/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00354: val_loss did not improve from 0.00570
# Epoch 355/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00355: val_loss did not improve from 0.00570
# Epoch 356/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0030 - val_loss: 0.0070
#
# Epoch 00356: val_loss did not improve from 0.00570
# Epoch 357/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0060
#
# Epoch 00357: val_loss did not improve from 0.00570
# Epoch 358/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0075
#
# Epoch 00358: val_loss did not improve from 0.00570
# Epoch 359/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0067
#
# Epoch 00359: val_loss did not improve from 0.00570
# Epoch 360/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0031 - val_loss: 0.0066
#
# Epoch 00360: val_loss did not improve from 0.00570
# Epoch 361/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0068
#
# Epoch 00361: val_loss did not improve from 0.00570
# Epoch 362/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00362: val_loss did not improve from 0.00570
# Epoch 363/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0075
#
# Epoch 00363: val_loss did not improve from 0.00570
# Epoch 364/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0086
#
# Epoch 00364: val_loss did not improve from 0.00570
# Epoch 365/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00365: val_loss did not improve from 0.00570
# Epoch 366/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0031 - val_loss: 0.0063
#
# Epoch 00366: val_loss did not improve from 0.00570
# Epoch 367/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00367: val_loss did not improve from 0.00570
# Epoch 368/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0070
#
# Epoch 00368: val_loss did not improve from 0.00570
# Epoch 369/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0029 - val_loss: 0.0075
#
# Epoch 00369: val_loss did not improve from 0.00570
# Epoch 370/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0064
#
# Epoch 00370: val_loss did not improve from 0.00570
# Epoch 371/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0070
#
# Epoch 00371: val_loss did not improve from 0.00570
# Epoch 372/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0030 - val_loss: 0.0063
#
# Epoch 00372: val_loss did not improve from 0.00570
# Epoch 373/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0033 - val_loss: 0.0085
#
# Epoch 00373: val_loss did not improve from 0.00570
# Epoch 374/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0113
#
# Epoch 00374: val_loss did not improve from 0.00570
# Epoch 375/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0069 - val_loss: 0.0087
#
# Epoch 00375: val_loss did not improve from 0.00570
# Epoch 376/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0061 - val_loss: 0.0072
#
# Epoch 00376: val_loss did not improve from 0.00570
# Epoch 377/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0052 - val_loss: 0.0079
#
# Epoch 00377: val_loss did not improve from 0.00570
# Epoch 378/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0041 - val_loss: 0.0071
#
# Epoch 00378: val_loss did not improve from 0.00570
# Epoch 379/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0034 - val_loss: 0.0067
#
# Epoch 00379: val_loss did not improve from 0.00570
# Epoch 380/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0030 - val_loss: 0.0071
#
# Epoch 00380: val_loss did not improve from 0.00570
# Epoch 381/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0032 - val_loss: 0.0072
#
# Epoch 00381: val_loss did not improve from 0.00570
# Epoch 382/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0033 - val_loss: 0.0083
#
# Epoch 00382: val_loss did not improve from 0.00570
# Epoch 383/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0031 - val_loss: 0.0074
#
# Epoch 00383: val_loss did not improve from 0.00570
# Epoch 384/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0031 - val_loss: 0.0074
#
# Epoch 00384: val_loss did not improve from 0.00570

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(history_ct.history['val_loss'], label="Validation")
plt.plot(history_ct.history['loss'], label="Training")
plt.yscale('log')
plt.ylim(.001,10)
plt.yticks(fontsize=13)
plt.xlim(0,500)
plt.xticks(fontsize=13)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right', ncol=1)
plt.text(500, 1.5, 'LR=1e-3', fontsize=13)
plt.text(500, 1, 'Batch: 384', fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_lossCurves_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
PFN_mdn.load_weights("PFN_MDN_regressor_weight_1.h5")

# %%
preds = np.exp(PFN_mdn.predict(eval_generator(x_test,500)))
print(preds.shape)
# Out:
# (18538, 2)

# %%
## PREDICTIONS AND TRUTH ##
bins = np.linspace(0,10,50, endpoint=True)
fig = plt.figure(figsize=(6,6))
plt.hist(np.exp(y_test), color='steelblue', bins=bins, density=True, alpha=.5, edgecolor='black', label='target')
plt.hist(preds[:,0], color='coral', bins=bins, density=True, alpha=.5, edgecolor='black', label='network')
plt.title('Regression Output and Target', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(0,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(loc='upper left')
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_targetPreds_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
xcenter, medDNN = ru.responsePlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                 atlas_x = 0.46, atlas_y = 0.95, simulation = True,
                 textlist = [{'x': 0.46, 'y': 0.85, 'text': 'Single $\pi^{+}$, Track+Clusters'},
                             {'x': 0.46, 'y': 0.8,  'text': 'keras_pfn_mdn'}])

# %%
xcenter, iqrMDN3 = resolutionPlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                        atlas_x = 0.56, atlas_y = 0.95, simulation = True,
                        textlist = [{'x': 0.56, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
                                    {'x': 0.56, 'y': 0.8,  'text': 'PFN'}])

# %%
resp_plot = ru.resolutionPlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                    figfile='',
                    statistic='std', xlabel='Particle Truth Energy', ylabel='Energy IQR over Median',
                    atlas_x=-1, atlas_y=-1, simulation=False,
                    textlist=[])

# %%
resid_DNN = preds[:,0] - np.exp(y_test)

n_bins = 500
plt.cla(); plt.clf()
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.hist(resid_DNN,bins = n_bins,alpha=0.75)
plt.yscale('log')
plt.xlabel('Learned - True Energy')
plt.ylabel('Clusters')
plt.xlim(-3000,3000)
plt.legend()

atlas_x = 0.55
atlas_y = 0.95
simulation = True
textlist = [{'x': 0.55, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
            {'x': 0.55, 'y': 0.8,  'text': 'keras_pfn'}]
pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

plt.show()
