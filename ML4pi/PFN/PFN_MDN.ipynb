# %% [markdown]
# # Keras PFN and PFN with mdn layer

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib.colors import LogNorm
import time as t
from time import perf_counter as cput
import scipy.constants as spc
import matplotlib.ticker as ticker

# %%
path_prefix = 'D:/Work/EPE/ML4pi/'
plotpath = path_prefix+'plots/'
modelpath_c = path_prefix+''
modelpath = path_prefix+''
ext_path = "H:/EPE_file_storage/"
ext_modelpath = ext_path + "Model/"
ext_datapath = ext_path + "data_storage/STMC/"
ext_plotpath = ext_path + "plots/"

# %%
def tvt_num(_data, _tvt=(75, 10, 15)):
    ''' Function designed to output appropriate numbers for traning validation and testing given
    a variable length input. TVT expressed as ratios and do not need to add to 100. '''
    _tot = len(_data)
    _train, _val, _test = _tvt
    _tvt_sum = _train + _val + _test
    
    _train_rtrn = round(_train*_tot/_tvt_sum)
    _val_rtrn = round(_val*_tot/_tvt_sum)
    _test_rtrn = _tot - _train_rtrn - _val_rtrn
    
    return _train_rtrn, _val_rtrn, _test_rtrn

def normalize_input1d(arr, mask):
    ''' Note that non masked values are left alone i.e. zeros if mask = arr != 0'''
    len_arr = arr.shape[0]
    mean = np.repeat(np.mean(arr, where=mask), len_arr)
    std_dev = np.repeat(np.std(arr, where=mask), len_arr)
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev!=0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

def normalize_input2d(arr, mask):
    ''' Truth value is where to perform the operation, exclude False vals.
    returns: Array with the shape of arr with normalization carried out with mask '''
    len_ax1 = arr.shape[1]
    mean = np.tile(np.mean(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    std_dev = np.tile(np.std(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev != 0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

# %%
import sys
sys.path.append(path_prefix)
from util import resolution_util as ru
from util import plot_util as pu
from util import ml_util as mu
import uproot3 as ur
import os
import shutil

# %%
# load STMC numpy file

Nfile = 5
fileNames = []
for i in range(1,Nfile+1):
    fileNames.append(ext_datapath + 'STMC_' + str(i) + '.npz')

X = []
Y = []
for fname in fileNames:
    file = np.load(fname)
    file_X = file.f.x
    file_Y = file.f.y
    X.append(file_X)
    Y.append(file_Y)
Xraw = np.concatenate(X,axis=0)
Yraw = np.concatenate(Y,axis=0)

# %%
X = np.lib.format.open_memmap(ext_datapath + "stmc_X_3f_2.npy",
                             mode='w+', dtype=np.float64, shape=(Xraw.shape[0], Xraw.shape[1], 5))
np.copyto(dst=X, src=Xraw[:,:,:5], casting='same_kind', where=True)

Y = np.lib.format.open_memmap(ext_datapath + "stmc_Y_3f_2.npy",
                             mode='w+', dtype=np.float64, shape=(Yraw.shape[0]))
np.copyto(dst=Y, src=Yraw[:,0], casting='same_kind', where=True)

print(X.shape)
print(Y.shape)
# Out:
# (205980, 1086, 5)
# (205980,)

# %%
# for PFN approach Y normalization
# the target energy values
# target_zero_mask, Y : 0 for truthPartE, 1 for truthTrackPt, 2 for cluster_eng_clib_tot
target_zero_mask = Y > .05
Ylog = np.log(Y[target_zero_mask])
print('Any targets below 50 GeV: '+str(np.count_nonzero(np.invert(target_zero_mask))))
print('Number of events: '+str(len(Y)))
# Out:
# Any targets below 50 GeV: 0
# Number of events: 205980

# %%
t0 = t.time()
## Normalize rPerp to 1/3630
rPerp_mask = X[:,:,3] != 0
X[:,:,3][rPerp_mask] = X[:,:,3][rPerp_mask]/3630.

isnan = np.isnan(X[:,:,0])
anytruth = np.any(isnan)
print(anytruth)

## Energy Values that are not zero!
E_nonZeroMask = X[:,:,0] != 0
X[:,:,0][E_nonZeroMask] = np.log(X[:,:,0][E_nonZeroMask])
cellE_mean = np.mean(X[:,:,0][E_nonZeroMask])
cellE_std = np.std(X[:,:,0][E_nonZeroMask])
X[:,:,0][E_nonZeroMask] = (X[:,:,0][E_nonZeroMask] - cellE_mean)/cellE_std

## Eta and Phi
# do nothing for now as a control and check performance
eta_mask = X[:,:,1] != 0
X[:,:,1][eta_mask] = X[:,:,1][eta_mask]/.7

phi_mask = X[:,:,2] != 0
cellPhi_std = np.std(X[:,:,2][phi_mask])
X[:,:,2][phi_mask] = X[:,:,2][phi_mask]/cellPhi_std
t1 = t.time()
print('Time to Normalize: '+str(t1-t0)+' (s)')
# Out:
# False
# Time to Normalize: 11.249077081680298 (s)

# %%
############
## ENERGY ##
############
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
ebins = np.linspace(-6,7, 50, endpoint=True)
plt.hist(X[:,:,0][E_nonZeroMask], color='plum', bins=ebins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Energy Inputs', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(np.min(ebins),np.max(ebins))
plt.ylim(0,.55)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_E_2021-07-26.png', format='png')
plt.show()

#########
## ETA ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
etabins = np.linspace(-1.1,1.1,50, endpoint=True)
plt.hist(X[:,:,1][eta_mask], color='chocolate', bins=etabins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Eta Inputs', fontsize=16)
plt.xlabel('Eta', fontsize=14)
plt.xlim(np.min(etabins),np.max(etabins))
plt.ylim(0,4.5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_Eta_2021-07-26.png', format='png')
plt.show()

#########
## PHI ##
#########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
phibins = np.linspace(-np.pi/4,np.pi/4,50, endpoint=True)
plt.hist(X[:,:,2][phi_mask], color='olive', bins=phibins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell Phi Inputs Flattened', fontsize=16)
plt.xlabel('Phi', fontsize=14)
plt.xlim(np.min(phibins),np.max(phibins))
plt.ylim(0,5)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_Phi_2021-07-26.png', format='png')
plt.show()

###########
## RPERP ##
###########
plt.cla(); plt.clf()
fig = plt.figure(figsize=(6,6))
Rbins = np.linspace(-0,1.2,50, endpoint=True)
plt.hist(X[:,:,3][rPerp_mask], color='gold', bins=Rbins, density=True, alpha=.5, edgecolor='black')
plt.title('Cluster Cell rPerp Inputs Flattened', fontsize=16)
plt.xlabel('rPerp', fontsize=14)
plt.xlim(np.min(Rbins),np.max(Rbins))
plt.ylim(0,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.tight_layout()
# plt.savefig('Regression_Plots/July/X_STMC_rPerp_2021-07-26.png', format='png')
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import Sequential
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.models import load_model
import keras.backend as Kb

# %%
import energyflow as ef
from energyflow.archs import PFN

# %% [markdown]
# # Models

# %%
# EFN regression example uses 75/10/15 split for 100,000 samples
train, val, test = tvt_num(X, _tvt=(85, 5, 10))
print('train -- val -- test')
print(str(train)+' -- '+str(val)+' -- '+str(test))

# network architecture parameters
Phi_sizes, F_sizes = (100, 100, 128), (100, 100, 100)
output_act, output_dim = 'linear', 1
loss = 'mse'

# network training parameters
num_epoch = 1500
batch_size = 1000

netOpt = tf.keras.optimizers.Adam(learning_rate=0.001)
RMS_prop = tf.keras.optimizers.RMSprop(learning_rate=0.001)
# Out:
# train -- val -- test
# 175083 -- 10299 -- 20598

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, Y))
(x_train, x_val, x_test,
 y_train, y_val, y_test) = ef.utils.data_split(X, Ylog, val=val, test=test)

# Print out tensor shapes
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (175083, 1086, 5)
# (175083,)

# %%
# luanch wandb init()
Kb.clear_session()

pfn = PFN(input_dim=5, Phi_sizes=Phi_sizes, F_sizes=F_sizes, 
          output_act=output_act, output_dim=output_dim, loss=loss,
          optimizer=netOpt, metrics=[])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 5)]    0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 100)    600         input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, 100)    0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 100)    10100       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           tdist_1[0][0]
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            101         activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1)            0           output[0][0]
# ==================================================================================================
# Total params: 56,829
# Trainable params: 56,829
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('pfn_regressor_5f.h5', monitor='val_loss', verbose=1, save_best_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=150, verbose=0, restore_best_weights=True)
t0 = t.time()
history_ct = pfn.fit(x_train, y_train,
        epochs=1000,
        batch_size=800,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=[chkpoint, earlystop])
t1 = t.time()
# Out:
# Epoch 1/1000
# 219/219 [==============================] - 19s 68ms/step - loss: 79.6805 - val_loss: 2.2216
#
# Epoch 00001: val_loss improved from inf to 2.22165, saving model to pfn_regressor_5f.h5
# Epoch 2/1000
# 219/219 [==============================] - 13s 57ms/step - loss: 1.7325 - val_loss: 1.2628
#
# Epoch 00002: val_loss improved from 2.22165 to 1.26281, saving model to pfn_regressor_5f.h5
# Epoch 3/1000
# 219/219 [==============================] - 11s 52ms/step - loss: 1.2966 - val_loss: 1.3152
#
# Epoch 00003: val_loss did not improve from 1.26281
# Epoch 4/1000
# 219/219 [==============================] - 11s 52ms/step - loss: 1.2136 - val_loss: 1.5848
#
# Epoch 00004: val_loss did not improve from 1.26281
# Epoch 5/1000
# 219/219 [==============================] - 12s 54ms/step - loss: 1.1327 - val_loss: 0.7638
#
# Epoch 00005: val_loss improved from 1.26281 to 0.76379, saving model to pfn_regressor_5f.h5
# Epoch 6/1000
# 219/219 [==============================] - 12s 55ms/step - loss: 0.9435 - val_loss: 2.2451
#
# Epoch 00006: val_loss did not improve from 0.76379
# Epoch 7/1000
# 219/219 [==============================] - 12s 56ms/step - loss: 0.7859 - val_loss: 0.6665
#
# Epoch 00007: val_loss improved from 0.76379 to 0.66651, saving model to pfn_regressor_5f.h5
# Epoch 8/1000
# 219/219 [==============================] - 12s 57ms/step - loss: 0.7456 - val_loss: 0.7169
#
# Epoch 00008: val_loss did not improve from 0.66651
# Epoch 9/1000
# 219/219 [==============================] - 12s 57ms/step - loss: 1.3271 - val_loss: 0.9824
#
# Epoch 00009: val_loss did not improve from 0.66651
# Epoch 10/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.8446 - val_loss: 0.3708
#
# Epoch 00010: val_loss improved from 0.66651 to 0.37076, saving model to pfn_regressor_5f.h5
# Epoch 11/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.4616 - val_loss: 0.5872
#
# Epoch 00011: val_loss did not improve from 0.37076
# Epoch 12/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.6414 - val_loss: 0.2662
#
# Epoch 00012: val_loss improved from 0.37076 to 0.26623, saving model to pfn_regressor_5f.h5
# Epoch 13/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.5954 - val_loss: 0.9143
#
# Epoch 00013: val_loss did not improve from 0.26623
# Epoch 14/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.4045 - val_loss: 0.4057
#
# Epoch 00014: val_loss did not improve from 0.26623
# Epoch 15/1000
# 219/219 [==============================] - 12s 57ms/step - loss: 0.3116 - val_loss: 0.2545
#
# Epoch 00015: val_loss improved from 0.26623 to 0.25452, saving model to pfn_regressor_5f.h5
# Epoch 16/1000
# 219/219 [==============================] - 12s 57ms/step - loss: 0.4174 - val_loss: 0.2635
#
# Epoch 00016: val_loss did not improve from 0.25452
# Epoch 17/1000
# 219/219 [==============================] - 13s 57ms/step - loss: 0.2775 - val_loss: 0.3780
#
# Epoch 00017: val_loss did not improve from 0.25452
# Epoch 18/1000
# 219/219 [==============================] - 13s 57ms/step - loss: 0.5481 - val_loss: 0.2547
#
# Epoch 00018: val_loss did not improve from 0.25452
# Epoch 19/1000
# 219/219 [==============================] - 12s 57ms/step - loss: 0.3579 - val_loss: 0.4847
#
# Epoch 00019: val_loss did not improve from 0.25452
# Epoch 20/1000
# 219/219 [==============================] - 13s 57ms/step - loss: 0.3628 - val_loss: 0.3380
#
# Epoch 00020: val_loss did not improve from 0.25452
# Epoch 21/1000
# 219/219 [==============================] - 13s 57ms/step - loss: 0.2811 - val_loss: 0.2124
#
# Epoch 00021: val_loss improved from 0.25452 to 0.21239, saving model to pfn_regressor_5f.h5
# Epoch 22/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.2126 - val_loss: 0.1178
#
# Epoch 00022: val_loss improved from 0.21239 to 0.11785, saving model to pfn_regressor_5f.h5
# Epoch 23/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.2049 - val_loss: 0.2269
#
# Epoch 00023: val_loss did not improve from 0.11785
# Epoch 24/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1670 - val_loss: 0.1618
#
# Epoch 00024: val_loss did not improve from 0.11785
# Epoch 25/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.1727 - val_loss: 0.1387
#
# Epoch 00025: val_loss did not improve from 0.11785
# Epoch 26/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1950 - val_loss: 0.1041
#
# Epoch 00026: val_loss improved from 0.11785 to 0.10408, saving model to pfn_regressor_5f.h5
# Epoch 27/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1200 - val_loss: 0.2358
#
# Epoch 00027: val_loss did not improve from 0.10408
# Epoch 28/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.2018 - val_loss: 0.0925
#
# Epoch 00028: val_loss improved from 0.10408 to 0.09254, saving model to pfn_regressor_5f.h5
# Epoch 29/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1233 - val_loss: 0.0974
#
# Epoch 00029: val_loss did not improve from 0.09254
# Epoch 30/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0825 - val_loss: 0.0687
#
# Epoch 00030: val_loss improved from 0.09254 to 0.06866, saving model to pfn_regressor_5f.h5
# Epoch 31/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1026 - val_loss: 0.1074
#
# Epoch 00031: val_loss did not improve from 0.06866
# Epoch 32/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0913 - val_loss: 0.1138
#
# Epoch 00032: val_loss did not improve from 0.06866
# Epoch 33/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0766 - val_loss: 0.0876
#
# Epoch 00033: val_loss did not improve from 0.06866
# Epoch 34/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.1020 - val_loss: 0.0818
#
# Epoch 00034: val_loss did not improve from 0.06866
# Epoch 35/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0782 - val_loss: 0.0651
#
# Epoch 00035: val_loss improved from 0.06866 to 0.06509, saving model to pfn_regressor_5f.h5
# Epoch 36/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0648 - val_loss: 0.0781
#
# Epoch 00036: val_loss did not improve from 0.06509
# Epoch 37/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0751 - val_loss: 0.0581
#
# Epoch 00037: val_loss improved from 0.06509 to 0.05808, saving model to pfn_regressor_5f.h5
# Epoch 38/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0687 - val_loss: 0.0714
#
# Epoch 00038: val_loss did not improve from 0.05808
# Epoch 39/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.1629 - val_loss: 0.1778
#
# Epoch 00039: val_loss did not improve from 0.05808
# Epoch 40/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0511 - val_loss: 0.0449
#
# Epoch 00040: val_loss improved from 0.05808 to 0.04485, saving model to pfn_regressor_5f.h5
# Epoch 41/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0405 - val_loss: 0.0453
#
# Epoch 00041: val_loss did not improve from 0.04485
# Epoch 42/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0441 - val_loss: 0.0490
#
# Epoch 00042: val_loss did not improve from 0.04485
# Epoch 43/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0559 - val_loss: 0.0388
#
# Epoch 00043: val_loss improved from 0.04485 to 0.03879, saving model to pfn_regressor_5f.h5
# Epoch 44/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0373 - val_loss: 0.0449
#
# Epoch 00044: val_loss did not improve from 0.03879
# Epoch 45/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0860 - val_loss: 0.2795
#
# Epoch 00045: val_loss did not improve from 0.03879
# Epoch 46/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0618 - val_loss: 0.0466
#
# Epoch 00046: val_loss did not improve from 0.03879
# Epoch 47/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0341 - val_loss: 0.0358
#
# Epoch 00047: val_loss improved from 0.03879 to 0.03583, saving model to pfn_regressor_5f.h5
# Epoch 48/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0298 - val_loss: 0.0531
#
# Epoch 00048: val_loss did not improve from 0.03583
# Epoch 49/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0311 - val_loss: 0.0321
#
# Epoch 00049: val_loss improved from 0.03583 to 0.03206, saving model to pfn_regressor_5f.h5
# Epoch 50/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0367 - val_loss: 0.0720
#
# Epoch 00050: val_loss did not improve from 0.03206
# Epoch 51/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0308 - val_loss: 0.0319
#
# Epoch 00051: val_loss improved from 0.03206 to 0.03185, saving model to pfn_regressor_5f.h5
# Epoch 52/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0385 - val_loss: 0.0452
#
# Epoch 00052: val_loss did not improve from 0.03185
# Epoch 53/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0321 - val_loss: 0.0258
#
# Epoch 00053: val_loss improved from 0.03185 to 0.02581, saving model to pfn_regressor_5f.h5
# Epoch 54/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0355 - val_loss: 0.0365
#
# Epoch 00054: val_loss did not improve from 0.02581
# Epoch 55/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0329 - val_loss: 0.0380
#
# Epoch 00055: val_loss did not improve from 0.02581
# Epoch 56/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0331 - val_loss: 0.0248
#
# Epoch 00056: val_loss improved from 0.02581 to 0.02480, saving model to pfn_regressor_5f.h5
# Epoch 57/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0299 - val_loss: 0.0242
#
# Epoch 00057: val_loss improved from 0.02480 to 0.02417, saving model to pfn_regressor_5f.h5
# Epoch 58/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0269 - val_loss: 0.0289
#
# Epoch 00058: val_loss did not improve from 0.02417
# Epoch 59/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0377 - val_loss: 0.0442
#
# Epoch 00059: val_loss did not improve from 0.02417
# Epoch 60/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0280 - val_loss: 0.0234
#
# Epoch 00060: val_loss improved from 0.02417 to 0.02338, saving model to pfn_regressor_5f.h5
# Epoch 61/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0290 - val_loss: 0.0518
#
# Epoch 00061: val_loss did not improve from 0.02338
# Epoch 62/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0272 - val_loss: 0.0246
#
# Epoch 00062: val_loss did not improve from 0.02338
# Epoch 63/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0238 - val_loss: 0.0478
#
# Epoch 00063: val_loss did not improve from 0.02338
# Epoch 64/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0242 - val_loss: 0.0223
#
# Epoch 00064: val_loss improved from 0.02338 to 0.02234, saving model to pfn_regressor_5f.h5
# Epoch 65/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0206 - val_loss: 0.0208
#
# Epoch 00065: val_loss improved from 0.02234 to 0.02079, saving model to pfn_regressor_5f.h5
# Epoch 66/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0230 - val_loss: 0.0263
#
# Epoch 00066: val_loss did not improve from 0.02079
# Epoch 67/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0199 - val_loss: 0.0197
#
# Epoch 00067: val_loss improved from 0.02079 to 0.01966, saving model to pfn_regressor_5f.h5
# Epoch 68/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0185 - val_loss: 0.0211
#
# Epoch 00068: val_loss did not improve from 0.01966
# Epoch 69/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 1.1008 - val_loss: 0.3294
#
# Epoch 00069: val_loss did not improve from 0.01966
# Epoch 70/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0717 - val_loss: 0.0450
#
# Epoch 00070: val_loss did not improve from 0.01966
# Epoch 71/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0368 - val_loss: 0.0351
#
# Epoch 00071: val_loss did not improve from 0.01966
# Epoch 72/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0293 - val_loss: 0.0283
#
# Epoch 00072: val_loss did not improve from 0.01966
# Epoch 73/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0278 - val_loss: 0.0240
#
# Epoch 00073: val_loss did not improve from 0.01966
# Epoch 74/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0251 - val_loss: 0.0241
#
# Epoch 00074: val_loss did not improve from 0.01966
# Epoch 75/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0229 - val_loss: 0.0226
#
# Epoch 00075: val_loss did not improve from 0.01966
# Epoch 76/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0226 - val_loss: 0.0219
#
# Epoch 00076: val_loss did not improve from 0.01966
# Epoch 77/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0230 - val_loss: 0.0216
#
# Epoch 00077: val_loss did not improve from 0.01966
# Epoch 78/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0212 - val_loss: 0.0282
#
# Epoch 00078: val_loss did not improve from 0.01966
# Epoch 79/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0213 - val_loss: 0.0287
#
# Epoch 00079: val_loss did not improve from 0.01966
# Epoch 80/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0208 - val_loss: 0.0194
#
# Epoch 00080: val_loss improved from 0.01966 to 0.01939, saving model to pfn_regressor_5f.h5
# Epoch 81/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0207 - val_loss: 0.0197
#
# Epoch 00081: val_loss did not improve from 0.01939
# Epoch 82/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0209 - val_loss: 0.0187
#
# Epoch 00082: val_loss improved from 0.01939 to 0.01870, saving model to pfn_regressor_5f.h5
# Epoch 83/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0198 - val_loss: 0.0230
#
# Epoch 00083: val_loss did not improve from 0.01870
# Epoch 84/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0188 - val_loss: 0.0183
#
# Epoch 00084: val_loss improved from 0.01870 to 0.01830, saving model to pfn_regressor_5f.h5
# Epoch 85/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0203 - val_loss: 0.0205
#
# Epoch 00085: val_loss did not improve from 0.01830
# Epoch 86/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0202 - val_loss: 0.0197
#
# Epoch 00086: val_loss did not improve from 0.01830
# Epoch 87/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0181 - val_loss: 0.0169
#
# Epoch 00087: val_loss improved from 0.01830 to 0.01687, saving model to pfn_regressor_5f.h5
# Epoch 88/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0178 - val_loss: 0.0184
#
# Epoch 00088: val_loss did not improve from 0.01687
# Epoch 89/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0179 - val_loss: 0.0160
#
# Epoch 00089: val_loss improved from 0.01687 to 0.01599, saving model to pfn_regressor_5f.h5
# Epoch 90/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0195 - val_loss: 0.0161
#
# Epoch 00090: val_loss did not improve from 0.01599
# Epoch 91/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0169 - val_loss: 0.0171
#
# Epoch 00091: val_loss did not improve from 0.01599
# Epoch 92/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0169 - val_loss: 0.0188
#
# Epoch 00092: val_loss did not improve from 0.01599
# Epoch 93/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0195 - val_loss: 0.0163
#
# Epoch 00093: val_loss did not improve from 0.01599
# Epoch 94/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0185 - val_loss: 0.0193
#
# Epoch 00094: val_loss did not improve from 0.01599
# Epoch 95/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0161 - val_loss: 0.0166
#
# Epoch 00095: val_loss did not improve from 0.01599
# Epoch 96/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0168 - val_loss: 0.0148
#
# Epoch 00096: val_loss improved from 0.01599 to 0.01482, saving model to pfn_regressor_5f.h5
# Epoch 97/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0161 - val_loss: 0.0146
#
# Epoch 00097: val_loss improved from 0.01482 to 0.01463, saving model to pfn_regressor_5f.h5
# Epoch 98/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0164 - val_loss: 0.0162
#
# Epoch 00098: val_loss did not improve from 0.01463
# Epoch 99/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0169 - val_loss: 0.0145
#
# Epoch 00099: val_loss improved from 0.01463 to 0.01452, saving model to pfn_regressor_5f.h5
# Epoch 100/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0156 - val_loss: 0.0152
#
# Epoch 00100: val_loss did not improve from 0.01452
# Epoch 101/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0151 - val_loss: 0.0153
#
# Epoch 00101: val_loss did not improve from 0.01452
# Epoch 102/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0159 - val_loss: 0.0150
#
# Epoch 00102: val_loss did not improve from 0.01452
# Epoch 103/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0159 - val_loss: 0.0142
#
# Epoch 00103: val_loss improved from 0.01452 to 0.01418, saving model to pfn_regressor_5f.h5
# Epoch 104/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0155 - val_loss: 0.0163
#
# Epoch 00104: val_loss did not improve from 0.01418
# Epoch 105/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0160 - val_loss: 0.0145
#
# Epoch 00105: val_loss did not improve from 0.01418
# Epoch 106/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0144 - val_loss: 0.0146
#
# Epoch 00106: val_loss did not improve from 0.01418
# Epoch 107/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0142 - val_loss: 0.0169
#
# Epoch 00107: val_loss did not improve from 0.01418
# Epoch 108/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0148 - val_loss: 0.0142
#
# Epoch 00108: val_loss did not improve from 0.01418
# Epoch 109/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0152 - val_loss: 0.0190
#
# Epoch 00109: val_loss did not improve from 0.01418
# Epoch 110/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0134 - val_loss: 0.0140
#
# Epoch 00110: val_loss improved from 0.01418 to 0.01400, saving model to pfn_regressor_5f.h5
# Epoch 111/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0153 - val_loss: 0.0170
#
# Epoch 00111: val_loss did not improve from 0.01400
# Epoch 112/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0146 - val_loss: 0.0135
#
# Epoch 00112: val_loss improved from 0.01400 to 0.01346, saving model to pfn_regressor_5f.h5
# Epoch 113/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0129 - val_loss: 0.0128
#
# Epoch 00113: val_loss improved from 0.01346 to 0.01282, saving model to pfn_regressor_5f.h5
# Epoch 114/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0137 - val_loss: 0.0287
#
# Epoch 00114: val_loss did not improve from 0.01282
# Epoch 115/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0136 - val_loss: 0.0145
#
# Epoch 00115: val_loss did not improve from 0.01282
# Epoch 116/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0130 - val_loss: 0.0130
#
# Epoch 00116: val_loss did not improve from 0.01282
# Epoch 117/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0129 - val_loss: 0.0142
#
# Epoch 00117: val_loss did not improve from 0.01282
# Epoch 118/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0136 - val_loss: 0.0183
#
# Epoch 00118: val_loss did not improve from 0.01282
# Epoch 119/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0126 - val_loss: 0.0136
#
# Epoch 00119: val_loss did not improve from 0.01282
# Epoch 120/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0125 - val_loss: 0.0124
#
# Epoch 00120: val_loss improved from 0.01282 to 0.01244, saving model to pfn_regressor_5f.h5
# Epoch 121/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0122 - val_loss: 0.0141
#
# Epoch 00121: val_loss did not improve from 0.01244
# Epoch 122/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0117 - val_loss: 0.0147
#
# Epoch 00122: val_loss did not improve from 0.01244
# Epoch 123/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0125 - val_loss: 0.0253
#
# Epoch 00123: val_loss did not improve from 0.01244
# Epoch 124/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0127 - val_loss: 0.0129
#
# Epoch 00124: val_loss did not improve from 0.01244
# Epoch 125/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0109 - val_loss: 0.0117
#
# Epoch 00125: val_loss improved from 0.01244 to 0.01168, saving model to pfn_regressor_5f.h5
# Epoch 126/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0108 - val_loss: 0.0111
#
# Epoch 00126: val_loss improved from 0.01168 to 0.01111, saving model to pfn_regressor_5f.h5
# Epoch 127/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0109 - val_loss: 0.0119
#
# Epoch 00127: val_loss did not improve from 0.01111
# Epoch 128/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0105 - val_loss: 0.0112
#
# Epoch 00128: val_loss did not improve from 0.01111
# Epoch 129/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0107 - val_loss: 0.0121
#
# Epoch 00129: val_loss did not improve from 0.01111
# Epoch 130/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0115 - val_loss: 0.0116
#
# Epoch 00130: val_loss did not improve from 0.01111
# Epoch 131/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0103 - val_loss: 0.0108
#
# Epoch 00131: val_loss improved from 0.01111 to 0.01083, saving model to pfn_regressor_5f.h5
# Epoch 132/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0096 - val_loss: 0.0101
#
# Epoch 00132: val_loss improved from 0.01083 to 0.01005, saving model to pfn_regressor_5f.h5
# Epoch 133/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0098 - val_loss: 0.0106
#
# Epoch 00133: val_loss did not improve from 0.01005
# Epoch 134/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0100 - val_loss: 0.0105
#
# Epoch 00134: val_loss did not improve from 0.01005
# Epoch 135/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0095 - val_loss: 0.0126
#
# Epoch 00135: val_loss did not improve from 0.01005
# Epoch 136/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0099 - val_loss: 0.0103
#
# Epoch 00136: val_loss did not improve from 0.01005
# Epoch 137/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0092 - val_loss: 0.0095
#
# Epoch 00137: val_loss improved from 0.01005 to 0.00951, saving model to pfn_regressor_5f.h5
# Epoch 138/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0091 - val_loss: 0.0103
#
# Epoch 00138: val_loss did not improve from 0.00951
# Epoch 139/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0086 - val_loss: 0.0101
#
# Epoch 00139: val_loss did not improve from 0.00951
# Epoch 140/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0093 - val_loss: 0.0105
#
# Epoch 00140: val_loss did not improve from 0.00951
# Epoch 141/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0090 - val_loss: 0.0119
#
# Epoch 00141: val_loss did not improve from 0.00951
# Epoch 142/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0085 - val_loss: 0.0098
#
# Epoch 00142: val_loss did not improve from 0.00951
# Epoch 143/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0084 - val_loss: 0.0088
#
# Epoch 00143: val_loss improved from 0.00951 to 0.00883, saving model to pfn_regressor_5f.h5
# Epoch 144/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0086 - val_loss: 0.0103
#
# Epoch 00144: val_loss did not improve from 0.00883
# Epoch 145/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0083 - val_loss: 0.0109
#
# Epoch 00145: val_loss did not improve from 0.00883
# Epoch 146/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0082 - val_loss: 0.0105
#
# Epoch 00146: val_loss did not improve from 0.00883
# Epoch 147/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0078 - val_loss: 0.0110
#
# Epoch 00147: val_loss did not improve from 0.00883
# Epoch 148/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0077 - val_loss: 0.0099
#
# Epoch 00148: val_loss did not improve from 0.00883
# Epoch 149/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0082 - val_loss: 0.0103
#
# Epoch 00149: val_loss did not improve from 0.00883
# Epoch 150/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0076 - val_loss: 0.0103
#
# Epoch 00150: val_loss did not improve from 0.00883
# Epoch 151/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0084 - val_loss: 0.0122
#
# Epoch 00151: val_loss did not improve from 0.00883
# Epoch 152/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0079 - val_loss: 0.0083
#
# Epoch 00152: val_loss improved from 0.00883 to 0.00828, saving model to pfn_regressor_5f.h5
# Epoch 153/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0071 - val_loss: 0.0129
#
# Epoch 00153: val_loss did not improve from 0.00828
# Epoch 154/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0073 - val_loss: 0.0107
#
# Epoch 00154: val_loss did not improve from 0.00828
# Epoch 155/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0079 - val_loss: 0.0088
#
# Epoch 00155: val_loss did not improve from 0.00828
# Epoch 156/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0076 - val_loss: 0.0085
#
# Epoch 00156: val_loss did not improve from 0.00828
# Epoch 157/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0072 - val_loss: 0.0087
#
# Epoch 00157: val_loss did not improve from 0.00828
# Epoch 158/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0072 - val_loss: 0.0099
#
# Epoch 00158: val_loss did not improve from 0.00828
# Epoch 159/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0069 - val_loss: 0.0128
#
# Epoch 00159: val_loss did not improve from 0.00828
# Epoch 160/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0078 - val_loss: 0.0085
#
# Epoch 00160: val_loss did not improve from 0.00828
# Epoch 161/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0068 - val_loss: 0.0109
#
# Epoch 00161: val_loss did not improve from 0.00828
# Epoch 162/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0075 - val_loss: 0.0165
#
# Epoch 00162: val_loss did not improve from 0.00828
# Epoch 163/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0073 - val_loss: 0.0083
#
# Epoch 00163: val_loss improved from 0.00828 to 0.00826, saving model to pfn_regressor_5f.h5
# Epoch 164/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0068 - val_loss: 0.0101
#
# Epoch 00164: val_loss did not improve from 0.00826
# Epoch 165/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0070 - val_loss: 0.0087
#
# Epoch 00165: val_loss did not improve from 0.00826
# Epoch 166/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0074 - val_loss: 0.0085
#
# Epoch 00166: val_loss did not improve from 0.00826
# Epoch 167/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0070 - val_loss: 0.0113
#
# Epoch 00167: val_loss did not improve from 0.00826
# Epoch 168/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0071 - val_loss: 0.0088
#
# Epoch 00168: val_loss did not improve from 0.00826
# Epoch 169/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0068 - val_loss: 0.0142
#
# Epoch 00169: val_loss did not improve from 0.00826
# Epoch 170/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0069 - val_loss: 0.0101
#
# Epoch 00170: val_loss did not improve from 0.00826
# Epoch 171/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0069 - val_loss: 0.0078
#
# Epoch 00171: val_loss improved from 0.00826 to 0.00783, saving model to pfn_regressor_5f.h5
# Epoch 172/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0069 - val_loss: 0.0083
#
# Epoch 00172: val_loss did not improve from 0.00783
# Epoch 173/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0063 - val_loss: 0.0088
#
# Epoch 00173: val_loss did not improve from 0.00783
# Epoch 174/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0066 - val_loss: 0.0097
#
# Epoch 00174: val_loss did not improve from 0.00783
# Epoch 175/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0071 - val_loss: 0.0095
#
# Epoch 00175: val_loss did not improve from 0.00783
# Epoch 176/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0063 - val_loss: 0.0085
#
# Epoch 00176: val_loss did not improve from 0.00783
# Epoch 177/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0064 - val_loss: 0.0100
#
# Epoch 00177: val_loss did not improve from 0.00783
# Epoch 178/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0073 - val_loss: 0.0091
#
# Epoch 00178: val_loss did not improve from 0.00783
# Epoch 179/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0068 - val_loss: 0.0087
#
# Epoch 00179: val_loss did not improve from 0.00783
# Epoch 180/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0066 - val_loss: 0.0107
#
# Epoch 00180: val_loss did not improve from 0.00783
# Epoch 181/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0062 - val_loss: 0.0085
#
# Epoch 00181: val_loss did not improve from 0.00783
# Epoch 182/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0098
#
# Epoch 00182: val_loss did not improve from 0.00783
# Epoch 183/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0063 - val_loss: 0.0141
#
# Epoch 00183: val_loss did not improve from 0.00783
# Epoch 184/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0066 - val_loss: 0.0082
#
# Epoch 00184: val_loss did not improve from 0.00783
# Epoch 185/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0060 - val_loss: 0.0079
#
# Epoch 00185: val_loss did not improve from 0.00783
# Epoch 186/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0102
#
# Epoch 00186: val_loss did not improve from 0.00783
# Epoch 187/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0058 - val_loss: 0.0108
#
# Epoch 00187: val_loss did not improve from 0.00783
# Epoch 188/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0065 - val_loss: 0.0076
#
# Epoch 00188: val_loss improved from 0.00783 to 0.00762, saving model to pfn_regressor_5f.h5
# Epoch 189/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0073 - val_loss: 0.0095
#
# Epoch 00189: val_loss did not improve from 0.00762
# Epoch 190/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0060 - val_loss: 0.0116
#
# Epoch 00190: val_loss did not improve from 0.00762
# Epoch 191/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0060 - val_loss: 0.0076
#
# Epoch 00191: val_loss improved from 0.00762 to 0.00756, saving model to pfn_regressor_5f.h5
# Epoch 192/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0059 - val_loss: 0.0073
#
# Epoch 00192: val_loss improved from 0.00756 to 0.00729, saving model to pfn_regressor_5f.h5
# Epoch 193/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0059 - val_loss: 0.0086
#
# Epoch 00193: val_loss did not improve from 0.00729
# Epoch 194/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0075
#
# Epoch 00194: val_loss did not improve from 0.00729
# Epoch 195/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0059 - val_loss: 0.0080
#
# Epoch 00195: val_loss did not improve from 0.00729
# Epoch 196/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0064 - val_loss: 0.0081
#
# Epoch 00196: val_loss did not improve from 0.00729
# Epoch 197/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0088
#
# Epoch 00197: val_loss did not improve from 0.00729
# Epoch 198/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0089
#
# Epoch 00198: val_loss did not improve from 0.00729
# Epoch 199/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0057 - val_loss: 0.0073
#
# Epoch 00199: val_loss did not improve from 0.00729
# Epoch 200/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0062 - val_loss: 0.0085
#
# Epoch 00200: val_loss did not improve from 0.00729
# Epoch 201/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0058 - val_loss: 0.0082
#
# Epoch 00201: val_loss did not improve from 0.00729
# Epoch 202/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0064 - val_loss: 0.0107
#
# Epoch 00202: val_loss did not improve from 0.00729
# Epoch 203/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0061 - val_loss: 0.0075
#
# Epoch 00203: val_loss did not improve from 0.00729
# Epoch 204/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0071
#
# Epoch 00204: val_loss improved from 0.00729 to 0.00706, saving model to pfn_regressor_5f.h5
# Epoch 205/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0054 - val_loss: 0.0087
#
# Epoch 00205: val_loss did not improve from 0.00706
# Epoch 206/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0085
#
# Epoch 00206: val_loss did not improve from 0.00706
# Epoch 207/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0060 - val_loss: 0.0084
#
# Epoch 00207: val_loss did not improve from 0.00706
# Epoch 208/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0054 - val_loss: 0.0069
#
# Epoch 00208: val_loss improved from 0.00706 to 0.00691, saving model to pfn_regressor_5f.h5
# Epoch 209/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0060 - val_loss: 0.0078
#
# Epoch 00209: val_loss did not improve from 0.00691
# Epoch 210/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0059 - val_loss: 0.0074
#
# Epoch 00210: val_loss did not improve from 0.00691
# Epoch 211/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0068
#
# Epoch 00211: val_loss improved from 0.00691 to 0.00678, saving model to pfn_regressor_5f.h5
# Epoch 212/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0055 - val_loss: 0.0093
#
# Epoch 00212: val_loss did not improve from 0.00678
# Epoch 213/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0059 - val_loss: 0.0085
#
# Epoch 00213: val_loss did not improve from 0.00678
# Epoch 214/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0063 - val_loss: 0.0105
#
# Epoch 00214: val_loss did not improve from 0.00678
# Epoch 215/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0071 - val_loss: 0.0119
#
# Epoch 00215: val_loss did not improve from 0.00678
# Epoch 216/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0061 - val_loss: 0.0079
#
# Epoch 00216: val_loss did not improve from 0.00678
# Epoch 217/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0057 - val_loss: 0.0079
#
# Epoch 00217: val_loss did not improve from 0.00678
# Epoch 218/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0056 - val_loss: 0.0072
#
# Epoch 00218: val_loss did not improve from 0.00678
# Epoch 219/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0075
#
# Epoch 00219: val_loss did not improve from 0.00678
# Epoch 220/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0053 - val_loss: 0.0075
#
# Epoch 00220: val_loss did not improve from 0.00678
# Epoch 221/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0077
#
# Epoch 00221: val_loss did not improve from 0.00678
# Epoch 222/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0065
#
# Epoch 00222: val_loss improved from 0.00678 to 0.00655, saving model to pfn_regressor_5f.h5
# Epoch 223/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0055 - val_loss: 0.0088
#
# Epoch 00223: val_loss did not improve from 0.00655
# Epoch 224/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0074
#
# Epoch 00224: val_loss did not improve from 0.00655
# Epoch 225/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0082
#
# Epoch 00225: val_loss did not improve from 0.00655
# Epoch 226/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0100
#
# Epoch 00226: val_loss did not improve from 0.00655
# Epoch 227/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0062 - val_loss: 0.0109
#
# Epoch 00227: val_loss did not improve from 0.00655
# Epoch 228/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0104
#
# Epoch 00228: val_loss did not improve from 0.00655
# Epoch 229/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0075
#
# Epoch 00229: val_loss did not improve from 0.00655
# Epoch 230/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0052 - val_loss: 0.0074
#
# Epoch 00230: val_loss did not improve from 0.00655
# Epoch 231/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0076
#
# Epoch 00231: val_loss did not improve from 0.00655
# Epoch 232/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0078
#
# Epoch 00232: val_loss did not improve from 0.00655
# Epoch 233/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0055 - val_loss: 0.0081
#
# Epoch 00233: val_loss did not improve from 0.00655
# Epoch 234/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0055 - val_loss: 0.0073
#
# Epoch 00234: val_loss did not improve from 0.00655
# Epoch 235/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0064 - val_loss: 0.0077
#
# Epoch 00235: val_loss did not improve from 0.00655
# Epoch 236/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0057 - val_loss: 0.0075
#
# Epoch 00236: val_loss did not improve from 0.00655
# Epoch 237/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0065
#
# Epoch 00237: val_loss improved from 0.00655 to 0.00650, saving model to pfn_regressor_5f.h5
# Epoch 238/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0092
#
# Epoch 00238: val_loss did not improve from 0.00650
# Epoch 239/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0051 - val_loss: 0.0079
#
# Epoch 00239: val_loss did not improve from 0.00650
# Epoch 240/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0072
#
# Epoch 00240: val_loss did not improve from 0.00650
# Epoch 241/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0069
#
# Epoch 00241: val_loss did not improve from 0.00650
# Epoch 242/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0089
#
# Epoch 00242: val_loss did not improve from 0.00650
# Epoch 243/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0060 - val_loss: 0.0091
#
# Epoch 00243: val_loss did not improve from 0.00650
# Epoch 244/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0073
#
# Epoch 00244: val_loss did not improve from 0.00650
# Epoch 245/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0073
#
# Epoch 00245: val_loss did not improve from 0.00650
# Epoch 246/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0051 - val_loss: 0.0075
#
# Epoch 00246: val_loss did not improve from 0.00650
# Epoch 247/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0051 - val_loss: 0.0086
#
# Epoch 00247: val_loss did not improve from 0.00650
# Epoch 248/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0068
#
# Epoch 00248: val_loss did not improve from 0.00650
# Epoch 249/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0051 - val_loss: 0.0090
#
# Epoch 00249: val_loss did not improve from 0.00650
# Epoch 250/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0073
#
# Epoch 00250: val_loss did not improve from 0.00650
# Epoch 251/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0074
#
# Epoch 00251: val_loss did not improve from 0.00650
# Epoch 252/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0079
#
# Epoch 00252: val_loss did not improve from 0.00650
# Epoch 253/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0099
#
# Epoch 00253: val_loss did not improve from 0.00650
# Epoch 254/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0050 - val_loss: 0.0066
#
# Epoch 00254: val_loss did not improve from 0.00650
# Epoch 255/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0060 - val_loss: 0.0088
#
# Epoch 00255: val_loss did not improve from 0.00650
# Epoch 256/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0066
#
# Epoch 00256: val_loss did not improve from 0.00650
# Epoch 257/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0091
#
# Epoch 00257: val_loss did not improve from 0.00650
# Epoch 258/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0054 - val_loss: 0.0084
#
# Epoch 00258: val_loss did not improve from 0.00650
# Epoch 259/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0057 - val_loss: 0.0086
#
# Epoch 00259: val_loss did not improve from 0.00650
# Epoch 260/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0051 - val_loss: 0.0074
#
# Epoch 00260: val_loss did not improve from 0.00650
# Epoch 261/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0048 - val_loss: 0.0071
#
# Epoch 00261: val_loss did not improve from 0.00650
# Epoch 262/1000
# 219/219 [==============================] - 13s 58ms/step - loss: 0.0046 - val_loss: 0.0076
#
# Epoch 00262: val_loss did not improve from 0.00650
# Epoch 263/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0044 - val_loss: 0.0072
#
# Epoch 00263: val_loss did not improve from 0.00650
# Epoch 264/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0043 - val_loss: 0.0067
#
# Epoch 00264: val_loss did not improve from 0.00650
# Epoch 265/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0078
#
# Epoch 00265: val_loss did not improve from 0.00650
# Epoch 266/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0047 - val_loss: 0.0071
#
# Epoch 00266: val_loss did not improve from 0.00650
# Epoch 267/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0043 - val_loss: 0.0063
#
# Epoch 00267: val_loss improved from 0.00650 to 0.00627, saving model to pfn_regressor_5f.h5
# Epoch 268/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0071
#
# Epoch 00268: val_loss did not improve from 0.00627
# Epoch 269/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0111
#
# Epoch 00269: val_loss did not improve from 0.00627
# Epoch 270/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0048 - val_loss: 0.0066
#
# Epoch 00270: val_loss did not improve from 0.00627
# Epoch 271/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0044 - val_loss: 0.0082
#
# Epoch 00271: val_loss did not improve from 0.00627
# Epoch 272/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0072
#
# Epoch 00272: val_loss did not improve from 0.00627
# Epoch 273/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0087
#
# Epoch 00273: val_loss did not improve from 0.00627
# Epoch 274/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0044 - val_loss: 0.0076
#
# Epoch 00274: val_loss did not improve from 0.00627
# Epoch 275/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0092
#
# Epoch 00275: val_loss did not improve from 0.00627
# Epoch 276/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0047 - val_loss: 0.0084
#
# Epoch 00276: val_loss did not improve from 0.00627
# Epoch 277/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0055 - val_loss: 0.0074
#
# Epoch 00277: val_loss did not improve from 0.00627
# Epoch 278/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0049 - val_loss: 0.0072
#
# Epoch 00278: val_loss did not improve from 0.00627
# Epoch 279/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0062
#
# Epoch 00279: val_loss improved from 0.00627 to 0.00618, saving model to pfn_regressor_5f.h5
# Epoch 280/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0042 - val_loss: 0.0067
#
# Epoch 00280: val_loss did not improve from 0.00618
# Epoch 281/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0067
#
# Epoch 00281: val_loss did not improve from 0.00618
# Epoch 282/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0047 - val_loss: 0.0070
#
# Epoch 00282: val_loss did not improve from 0.00618
# Epoch 283/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0041 - val_loss: 0.0062
#
# Epoch 00283: val_loss improved from 0.00618 to 0.00616, saving model to pfn_regressor_5f.h5
# Epoch 284/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0043 - val_loss: 0.0068
#
# Epoch 00284: val_loss did not improve from 0.00616
# Epoch 285/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0041 - val_loss: 0.0073
#
# Epoch 00285: val_loss did not improve from 0.00616
# Epoch 286/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0044 - val_loss: 0.0077
#
# Epoch 00286: val_loss did not improve from 0.00616
# Epoch 287/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0043 - val_loss: 0.0074
#
# Epoch 00287: val_loss did not improve from 0.00616
# Epoch 288/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0044 - val_loss: 0.0069
#
# Epoch 00288: val_loss did not improve from 0.00616
# Epoch 289/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0052 - val_loss: 0.0095
#
# Epoch 00289: val_loss did not improve from 0.00616
# Epoch 290/1000
# ...
# Epoch 409/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0073
#
# Epoch 00409: val_loss did not improve from 0.00574
# Epoch 410/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0067
#
# Epoch 00410: val_loss did not improve from 0.00574
# Epoch 411/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0084
#
# Epoch 00411: val_loss did not improve from 0.00574
# Epoch 412/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0068
#
# Epoch 00412: val_loss did not improve from 0.00574
# Epoch 413/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0064
#
# Epoch 00413: val_loss did not improve from 0.00574
# Epoch 414/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0069
#
# Epoch 00414: val_loss did not improve from 0.00574
# Epoch 415/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0071
#
# Epoch 00415: val_loss did not improve from 0.00574
# Epoch 416/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00416: val_loss did not improve from 0.00574
# Epoch 417/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0040 - val_loss: 0.0067
#
# Epoch 00417: val_loss did not improve from 0.00574
# Epoch 418/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0046 - val_loss: 0.0066
#
# Epoch 00418: val_loss did not improve from 0.00574
# Epoch 419/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0041 - val_loss: 0.0076
#
# Epoch 00419: val_loss did not improve from 0.00574
# Epoch 420/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0071
#
# Epoch 00420: val_loss did not improve from 0.00574
# Epoch 421/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0071
#
# Epoch 00421: val_loss did not improve from 0.00574
# Epoch 422/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0068
#
# Epoch 00422: val_loss did not improve from 0.00574
# Epoch 423/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0062
#
# Epoch 00423: val_loss did not improve from 0.00574
# Epoch 424/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0037 - val_loss: 0.0063
#
# Epoch 00424: val_loss did not improve from 0.00574
# Epoch 425/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0037 - val_loss: 0.0063
#
# Epoch 00425: val_loss did not improve from 0.00574
# Epoch 426/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0057
#
# Epoch 00426: val_loss improved from 0.00574 to 0.00574, saving model to pfn_regressor_5f.h5
# Epoch 427/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0073
#
# Epoch 00427: val_loss did not improve from 0.00574
# Epoch 428/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0063
#
# Epoch 00428: val_loss did not improve from 0.00574
# Epoch 429/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0061
#
# Epoch 00429: val_loss did not improve from 0.00574
# Epoch 430/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0072
#
# Epoch 00430: val_loss did not improve from 0.00574
# Epoch 431/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00431: val_loss did not improve from 0.00574
# Epoch 432/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0068
#
# Epoch 00432: val_loss did not improve from 0.00574
# Epoch 433/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00433: val_loss did not improve from 0.00574
# Epoch 434/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0070
#
# Epoch 00434: val_loss did not improve from 0.00574
# Epoch 435/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0067
#
# Epoch 00435: val_loss did not improve from 0.00574
# Epoch 436/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0067
#
# Epoch 00436: val_loss did not improve from 0.00574
# Epoch 437/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0068
#
# Epoch 00437: val_loss did not improve from 0.00574
# Epoch 438/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0064
#
# Epoch 00438: val_loss did not improve from 0.00574
# Epoch 439/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0070
#
# Epoch 00439: val_loss did not improve from 0.00574
# Epoch 440/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0038 - val_loss: 0.0067
#
# Epoch 00440: val_loss did not improve from 0.00574
# Epoch 441/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0077
#
# Epoch 00441: val_loss did not improve from 0.00574
# Epoch 442/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0092
#
# Epoch 00442: val_loss did not improve from 0.00574
# Epoch 443/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0043 - val_loss: 0.0084
#
# Epoch 00443: val_loss did not improve from 0.00574
# Epoch 444/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0064
#
# Epoch 00444: val_loss did not improve from 0.00574
# Epoch 445/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0066
#
# Epoch 00445: val_loss did not improve from 0.00574
# Epoch 446/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0076
#
# Epoch 00446: val_loss did not improve from 0.00574
# Epoch 447/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0069
#
# Epoch 00447: val_loss did not improve from 0.00574
# Epoch 448/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0078
#
# Epoch 00448: val_loss did not improve from 0.00574
# Epoch 449/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0067
#
# Epoch 00449: val_loss did not improve from 0.00574
# Epoch 450/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0073
#
# Epoch 00450: val_loss did not improve from 0.00574
# Epoch 451/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0065
#
# Epoch 00451: val_loss did not improve from 0.00574
# Epoch 452/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0066
#
# Epoch 00452: val_loss did not improve from 0.00574
# Epoch 453/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0068
#
# Epoch 00453: val_loss did not improve from 0.00574
# Epoch 454/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0067
#
# Epoch 00454: val_loss did not improve from 0.00574
# Epoch 455/1000
# 219/219 [==============================] - 13s 60ms/step - loss: 0.0032 - val_loss: 0.0066
#
# Epoch 00455: val_loss did not improve from 0.00574
# Epoch 456/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0076
#
# Epoch 00456: val_loss did not improve from 0.00574
# Epoch 457/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0073
#
# Epoch 00457: val_loss did not improve from 0.00574
# Epoch 458/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0065
#
# Epoch 00458: val_loss did not improve from 0.00574
# Epoch 459/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0045 - val_loss: 0.0075
#
# Epoch 00459: val_loss did not improve from 0.00574
# Epoch 460/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0053 - val_loss: 0.0065
#
# Epoch 00460: val_loss did not improve from 0.00574
# Epoch 461/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0041 - val_loss: 0.0070
#
# Epoch 00461: val_loss did not improve from 0.00574
# Epoch 462/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0065
#
# Epoch 00462: val_loss did not improve from 0.00574
# Epoch 463/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0035 - val_loss: 0.0059
#
# Epoch 00463: val_loss did not improve from 0.00574
# Epoch 464/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0059
#
# Epoch 00464: val_loss did not improve from 0.00574
# Epoch 465/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0061
#
# Epoch 00465: val_loss did not improve from 0.00574
# Epoch 466/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0066
#
# Epoch 00466: val_loss did not improve from 0.00574
# Epoch 467/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0067
#
# Epoch 00467: val_loss did not improve from 0.00574
# Epoch 468/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0066
#
# Epoch 00468: val_loss did not improve from 0.00574
# Epoch 469/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0063
#
# Epoch 00469: val_loss did not improve from 0.00574
# Epoch 470/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0071
#
# Epoch 00470: val_loss did not improve from 0.00574
# Epoch 471/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0065
#
# Epoch 00471: val_loss did not improve from 0.00574
# Epoch 472/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0067
#
# Epoch 00472: val_loss did not improve from 0.00574
# Epoch 473/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0064
#
# Epoch 00473: val_loss did not improve from 0.00574
# Epoch 474/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0068
#
# Epoch 00474: val_loss did not improve from 0.00574
# Epoch 475/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0071
#
# Epoch 00475: val_loss did not improve from 0.00574
# Epoch 476/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0075
#
# Epoch 00476: val_loss did not improve from 0.00574
# Epoch 477/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0065
#
# Epoch 00477: val_loss did not improve from 0.00574
# Epoch 478/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0064
#
# Epoch 00478: val_loss did not improve from 0.00574
# Epoch 479/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00479: val_loss did not improve from 0.00574
# Epoch 480/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0063
#
# Epoch 00480: val_loss did not improve from 0.00574
# Epoch 481/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00481: val_loss did not improve from 0.00574
# Epoch 482/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0040 - val_loss: 0.0112
#
# Epoch 00482: val_loss did not improve from 0.00574
# Epoch 483/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0038 - val_loss: 0.0080
#
# Epoch 00483: val_loss did not improve from 0.00574
# Epoch 484/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0058
#
# Epoch 00484: val_loss did not improve from 0.00574
# Epoch 485/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00485: val_loss did not improve from 0.00574
# Epoch 486/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0062
#
# Epoch 00486: val_loss did not improve from 0.00574
# Epoch 487/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00487: val_loss did not improve from 0.00574
# Epoch 488/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0059
#
# Epoch 00488: val_loss did not improve from 0.00574
# Epoch 489/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0059
#
# Epoch 00489: val_loss did not improve from 0.00574
# Epoch 490/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0058
#
# Epoch 00490: val_loss did not improve from 0.00574
# Epoch 491/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0029 - val_loss: 0.0058
#
# Epoch 00491: val_loss did not improve from 0.00574
# Epoch 492/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0073
#
# Epoch 00492: val_loss did not improve from 0.00574
# Epoch 493/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0061
#
# Epoch 00493: val_loss did not improve from 0.00574
# Epoch 494/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00494: val_loss did not improve from 0.00574
# Epoch 495/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0061
#
# Epoch 00495: val_loss did not improve from 0.00574
# Epoch 496/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0065
#
# Epoch 00496: val_loss did not improve from 0.00574
# Epoch 497/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0060
#
# Epoch 00497: val_loss did not improve from 0.00574
# Epoch 498/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0061
#
# Epoch 00498: val_loss did not improve from 0.00574
# Epoch 499/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00499: val_loss did not improve from 0.00574
# Epoch 500/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0064
#
# Epoch 00500: val_loss did not improve from 0.00574
# Epoch 501/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0066
#
# Epoch 00501: val_loss did not improve from 0.00574
# Epoch 502/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00502: val_loss did not improve from 0.00574
# Epoch 503/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0033 - val_loss: 0.0073
#
# Epoch 00503: val_loss did not improve from 0.00574
# Epoch 504/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0036 - val_loss: 0.0063
#
# Epoch 00504: val_loss did not improve from 0.00574
# Epoch 505/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0034 - val_loss: 0.0061
#
# Epoch 00505: val_loss did not improve from 0.00574
# Epoch 506/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0065
#
# Epoch 00506: val_loss did not improve from 0.00574
# Epoch 507/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0061
#
# Epoch 00507: val_loss did not improve from 0.00574
# Epoch 508/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0031 - val_loss: 0.0061
#
# Epoch 00508: val_loss did not improve from 0.00574
# Epoch 509/1000
# 219/219 [==============================] - 13s 59ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00509: val_loss did not improve from 0.00574

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(history_ct.history['val_loss'], label="Validation")
plt.plot(history_ct.history['loss'], label="Training")
plt.yscale('log')
plt.ylim(.001,10)
plt.yticks(fontsize=13)
plt.xlim(0,600)
plt.xticks(fontsize=13)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right', ncol=1)
plt.text(600, 1.5, 'LR=1e-3', fontsize=13)
plt.text(600, 1, 'Batch: 509', fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_lossCurves_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
model = tf.keras.models.load_model("pfn_regressor_2g_fs.h5")

# %%
def eval_generator(data, batch_size):
     batches = (len(data) + batch_size - 1)//batch_size
     for i in range(batches):
          X = data[i*batch_size : (i+1)*batch_size]
          yield (X)

# %%
preds = np.exp(pfn.predict(eval_generator(x_test,500)).flatten())
print(preds.shape)
# Out:
# (20598,)

# %%
## PREDICTIONS AND TRUTH ##
bins = np.linspace(0,8,50, endpoint=True)
fig = plt.figure(figsize=(6,6))
plt.hist(y_test, color='steelblue', bins=bins, density=True, alpha=.5, edgecolor='black', label='target')
plt.hist(np.log(preds), color='coral', bins=bins, density=True, alpha=.5, edgecolor='black', label='network')
plt.title('Regression Output and Target', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(0,8)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(loc='upper left')
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_targetPreds_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
xcenter, medDNN = ru.responsePlot(x=np.exp(y_test), y=preds/np.exp(y_test),
                 atlas_x = 0.46, atlas_y = 0.95, simulation = True,
                 textlist = [{'x': 0.46, 'y': 0.85, 'text': 'Single $\pi^{+}$, Track+Clusters'},
                             {'x': 0.46, 'y': 0.8,  'text': 'PFN api'}])

# %%
import scipy.stats as stats
# from . import plot_util as pu
from util import plot_util as pu

def _iqrOverMed(x):
    # get the IQR via the percentile function
    # 84 is median + 1 sigma, 16 is median - 1 sigma
    q16, q84 = np.percentile(x, [16, 84])
    return (q84 - q16) / (2 * np.median(x))

def resolutionPlot(x, y, figfile='',
                   xlabel='True Energy [GeV]', ylabel='Response IQR / (2 x Median)',
                   atlas_x=-1, atlas_y=-1, simulation=False,
                   xlim=(0.3,1000), ylim=(0,1), 
                   textlist=[]):
    xbin = [10**exp for exp in  np.arange(-1.0, 3.1, 0.1)]
    xcenter = [(xbin[i] + xbin[i+1]) / 2 for i in range(len(xbin)-1)]

    resolution = stats.binned_statistic(x, y, bins=xbin, statistic=_iqrOverMed).statistic
    
    plt.cla(); plt.clf()
    fig = plt.figure()
    fig.patch.set_facecolor('white')
    plt.plot(xcenter, resolution)
    plt.xscale('log')
    plt.xlim(xlim)
    plt.ylim(ylim)
    pu.ampl.set_xlabel(xlabel)
    pu.ampl.set_ylabel(ylabel)

    pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

    if figfile != '':
        plt.savefig(figfile)
    plt.show()

    return xcenter, resolution

# %%
xcenter, iqrMDN3 = resolutionPlot(np.exp(y_test), preds,
                        atlas_x = 0.56, atlas_y = 0.95, simulation = True,
                        textlist = [{'x': 0.56, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
                                    {'x': 0.56, 'y': 0.8,  'text': 'PFN Api'}])

# %%
resp_plot = ru.resolutionPlot(x=np.exp(y_test), y=preds/np.exp(y_test),
                    figfile='',
                    statistic='std', xlabel='Particle Truth Energy', ylabel='Energy IQR over Median',
                    atlas_x=-1, atlas_y=-1, simulation=False,
                    textlist=[])

# %%
resid_DNN = preds - np.exp(y_test)

n_bins = 500
plt.cla(); plt.clf()
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.hist(resid_DNN,bins = n_bins,alpha=0.75)
plt.yscale('log')
plt.xlabel('Learned - True Energy')
plt.ylabel('Clusters')
plt.xlim(-3000,3000)
plt.legend()

atlas_x = 0.55
atlas_y = 0.95
simulation = True
textlist = [{'x': 0.55, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
            {'x': 0.55, 'y': 0.8,  'text': 'keras_pfn'}]
pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

plt.show()

# %%
def histogramSlices(x, ylist, labels=[''], xstep=0.2, statistic='iqr', title = 'Response',
                 xlabel='Predicted Energy / True Energy', ylabel='Clusters', alpha=1.,
                 xlim=(0.3,1000.), ylim=(0.,3.1), binsize=0.05, baseline=False, logscale=False, density=False,
                 atlas_x=-1, atlas_y=-1, simulation=False,
                 textlist=[]):
    
    if type(ylist) != type([]):
        ylist = [ylist]

    xbin = [10**exp for exp in np.arange(-1.0, 3.1, xstep)]
    last_xbin = [10**exp for exp in np.arange(-1.0, 3.1, xstep)]
    
    ybin = np.arange(ylim[0], ylim[1], binsize)

    plt.cla()
    plt.clf()

    for xbin_left,xbin_right in zip(last_xbin,xbin[1:]):
        fig = plt.figure()
        val_mask = np.logical_and(x > xbin_left, x < xbin_right)

        for y,label in zip(ylist,labels):
            if statistic == 'iqr':
                med = np.median(y[val_mask])
                iqr = np.percentile(y[val_mask], q=84) - np.percentile(y[val_mask], q=16)
                plt.hist(y[val_mask], bins=ybin, density=density, 
                        label = label + ' Median = {:.2f}, IQR = {:.2f}'.format(med, iqr),
                         alpha=alpha)
            elif statistic == 'std':
                mu = np.mean(y[val_mask])
                sig = np.std(y[val_mask])
                plt.hist(y[val_mask], bins=ybin, density=density, 
                        label = label + ' Mean = {:.2f}, Std. Dev. = {:.2f}'.format(mu, sig),
                         alpha=alpha)
            else:
                plt.hist(y[val_mask], bins=ybin, density=density,
                         label = label,
                         alpha=alpha)
            
            if baseline:
                x1 = np.linspace(-6,6,100)
                pdf = stats.norm.pdf(x1)
                plt.plot(x1, pdf, label='Unit Normal')

        if len(textlist) >= 2:
            textlist[1]['text'] = '{:.4g} - {:.4g} GeV Clusters'.format(xbin_left, xbin_right)
            pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

        if logscale:
            plt.yscale('log')

        # plt.title(title + ' {:.4g} - {:.4g} GeV'.format(xbin_left, xbin_right))
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.xlim(ylim)
        plt.legend()
        plt.show()

# %%
import tensorflow_probability as tfp

# %%
def point_mask_fn(X, mask_val=0.):
    return Kb.cast(Kb.any(Kb.not_equal(X, mask_val), axis=-1), Kb.dtype(X))

def convert_to_tensor(X):
    return tf.concat([tfp.distributions.Distribution.mean(X), tfp.distributions.Distribution.stddev(X)],1)

def ParticleFlow_MDN(num_features, name="PFN_MDN_Network"):
    
    event_shape = [1]
    num_components = 3
    params_size = tfp.layers.MixtureNormal.params_size(num_components, event_shape)


    inputs = keras.Input(shape=(None, num_features), name='input')

    dense_0 = layers.Dense(100)
    t_dist_0 = layers.TimeDistributed(dense_0, name='t_dist_0')(inputs)
    activation_0 = layers.Activation('relu', name="activation_0")(t_dist_0)
    
    dense_1 = layers.Dense(100)
    t_dist_1 = layers.TimeDistributed(dense_1, name='t_dist_1')(activation_0)
    activation_1 = layers.Activation('relu', name='activation_1')(t_dist_1)
    
    dense_2 = layers.Dense(128)
    t_dist_2 = layers.TimeDistributed(dense_2, name='t_dist_2')(activation_1)
    activation_2 = layers.Activation('relu', name='activation_2')(t_dist_2)
    
    lambda_layer = layers.Lambda(point_mask_fn, output_shape=(None, None),
                                mask=None,
                                name='mask')(inputs)

    sum_layer = layers.Dot(axes=(1,1), name='sum')([lambda_layer, activation_2])
    
    dense_3 = layers.Dense(100, name='dense_0')(sum_layer)
    activation_3 = layers.Activation('relu', name="activation_3")(dense_3)
    
    dense_4 = layers.Dense(100, name='dense_1')(activation_3)
    activation_4 = layers.Activation('relu', name="activation_4")(dense_4)
    
    dense_5 = layers.Dense(100, name='dense_2')(activation_4)
    activation_5 = layers.Activation('relu', name="activation_5")(dense_5)
    
    dense_6 = layers.Dense(units=params_size, activation=lambda x: tf.clip_by_value(x, -30., 30.))(activation_5)

    
    mdn_0 = tfp.layers.MixtureNormal(num_components, event_shape, validate_args=True,
                                          convert_to_tensor_fn=convert_to_tensor)(dense_6)
    
    return keras.Model(inputs=inputs, outputs=mdn_0, name=name)

# %%
Kb.clear_session()

PFN_mdn = ParticleFlow_MDN(num_features=5)
PFN_mdn.compile(optimizer = netOpt, loss="mse")
PFN_mdn.summary()
# Out:
# Model: "PFN_MDN_Network"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 5)]    0
# __________________________________________________________________________________________________
# t_dist_0 (TimeDistributed)      (None, None, 100)    600         input[0][0]
# __________________________________________________________________________________________________
# activation_0 (Activation)       (None, None, 100)    0           t_dist_0[0][0]
# __________________________________________________________________________________________________
# t_dist_1 (TimeDistributed)      (None, None, 100)    10100       activation_0[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           t_dist_1[0][0]
# __________________________________________________________________________________________________
# t_dist_2 (TimeDistributed)      (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           t_dist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 9)            909         activation_5[0][0]
# __________________________________________________________________________________________________
# mixture_normal (MixtureNormal)  multiple             0           dense_3[0][0]
# ==================================================================================================
# Total params: 57,637
# Trainable params: 57,637
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(PFN_mdn, show_shapes=True, show_layer_names=True,)

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('PFN_MDN_regressor_weight_1.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=150, verbose=0, restore_best_weights=True)
t0 = t.time()
history_ct = PFN_mdn.fit(x_train, y_train,
        epochs=1000,
        batch_size=800,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=[chkpoint, earlystop])
t1 = t.time()
# Out:
# Epoch 1/1000
# 116/116 [==============================] - 12s 75ms/step - loss: 3.0769 - val_loss: 0.3696
#
# Epoch 00001: val_loss improved from inf to 0.36958, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 2/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.2674 - val_loss: 0.1393
#
# Epoch 00002: val_loss improved from 0.36958 to 0.13935, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 3/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.1913 - val_loss: 0.1353
#
# Epoch 00003: val_loss improved from 0.13935 to 0.13528, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 4/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0852 - val_loss: 0.0594
#
# Epoch 00004: val_loss improved from 0.13528 to 0.05941, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 5/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0577 - val_loss: 0.0466
#
# Epoch 00005: val_loss improved from 0.05941 to 0.04664, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 6/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0471 - val_loss: 0.0679
#
# Epoch 00006: val_loss did not improve from 0.04664
# Epoch 7/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0417 - val_loss: 0.0431
#
# Epoch 00007: val_loss improved from 0.04664 to 0.04310, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 8/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0473 - val_loss: 0.0485
#
# Epoch 00008: val_loss did not improve from 0.04310
# Epoch 9/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0390 - val_loss: 0.0718
#
# Epoch 00009: val_loss did not improve from 0.04310
# Epoch 10/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0400 - val_loss: 0.0484
#
# Epoch 00010: val_loss did not improve from 0.04310
# Epoch 11/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0426 - val_loss: 0.0649
#
# Epoch 00011: val_loss did not improve from 0.04310
# Epoch 12/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0341 - val_loss: 0.0317
#
# Epoch 00012: val_loss improved from 0.04310 to 0.03173, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 13/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0345 - val_loss: 0.0336
#
# Epoch 00013: val_loss did not improve from 0.03173
# Epoch 14/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0358 - val_loss: 0.0317
#
# Epoch 00014: val_loss did not improve from 0.03173
# Epoch 15/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0313 - val_loss: 0.0308
#
# Epoch 00015: val_loss improved from 0.03173 to 0.03085, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 16/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0325 - val_loss: 0.0301
#
# Epoch 00016: val_loss improved from 0.03085 to 0.03013, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 17/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0287 - val_loss: 0.0283
#
# Epoch 00017: val_loss improved from 0.03013 to 0.02827, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 18/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0434 - val_loss: 0.0292
#
# Epoch 00018: val_loss did not improve from 0.02827
# Epoch 19/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0292 - val_loss: 0.0272
#
# Epoch 00019: val_loss improved from 0.02827 to 0.02721, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 20/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0291 - val_loss: 0.0325
#
# Epoch 00020: val_loss did not improve from 0.02721
# Epoch 21/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0315 - val_loss: 0.0397
#
# Epoch 00021: val_loss did not improve from 0.02721
# Epoch 22/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0273 - val_loss: 0.0258
#
# Epoch 00022: val_loss improved from 0.02721 to 0.02579, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 23/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0272 - val_loss: 0.0278
#
# Epoch 00023: val_loss did not improve from 0.02579
# Epoch 24/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0303 - val_loss: 0.0273
#
# Epoch 00024: val_loss did not improve from 0.02579
# Epoch 25/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0262 - val_loss: 0.1348
#
# Epoch 00025: val_loss did not improve from 0.02579
# Epoch 26/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0324 - val_loss: 0.0239
#
# Epoch 00026: val_loss improved from 0.02579 to 0.02391, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 27/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0233 - val_loss: 0.0263
#
# Epoch 00027: val_loss did not improve from 0.02391
# Epoch 28/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0263 - val_loss: 0.0269
#
# Epoch 00028: val_loss did not improve from 0.02391
# Epoch 29/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0254 - val_loss: 0.0263
#
# Epoch 00029: val_loss did not improve from 0.02391
# Epoch 30/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0221 - val_loss: 0.0225
#
# Epoch 00030: val_loss improved from 0.02391 to 0.02253, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 31/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0266 - val_loss: 0.0247
#
# Epoch 00031: val_loss did not improve from 0.02253
# Epoch 32/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0241 - val_loss: 0.0244
#
# Epoch 00032: val_loss did not improve from 0.02253
# Epoch 33/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0236 - val_loss: 0.0219
#
# Epoch 00033: val_loss improved from 0.02253 to 0.02189, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 34/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0231 - val_loss: 0.0236
#
# Epoch 00034: val_loss did not improve from 0.02189
# Epoch 35/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0208 - val_loss: 0.0205
#
# Epoch 00035: val_loss improved from 0.02189 to 0.02052, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 36/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0208 - val_loss: 0.0562
#
# Epoch 00036: val_loss did not improve from 0.02052
# Epoch 37/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0252 - val_loss: 0.0255
#
# Epoch 00037: val_loss did not improve from 0.02052
# Epoch 38/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0199 - val_loss: 0.0194
#
# Epoch 00038: val_loss improved from 0.02052 to 0.01937, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 39/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0187 - val_loss: 0.0223
#
# Epoch 00039: val_loss did not improve from 0.01937
# Epoch 40/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0193 - val_loss: 0.0193
#
# Epoch 00040: val_loss improved from 0.01937 to 0.01930, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 41/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0177 - val_loss: 0.0191
#
# Epoch 00041: val_loss improved from 0.01930 to 0.01908, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 42/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0173 - val_loss: 0.0191
#
# Epoch 00042: val_loss did not improve from 0.01908
# Epoch 43/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0203 - val_loss: 0.0187
#
# Epoch 00043: val_loss improved from 0.01908 to 0.01867, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 44/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0176 - val_loss: 0.0208
#
# Epoch 00044: val_loss did not improve from 0.01867
# Epoch 45/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0169 - val_loss: 0.0184
#
# Epoch 00045: val_loss improved from 0.01867 to 0.01838, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 46/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0171 - val_loss: 0.0171
#
# Epoch 00046: val_loss improved from 0.01838 to 0.01706, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 47/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0169 - val_loss: 0.0217
#
# Epoch 00047: val_loss did not improve from 0.01706
# Epoch 48/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0181 - val_loss: 0.0203
#
# Epoch 00048: val_loss did not improve from 0.01706
# Epoch 49/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0168 - val_loss: 0.0169
#
# Epoch 00049: val_loss improved from 0.01706 to 0.01686, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 50/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0173 - val_loss: 0.0168
#
# Epoch 00050: val_loss improved from 0.01686 to 0.01684, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 51/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0170 - val_loss: 0.0197
#
# Epoch 00051: val_loss did not improve from 0.01684
# Epoch 52/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0157 - val_loss: 0.0183
#
# Epoch 00052: val_loss did not improve from 0.01684
# Epoch 53/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0149 - val_loss: 0.0169
#
# Epoch 00053: val_loss did not improve from 0.01684
# Epoch 54/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0156 - val_loss: 0.0196
#
# Epoch 00054: val_loss did not improve from 0.01684
# Epoch 55/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0153 - val_loss: 0.0179
#
# Epoch 00055: val_loss did not improve from 0.01684
# Epoch 56/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0141 - val_loss: 0.0184
#
# Epoch 00056: val_loss did not improve from 0.01684
# Epoch 57/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0154 - val_loss: 0.0222
#
# Epoch 00057: val_loss did not improve from 0.01684
# Epoch 58/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0148 - val_loss: 0.0159
#
# Epoch 00058: val_loss improved from 0.01684 to 0.01590, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 59/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0158 - val_loss: 0.0202
#
# Epoch 00059: val_loss did not improve from 0.01590
# Epoch 60/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0140 - val_loss: 0.0166
#
# Epoch 00060: val_loss did not improve from 0.01590
# Epoch 61/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0153 - val_loss: 0.0153
#
# Epoch 00061: val_loss improved from 0.01590 to 0.01532, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 62/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0141 - val_loss: 0.0180
#
# Epoch 00062: val_loss did not improve from 0.01532
# Epoch 63/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0151 - val_loss: 0.0139
#
# Epoch 00063: val_loss improved from 0.01532 to 0.01390, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 64/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0150 - val_loss: 0.0171
#
# Epoch 00064: val_loss did not improve from 0.01390
# Epoch 65/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0137 - val_loss: 0.0143
#
# Epoch 00065: val_loss did not improve from 0.01390
# Epoch 66/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0139 - val_loss: 0.0216
#
# Epoch 00066: val_loss did not improve from 0.01390
# Epoch 67/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0145 - val_loss: 0.0169
#
# Epoch 00067: val_loss did not improve from 0.01390
# Epoch 68/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0125 - val_loss: 0.0160
#
# Epoch 00068: val_loss did not improve from 0.01390
# Epoch 69/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0132 - val_loss: 0.0148
#
# Epoch 00069: val_loss did not improve from 0.01390
# Epoch 70/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0124 - val_loss: 0.0152
#
# Epoch 00070: val_loss did not improve from 0.01390
# Epoch 71/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0123 - val_loss: 0.0132
#
# Epoch 00071: val_loss improved from 0.01390 to 0.01318, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 72/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0134 - val_loss: 0.0199
#
# Epoch 00072: val_loss did not improve from 0.01318
# Epoch 73/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0121 - val_loss: 0.0140
#
# Epoch 00073: val_loss did not improve from 0.01318
# Epoch 74/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0132 - val_loss: 0.0134
#
# Epoch 00074: val_loss did not improve from 0.01318
# Epoch 75/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0124 - val_loss: 0.0178
#
# Epoch 00075: val_loss did not improve from 0.01318
# Epoch 76/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0119 - val_loss: 0.0154
#
# Epoch 00076: val_loss did not improve from 0.01318
# Epoch 77/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0120 - val_loss: 0.0150
#
# Epoch 00077: val_loss did not improve from 0.01318
# Epoch 78/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0114 - val_loss: 0.0126
#
# Epoch 00078: val_loss improved from 0.01318 to 0.01265, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 79/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0112 - val_loss: 0.0128
#
# Epoch 00079: val_loss did not improve from 0.01265
# Epoch 80/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0135 - val_loss: 0.0126
#
# Epoch 00080: val_loss improved from 0.01265 to 0.01259, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 81/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0116 - val_loss: 0.0115
#
# Epoch 00081: val_loss improved from 0.01259 to 0.01152, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 82/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0100 - val_loss: 0.0120
#
# Epoch 00082: val_loss did not improve from 0.01152
# Epoch 83/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0110 - val_loss: 0.0118
#
# Epoch 00083: val_loss did not improve from 0.01152
# Epoch 84/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0108 - val_loss: 0.0123
#
# Epoch 00084: val_loss did not improve from 0.01152
# Epoch 85/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0113 - val_loss: 0.0124
#
# Epoch 00085: val_loss did not improve from 0.01152
# Epoch 86/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0103 - val_loss: 0.0118
#
# Epoch 00086: val_loss did not improve from 0.01152
# Epoch 87/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0108 - val_loss: 0.0106
#
# Epoch 00087: val_loss improved from 0.01152 to 0.01055, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 88/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0105 - val_loss: 0.0108
#
# Epoch 00088: val_loss did not improve from 0.01055
# Epoch 89/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0106 - val_loss: 0.0105
#
# Epoch 00089: val_loss improved from 0.01055 to 0.01049, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 90/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0104 - val_loss: 0.0107
#
# Epoch 00090: val_loss did not improve from 0.01049
# Epoch 91/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0105 - val_loss: 0.0114
#
# Epoch 00091: val_loss did not improve from 0.01049
# Epoch 92/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0086 - val_loss: 0.0120
#
# Epoch 00092: val_loss did not improve from 0.01049
# Epoch 93/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0094 - val_loss: 0.0104
#
# Epoch 00093: val_loss improved from 0.01049 to 0.01036, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 94/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0087 - val_loss: 0.0115
#
# Epoch 00094: val_loss did not improve from 0.01036
# Epoch 95/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0098 - val_loss: 0.0103
#
# Epoch 00095: val_loss improved from 0.01036 to 0.01027, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 96/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0094 - val_loss: 0.0091
#
# Epoch 00096: val_loss improved from 0.01027 to 0.00906, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 97/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0085 - val_loss: 0.0105
#
# Epoch 00097: val_loss did not improve from 0.00906
# Epoch 98/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0089 - val_loss: 0.0160
#
# Epoch 00098: val_loss did not improve from 0.00906
# Epoch 99/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0098 - val_loss: 0.0150
#
# Epoch 00099: val_loss did not improve from 0.00906
# Epoch 100/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0096 - val_loss: 0.0108
#
# Epoch 00100: val_loss did not improve from 0.00906
# Epoch 101/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0084 - val_loss: 0.0118
#
# Epoch 00101: val_loss did not improve from 0.00906
# Epoch 102/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0099 - val_loss: 0.0105
#
# Epoch 00102: val_loss did not improve from 0.00906
# Epoch 103/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0089 - val_loss: 0.0092
#
# Epoch 00103: val_loss did not improve from 0.00906
# Epoch 104/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0074 - val_loss: 0.0097
#
# Epoch 00104: val_loss did not improve from 0.00906
# Epoch 105/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0079 - val_loss: 0.0114
#
# Epoch 00105: val_loss did not improve from 0.00906
# Epoch 106/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0082 - val_loss: 0.0122
#
# Epoch 00106: val_loss did not improve from 0.00906
# Epoch 107/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0086 - val_loss: 0.0093
#
# Epoch 00107: val_loss did not improve from 0.00906
# Epoch 108/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0078 - val_loss: 0.0090
#
# Epoch 00108: val_loss improved from 0.00906 to 0.00903, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 109/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0079
#
# Epoch 00109: val_loss improved from 0.00903 to 0.00790, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 110/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0100
#
# Epoch 00110: val_loss did not improve from 0.00790
# Epoch 111/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0074 - val_loss: 0.0107
#
# Epoch 00111: val_loss did not improve from 0.00790
# Epoch 112/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0076 - val_loss: 0.0102
#
# Epoch 00112: val_loss did not improve from 0.00790
# Epoch 113/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0077 - val_loss: 0.0097
#
# Epoch 00113: val_loss did not improve from 0.00790
# Epoch 114/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0074 - val_loss: 0.0085
#
# Epoch 00114: val_loss did not improve from 0.00790
# Epoch 115/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0091
#
# Epoch 00115: val_loss did not improve from 0.00790
# Epoch 116/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0093
#
# Epoch 00116: val_loss did not improve from 0.00790
# Epoch 117/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0070 - val_loss: 0.0093
#
# Epoch 00117: val_loss did not improve from 0.00790
# Epoch 118/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0091 - val_loss: 0.0116
#
# Epoch 00118: val_loss did not improve from 0.00790
# Epoch 119/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0095 - val_loss: 0.0085
#
# Epoch 00119: val_loss did not improve from 0.00790
# Epoch 120/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0077 - val_loss: 0.0083
#
# Epoch 00120: val_loss did not improve from 0.00790
# Epoch 121/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0071 - val_loss: 0.0086
#
# Epoch 00121: val_loss did not improve from 0.00790
# Epoch 122/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0067 - val_loss: 0.0101
#
# Epoch 00122: val_loss did not improve from 0.00790
# Epoch 123/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0069 - val_loss: 0.0083
#
# Epoch 00123: val_loss did not improve from 0.00790
# Epoch 124/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0073 - val_loss: 0.0088
#
# Epoch 00124: val_loss did not improve from 0.00790
# Epoch 125/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0070 - val_loss: 0.0082
#
# Epoch 00125: val_loss did not improve from 0.00790
# Epoch 126/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0083 - val_loss: 0.0080
#
# Epoch 00126: val_loss did not improve from 0.00790
# Epoch 127/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0067 - val_loss: 0.0083
#
# Epoch 00127: val_loss did not improve from 0.00790
# Epoch 128/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0062 - val_loss: 0.0083
#
# Epoch 00128: val_loss did not improve from 0.00790
# Epoch 129/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0080
#
# Epoch 00129: val_loss did not improve from 0.00790
# Epoch 130/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0072 - val_loss: 0.0092
#
# Epoch 00130: val_loss did not improve from 0.00790
# Epoch 131/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0083
#
# Epoch 00131: val_loss did not improve from 0.00790
# Epoch 132/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0066 - val_loss: 0.0074
#
# Epoch 00132: val_loss improved from 0.00790 to 0.00742, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 133/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0065 - val_loss: 0.0087
#
# Epoch 00133: val_loss did not improve from 0.00742
# Epoch 134/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0098 - val_loss: 0.0103
#
# Epoch 00134: val_loss did not improve from 0.00742
# Epoch 135/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0075 - val_loss: 0.0090
#
# Epoch 00135: val_loss did not improve from 0.00742
# Epoch 136/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0081 - val_loss: 0.0097
#
# Epoch 00136: val_loss did not improve from 0.00742
# Epoch 137/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0072 - val_loss: 0.0085
#
# Epoch 00137: val_loss did not improve from 0.00742
# Epoch 138/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0065 - val_loss: 0.0072
#
# Epoch 00138: val_loss improved from 0.00742 to 0.00723, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 139/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0082
#
# Epoch 00139: val_loss did not improve from 0.00723
# Epoch 140/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0068 - val_loss: 0.0081
#
# Epoch 00140: val_loss did not improve from 0.00723
# Epoch 141/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0066 - val_loss: 0.0127
#
# Epoch 00141: val_loss did not improve from 0.00723
# Epoch 142/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0068 - val_loss: 0.0083
#
# Epoch 00142: val_loss did not improve from 0.00723
# Epoch 143/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0062 - val_loss: 0.0082
#
# Epoch 00143: val_loss did not improve from 0.00723
# Epoch 144/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0069 - val_loss: 0.0086
#
# Epoch 00144: val_loss did not improve from 0.00723
# Epoch 145/1000
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0060 - val_loss: 0.0077
#
# Epoch 00145: val_loss did not improve from 0.00723
# Epoch 146/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0073
#
# Epoch 00146: val_loss did not improve from 0.00723
# Epoch 147/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0068 - val_loss: 0.0075
#
# Epoch 00147: val_loss did not improve from 0.00723
# Epoch 148/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0081 - val_loss: 0.0088
#
# Epoch 00148: val_loss did not improve from 0.00723
# Epoch 149/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0075 - val_loss: 0.0079
#
# Epoch 00149: val_loss did not improve from 0.00723
# Epoch 150/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0064 - val_loss: 0.0079
#
# Epoch 00150: val_loss did not improve from 0.00723
# Epoch 151/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0079
#
# Epoch 00151: val_loss did not improve from 0.00723
# Epoch 152/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0082
#
# Epoch 00152: val_loss did not improve from 0.00723
# Epoch 153/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0074
#
# Epoch 00153: val_loss did not improve from 0.00723
# Epoch 154/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0071 - val_loss: 0.0092
#
# Epoch 00154: val_loss did not improve from 0.00723
# Epoch 155/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0062 - val_loss: 0.0076
#
# Epoch 00155: val_loss did not improve from 0.00723
# Epoch 156/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0080
#
# Epoch 00156: val_loss did not improve from 0.00723
# Epoch 157/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0064 - val_loss: 0.0072
#
# Epoch 00157: val_loss improved from 0.00723 to 0.00720, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 158/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0072
#
# Epoch 00158: val_loss did not improve from 0.00720
# Epoch 159/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0078
#
# Epoch 00159: val_loss did not improve from 0.00720
# Epoch 160/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0063 - val_loss: 0.0078
#
# Epoch 00160: val_loss did not improve from 0.00720
# Epoch 161/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0073
#
# Epoch 00161: val_loss did not improve from 0.00720
# Epoch 162/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0060 - val_loss: 0.0084
#
# Epoch 00162: val_loss did not improve from 0.00720
# Epoch 163/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0059 - val_loss: 0.0072
#
# Epoch 00163: val_loss improved from 0.00720 to 0.00716, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 164/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0060 - val_loss: 0.0075
#
# Epoch 00164: val_loss did not improve from 0.00716
# Epoch 165/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0074
#
# Epoch 00165: val_loss did not improve from 0.00716
# Epoch 166/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0068
#
# Epoch 00166: val_loss improved from 0.00716 to 0.00685, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 167/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0074
#
# Epoch 00167: val_loss did not improve from 0.00685
# Epoch 168/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0057 - val_loss: 0.0068
#
# Epoch 00168: val_loss improved from 0.00685 to 0.00683, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 169/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0105
#
# Epoch 00169: val_loss did not improve from 0.00683
# Epoch 170/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0106
#
# Epoch 00170: val_loss did not improve from 0.00683
# Epoch 171/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0079
#
# Epoch 00171: val_loss did not improve from 0.00683
# Epoch 172/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0077
#
# Epoch 00172: val_loss did not improve from 0.00683
# Epoch 173/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0061 - val_loss: 0.0087
#
# Epoch 00173: val_loss did not improve from 0.00683
# Epoch 174/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0072 - val_loss: 0.0096
#
# Epoch 00174: val_loss did not improve from 0.00683
# Epoch 175/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0070 - val_loss: 0.0087
#
# Epoch 00175: val_loss did not improve from 0.00683
# Epoch 176/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0065 - val_loss: 0.0097
#
# Epoch 00176: val_loss did not improve from 0.00683
# Epoch 177/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0068 - val_loss: 0.0078
#
# Epoch 00177: val_loss did not improve from 0.00683
# Epoch 178/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0066 - val_loss: 0.0085
#
# Epoch 00178: val_loss did not improve from 0.00683
# Epoch 179/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0060 - val_loss: 0.0117
#
# Epoch 00179: val_loss did not improve from 0.00683
# Epoch 180/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0058 - val_loss: 0.0073
#
# Epoch 00180: val_loss did not improve from 0.00683
# Epoch 181/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0063
#
# Epoch 00181: val_loss improved from 0.00683 to 0.00633, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 182/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0055 - val_loss: 0.0067
#
# Epoch 00182: val_loss did not improve from 0.00633
# Epoch 183/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0075
#
# Epoch 00183: val_loss did not improve from 0.00633
# Epoch 184/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0055 - val_loss: 0.0071
#
# Epoch 00184: val_loss did not improve from 0.00633
# Epoch 185/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0071
#
# Epoch 00185: val_loss did not improve from 0.00633
# Epoch 186/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0073
#
# Epoch 00186: val_loss did not improve from 0.00633
# Epoch 187/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0069
#
# Epoch 00187: val_loss did not improve from 0.00633
# Epoch 188/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0076
#
# Epoch 00188: val_loss did not improve from 0.00633
# Epoch 189/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0075
#
# Epoch 00189: val_loss did not improve from 0.00633
# Epoch 190/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0058 - val_loss: 0.0080
#
# Epoch 00190: val_loss did not improve from 0.00633
# Epoch 191/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0056 - val_loss: 0.0079
#
# Epoch 00191: val_loss did not improve from 0.00633
# Epoch 192/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0069
#
# Epoch 00192: val_loss did not improve from 0.00633
# Epoch 193/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0070
#
# Epoch 00193: val_loss did not improve from 0.00633
# Epoch 194/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0067
#
# Epoch 00194: val_loss did not improve from 0.00633
# Epoch 195/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0077
#
# Epoch 00195: val_loss did not improve from 0.00633
# Epoch 196/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0076
#
# Epoch 00196: val_loss did not improve from 0.00633
# Epoch 197/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0073
#
# Epoch 00197: val_loss did not improve from 0.00633
# Epoch 198/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0079
#
# Epoch 00198: val_loss did not improve from 0.00633
# Epoch 199/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0066
#
# Epoch 00199: val_loss did not improve from 0.00633
# Epoch 200/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0073
#
# Epoch 00200: val_loss did not improve from 0.00633
# Epoch 201/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0061
#
# Epoch 00201: val_loss improved from 0.00633 to 0.00614, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 202/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0052 - val_loss: 0.0070
#
# Epoch 00202: val_loss did not improve from 0.00614
# Epoch 203/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0057 - val_loss: 0.0066
#
# Epoch 00203: val_loss did not improve from 0.00614
# Epoch 204/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0072
#
# Epoch 00204: val_loss did not improve from 0.00614
# Epoch 205/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0055 - val_loss: 0.0074
#
# Epoch 00205: val_loss did not improve from 0.00614
# Epoch 206/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0062
#
# Epoch 00206: val_loss did not improve from 0.00614
# Epoch 207/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0065
#
# Epoch 00207: val_loss did not improve from 0.00614
# Epoch 208/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0073 - val_loss: 0.0076
#
# Epoch 00208: val_loss did not improve from 0.00614
# Epoch 209/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0084 - val_loss: 0.0111
#
# Epoch 00209: val_loss did not improve from 0.00614
# Epoch 210/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0069 - val_loss: 0.0072
#
# Epoch 00210: val_loss did not improve from 0.00614
# Epoch 211/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0059 - val_loss: 0.0081
#
# Epoch 00211: val_loss did not improve from 0.00614
# Epoch 212/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0082
#
# Epoch 00212: val_loss did not improve from 0.00614
# Epoch 213/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0069
#
# Epoch 00213: val_loss did not improve from 0.00614
# Epoch 214/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0056 - val_loss: 0.0062
#
# Epoch 00214: val_loss did not improve from 0.00614
# Epoch 215/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0050 - val_loss: 0.0073
#
# Epoch 00215: val_loss did not improve from 0.00614
# Epoch 216/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0076
#
# Epoch 00216: val_loss did not improve from 0.00614
# Epoch 217/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0066
#
# Epoch 00217: val_loss did not improve from 0.00614
# Epoch 218/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0075
#
# Epoch 00218: val_loss did not improve from 0.00614
# Epoch 219/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0067
#
# Epoch 00219: val_loss did not improve from 0.00614
# Epoch 220/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0066
#
# Epoch 00220: val_loss did not improve from 0.00614
# Epoch 221/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0050 - val_loss: 0.0070
#
# Epoch 00221: val_loss did not improve from 0.00614
# Epoch 222/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0075
#
# Epoch 00222: val_loss did not improve from 0.00614
# Epoch 223/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0066
#
# Epoch 00223: val_loss did not improve from 0.00614
# Epoch 224/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0056 - val_loss: 0.0066
#
# Epoch 00224: val_loss did not improve from 0.00614
# Epoch 225/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0088
#
# Epoch 00225: val_loss did not improve from 0.00614
# Epoch 226/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0054 - val_loss: 0.0067
#
# Epoch 00226: val_loss did not improve from 0.00614
# Epoch 227/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0061
#
# Epoch 00227: val_loss improved from 0.00614 to 0.00610, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 228/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0087
#
# Epoch 00228: val_loss did not improve from 0.00610
# Epoch 229/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00229: val_loss did not improve from 0.00610
# Epoch 230/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0071
#
# Epoch 00230: val_loss did not improve from 0.00610
# Epoch 231/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00231: val_loss did not improve from 0.00610
# Epoch 232/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0060
#
# Epoch 00232: val_loss improved from 0.00610 to 0.00597, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 233/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0076
#
# Epoch 00233: val_loss did not improve from 0.00597
# Epoch 234/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0057
#
# Epoch 00234: val_loss improved from 0.00597 to 0.00570, saving model to PFN_MDN_regressor_weight_1.h5
# Epoch 235/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0064
#
# Epoch 00235: val_loss did not improve from 0.00570
# Epoch 236/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0063
#
# Epoch 00236: val_loss did not improve from 0.00570
# Epoch 237/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0059
#
# Epoch 00237: val_loss did not improve from 0.00570
# Epoch 238/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0054 - val_loss: 0.0064
#
# Epoch 00238: val_loss did not improve from 0.00570
# Epoch 239/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0077
#
# Epoch 00239: val_loss did not improve from 0.00570
# Epoch 240/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0057 - val_loss: 0.0072
#
# Epoch 00240: val_loss did not improve from 0.00570
# Epoch 241/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0050 - val_loss: 0.0069
#
# Epoch 00241: val_loss did not improve from 0.00570
# Epoch 242/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0071
#
# Epoch 00242: val_loss did not improve from 0.00570
# Epoch 243/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0052 - val_loss: 0.0065
#
# Epoch 00243: val_loss did not improve from 0.00570
# Epoch 244/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0073
#
# Epoch 00244: val_loss did not improve from 0.00570
# Epoch 245/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0049 - val_loss: 0.0076
#
# Epoch 00245: val_loss did not improve from 0.00570
# Epoch 246/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0067
#
# Epoch 00246: val_loss did not improve from 0.00570
# Epoch 247/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00247: val_loss did not improve from 0.00570
# Epoch 248/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0073
#
# Epoch 00248: val_loss did not improve from 0.00570
# Epoch 249/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0069
#
# Epoch 00249: val_loss did not improve from 0.00570
# Epoch 250/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0046 - val_loss: 0.0066
#
# Epoch 00250: val_loss did not improve from 0.00570
# Epoch 251/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0047 - val_loss: 0.0070
#
# Epoch 00251: val_loss did not improve from 0.00570
# Epoch 252/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0046 - val_loss: 0.0065
#
# Epoch 00252: val_loss did not improve from 0.00570
# Epoch 253/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0094
#
# Epoch 00253: val_loss did not improve from 0.00570
# Epoch 254/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0073
#
# Epoch 00254: val_loss did not improve from 0.00570
# Epoch 255/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00255: val_loss did not improve from 0.00570
# Epoch 256/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0053 - val_loss: 0.0058
#
# Epoch 00256: val_loss did not improve from 0.00570
# Epoch 257/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0049 - val_loss: 0.0077
#
# Epoch 00257: val_loss did not improve from 0.00570
# Epoch 258/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0060
#
# Epoch 00258: val_loss did not improve from 0.00570
# Epoch 259/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0057
#
# Epoch 00259: val_loss did not improve from 0.00570
# Epoch 260/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0048 - val_loss: 0.0058
#
# Epoch 00260: val_loss did not improve from 0.00570
# Epoch 261/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0074
#
# Epoch 00261: val_loss did not improve from 0.00570
# Epoch 262/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0052 - val_loss: 0.0080
#
# Epoch 00262: val_loss did not improve from 0.00570
# Epoch 263/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00263: val_loss did not improve from 0.00570
# Epoch 264/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0047 - val_loss: 0.0069
#
# Epoch 00264: val_loss did not improve from 0.00570
# Epoch 265/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0049 - val_loss: 0.0083
#
# Epoch 00265: val_loss did not improve from 0.00570
# Epoch 266/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0065
#
# Epoch 00266: val_loss did not improve from 0.00570
# Epoch 267/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0046 - val_loss: 0.0068
#
# Epoch 00267: val_loss did not improve from 0.00570
# Epoch 268/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0074
#
# Epoch 00268: val_loss did not improve from 0.00570
# Epoch 269/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0051 - val_loss: 0.0062
#
# Epoch 00269: val_loss did not improve from 0.00570
# Epoch 270/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0048 - val_loss: 0.0079
#
# Epoch 00270: val_loss did not improve from 0.00570
# Epoch 271/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0053 - val_loss: 0.0096
#
# Epoch 00271: val_loss did not improve from 0.00570
# Epoch 272/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0057 - val_loss: 0.0083
#
# Epoch 00272: val_loss did not improve from 0.00570
# Epoch 273/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0043 - val_loss: 0.0066
#
# Epoch 00273: val_loss did not improve from 0.00570
# Epoch 274/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0044 - val_loss: 0.0078
#
# Epoch 00274: val_loss did not improve from 0.00570
# Epoch 275/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0049 - val_loss: 0.0068
#
# Epoch 00275: val_loss did not improve from 0.00570
# Epoch 276/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0045 - val_loss: 0.0067
#
# Epoch 00276: val_loss did not improve from 0.00570
# Epoch 277/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0043 - val_loss: 0.0071
#
# Epoch 00277: val_loss did not improve from 0.00570
# Epoch 278/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0045 - val_loss: 0.0067
#
# Epoch 00278: val_loss did not improve from 0.00570
# Epoch 279/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0041 - val_loss: 0.0083
#
# Epoch 00279: val_loss did not improve from 0.00570
# Epoch 280/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0044 - val_loss: 0.0088
#
# Epoch 00280: val_loss did not improve from 0.00570
# Epoch 281/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0038 - val_loss: 0.0066
#
# Epoch 00281: val_loss did not improve from 0.00570
# Epoch 282/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0048 - val_loss: 0.0077
#
# Epoch 00282: val_loss did not improve from 0.00570
# Epoch 283/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0041 - val_loss: 0.0076
#
# Epoch 00283: val_loss did not improve from 0.00570
# Epoch 284/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0051 - val_loss: 0.0084
#
# Epoch 00284: val_loss did not improve from 0.00570
# Epoch 285/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0047 - val_loss: 0.0074
#
# Epoch 00285: val_loss did not improve from 0.00570
# Epoch 286/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0055 - val_loss: 0.0121
#
# Epoch 00286: val_loss did not improve from 0.00570
# Epoch 287/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0058 - val_loss: 0.0069
#
# Epoch 00287: val_loss did not improve from 0.00570
# Epoch 288/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0044 - val_loss: 0.0068
#
# Epoch 00288: val_loss did not improve from 0.00570
# Epoch 289/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0046 - val_loss: 0.0066
#
# Epoch 00289: val_loss did not improve from 0.00570
# Epoch 290/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0042 - val_loss: 0.0078
#
# Epoch 00290: val_loss did not improve from 0.00570
# Epoch 291/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0039 - val_loss: 0.0067
#
# Epoch 00291: val_loss did not improve from 0.00570
# Epoch 292/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0035 - val_loss: 0.0060
#
# Epoch 00292: val_loss did not improve from 0.00570
# Epoch 293/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0035 - val_loss: 0.0073
#
# Epoch 00293: val_loss did not improve from 0.00570
# Epoch 294/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0072
#
# Epoch 00294: val_loss did not improve from 0.00570
# Epoch 295/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0069
#
# Epoch 00295: val_loss did not improve from 0.00570
# Epoch 296/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0035 - val_loss: 0.0077
#
# Epoch 00296: val_loss did not improve from 0.00570
# Epoch 297/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0040 - val_loss: 0.0070
#
# Epoch 00297: val_loss did not improve from 0.00570
# Epoch 298/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0036 - val_loss: 0.0077
#
# Epoch 00298: val_loss did not improve from 0.00570
# Epoch 299/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0033 - val_loss: 0.0064
#
# Epoch 00299: val_loss did not improve from 0.00570
# Epoch 300/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0035 - val_loss: 0.0066
#
# Epoch 00300: val_loss did not improve from 0.00570
# Epoch 301/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0034 - val_loss: 0.0071
#
# Epoch 00301: val_loss did not improve from 0.00570
# Epoch 302/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0037 - val_loss: 0.0143
#
# Epoch 00302: val_loss did not improve from 0.00570
# Epoch 303/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0079 - val_loss: 0.0109
#
# Epoch 00303: val_loss did not improve from 0.00570
# Epoch 304/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0084 - val_loss: 0.0092
#
# Epoch 00304: val_loss did not improve from 0.00570
# Epoch 305/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0063 - val_loss: 0.0080
#
# Epoch 00305: val_loss did not improve from 0.00570
# Epoch 306/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0065 - val_loss: 0.0077
#
# Epoch 00306: val_loss did not improve from 0.00570
# Epoch 307/1000
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0061 - val_loss: 0.0085
#
# Epoch 00307: val_loss did not improve from 0.00570
# Epoch 308/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0053 - val_loss: 0.0072
#
# Epoch 00308: val_loss did not improve from 0.00570
# Epoch 309/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0057 - val_loss: 0.0069
#
# Epoch 00309: val_loss did not improve from 0.00570
# Epoch 310/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0048 - val_loss: 0.0074
#
# Epoch 00310: val_loss did not improve from 0.00570
# Epoch 311/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0050 - val_loss: 0.0071
#
# Epoch 00311: val_loss did not improve from 0.00570
# Epoch 312/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0051 - val_loss: 0.0066
#
# Epoch 00312: val_loss did not improve from 0.00570
# Epoch 313/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0038 - val_loss: 0.0081
#
# Epoch 00313: val_loss did not improve from 0.00570
# Epoch 314/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0039 - val_loss: 0.0062
#
# Epoch 00314: val_loss did not improve from 0.00570
# Epoch 315/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0062
#
# Epoch 00315: val_loss did not improve from 0.00570
# Epoch 316/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0034 - val_loss: 0.0067
#
# Epoch 00316: val_loss did not improve from 0.00570
# Epoch 317/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0057
#
# Epoch 00317: val_loss did not improve from 0.00570
# Epoch 318/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00318: val_loss did not improve from 0.00570
# Epoch 319/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0058
#
# Epoch 00319: val_loss did not improve from 0.00570
# Epoch 320/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0035 - val_loss: 0.0062
#
# Epoch 00320: val_loss did not improve from 0.00570
# Epoch 321/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00321: val_loss did not improve from 0.00570
# Epoch 322/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0065 - val_loss: 0.0083
#
# Epoch 00322: val_loss did not improve from 0.00570
# Epoch 323/1000
# 116/116 [==============================] - 7s 63ms/step - loss: 0.0050 - val_loss: 0.0069
#
# Epoch 00323: val_loss did not improve from 0.00570
# Epoch 324/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0046 - val_loss: 0.0068
#
# Epoch 00324: val_loss did not improve from 0.00570
# Epoch 325/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00325: val_loss did not improve from 0.00570
# Epoch 326/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0038 - val_loss: 0.0063
#
# Epoch 00326: val_loss did not improve from 0.00570
# Epoch 327/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0036 - val_loss: 0.0061
#
# Epoch 00327: val_loss did not improve from 0.00570
# Epoch 328/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00328: val_loss did not improve from 0.00570
# Epoch 329/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00329: val_loss did not improve from 0.00570
# Epoch 330/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0064
#
# Epoch 00330: val_loss did not improve from 0.00570
# Epoch 331/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0067
#
# Epoch 00331: val_loss did not improve from 0.00570
# Epoch 332/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00332: val_loss did not improve from 0.00570
# Epoch 333/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0066
#
# Epoch 00333: val_loss did not improve from 0.00570
# Epoch 334/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0065
#
# Epoch 00334: val_loss did not improve from 0.00570
# Epoch 335/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00335: val_loss did not improve from 0.00570
# Epoch 336/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00336: val_loss did not improve from 0.00570
# Epoch 337/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0074
#
# Epoch 00337: val_loss did not improve from 0.00570
# Epoch 338/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00338: val_loss did not improve from 0.00570
# Epoch 339/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0038 - val_loss: 0.0083
#
# Epoch 00339: val_loss did not improve from 0.00570
# Epoch 340/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0046 - val_loss: 0.0063
#
# Epoch 00340: val_loss did not improve from 0.00570
# Epoch 341/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0040 - val_loss: 0.0078
#
# Epoch 00341: val_loss did not improve from 0.00570
# Epoch 342/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0042 - val_loss: 0.0069
#
# Epoch 00342: val_loss did not improve from 0.00570
# Epoch 343/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0036 - val_loss: 0.0066
#
# Epoch 00343: val_loss did not improve from 0.00570
# Epoch 344/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0038 - val_loss: 0.0086
#
# Epoch 00344: val_loss did not improve from 0.00570
# Epoch 345/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0035 - val_loss: 0.0061
#
# Epoch 00345: val_loss did not improve from 0.00570
# Epoch 346/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00346: val_loss did not improve from 0.00570
# Epoch 347/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00347: val_loss did not improve from 0.00570
# Epoch 348/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0062
#
# Epoch 00348: val_loss did not improve from 0.00570
# Epoch 349/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0040 - val_loss: 0.0078
#
# Epoch 00349: val_loss did not improve from 0.00570
# Epoch 350/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0049 - val_loss: 0.0076
#
# Epoch 00350: val_loss did not improve from 0.00570
# Epoch 351/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0055 - val_loss: 0.0081
#
# Epoch 00351: val_loss did not improve from 0.00570
# Epoch 352/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0042 - val_loss: 0.0063
#
# Epoch 00352: val_loss did not improve from 0.00570
# Epoch 353/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0034 - val_loss: 0.0061
#
# Epoch 00353: val_loss did not improve from 0.00570
# Epoch 354/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0062
#
# Epoch 00354: val_loss did not improve from 0.00570
# Epoch 355/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00355: val_loss did not improve from 0.00570
# Epoch 356/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0030 - val_loss: 0.0070
#
# Epoch 00356: val_loss did not improve from 0.00570
# Epoch 357/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0060
#
# Epoch 00357: val_loss did not improve from 0.00570
# Epoch 358/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0075
#
# Epoch 00358: val_loss did not improve from 0.00570
# Epoch 359/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0067
#
# Epoch 00359: val_loss did not improve from 0.00570
# Epoch 360/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0031 - val_loss: 0.0066
#
# Epoch 00360: val_loss did not improve from 0.00570
# Epoch 361/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0032 - val_loss: 0.0068
#
# Epoch 00361: val_loss did not improve from 0.00570
# Epoch 362/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0034 - val_loss: 0.0066
#
# Epoch 00362: val_loss did not improve from 0.00570
# Epoch 363/1000
# 116/116 [==============================] - 8s 68ms/step - loss: 0.0031 - val_loss: 0.0075
#
# Epoch 00363: val_loss did not improve from 0.00570
# Epoch 364/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0086
#
# Epoch 00364: val_loss did not improve from 0.00570
# Epoch 365/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0033 - val_loss: 0.0063
#
# Epoch 00365: val_loss did not improve from 0.00570
# Epoch 366/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0031 - val_loss: 0.0063
#
# Epoch 00366: val_loss did not improve from 0.00570
# Epoch 367/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0032 - val_loss: 0.0064
#
# Epoch 00367: val_loss did not improve from 0.00570
# Epoch 368/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0033 - val_loss: 0.0070
#
# Epoch 00368: val_loss did not improve from 0.00570
# Epoch 369/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0029 - val_loss: 0.0075
#
# Epoch 00369: val_loss did not improve from 0.00570
# Epoch 370/1000
# 116/116 [==============================] - 8s 66ms/step - loss: 0.0034 - val_loss: 0.0064
#
# Epoch 00370: val_loss did not improve from 0.00570
# Epoch 371/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0032 - val_loss: 0.0070
#
# Epoch 00371: val_loss did not improve from 0.00570
# Epoch 372/1000
# 116/116 [==============================] - 8s 67ms/step - loss: 0.0030 - val_loss: 0.0063
#
# Epoch 00372: val_loss did not improve from 0.00570
# Epoch 373/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0033 - val_loss: 0.0085
#
# Epoch 00373: val_loss did not improve from 0.00570
# Epoch 374/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0064 - val_loss: 0.0113
#
# Epoch 00374: val_loss did not improve from 0.00570
# Epoch 375/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0069 - val_loss: 0.0087
#
# Epoch 00375: val_loss did not improve from 0.00570
# Epoch 376/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0061 - val_loss: 0.0072
#
# Epoch 00376: val_loss did not improve from 0.00570
# Epoch 377/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0052 - val_loss: 0.0079
#
# Epoch 00377: val_loss did not improve from 0.00570
# Epoch 378/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0041 - val_loss: 0.0071
#
# Epoch 00378: val_loss did not improve from 0.00570
# Epoch 379/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0034 - val_loss: 0.0067
#
# Epoch 00379: val_loss did not improve from 0.00570
# Epoch 380/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0030 - val_loss: 0.0071
#
# Epoch 00380: val_loss did not improve from 0.00570
# Epoch 381/1000
# 116/116 [==============================] - 7s 65ms/step - loss: 0.0032 - val_loss: 0.0072
#
# Epoch 00381: val_loss did not improve from 0.00570
# Epoch 382/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0033 - val_loss: 0.0083
#
# Epoch 00382: val_loss did not improve from 0.00570
# Epoch 383/1000
# 116/116 [==============================] - 7s 64ms/step - loss: 0.0031 - val_loss: 0.0074
#
# Epoch 00383: val_loss did not improve from 0.00570
# Epoch 384/1000
# 116/116 [==============================] - 8s 65ms/step - loss: 0.0031 - val_loss: 0.0074
#
# Epoch 00384: val_loss did not improve from 0.00570

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(history_ct.history['val_loss'], label="Validation")
plt.plot(history_ct.history['loss'], label="Training")
plt.yscale('log')
plt.ylim(.001,10)
plt.yticks(fontsize=13)
plt.xlim(0,500)
plt.xticks(fontsize=13)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right', ncol=1)
plt.text(500, 1.5, 'LR=1e-3', fontsize=13)
plt.text(500, 1, 'Batch: 384', fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_lossCurves_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
PFN_mdn.load_weights("PFN_MDN_regressor_weight_1.h5")

# %%
preds = np.exp(PFN_mdn.predict(eval_generator(x_test,500)))
print(preds.shape)
# Out:
# (20598, 2)

# %%
## PREDICTIONS AND TRUTH ##
bins = np.linspace(0,8,50, endpoint=True)
fig = plt.figure(figsize=(6,6))
plt.hist(y_test, color='steelblue', bins=bins, density=True, alpha=.5, edgecolor='black', label='target')
plt.hist(np.log(preds[:,0]), color='coral', bins=bins, density=True, alpha=.5, edgecolor='black', label='network')
plt.title('Regression Output and Target', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(0,8)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(loc='upper left')
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_targetPreds_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
xcenter, medDNN = ru.responsePlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                 atlas_x = 0.46, atlas_y = 0.95, simulation = True,
                 textlist = [{'x': 0.46, 'y': 0.85, 'text': 'Single $\pi^{+}$, Track+Clusters'},
                             {'x': 0.46, 'y': 0.8,  'text': 'keras_pfn_mdn'}])

# %%
xcenter, iqrMDN3 = resolutionPlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                        atlas_x = 0.56, atlas_y = 0.95, simulation = True,
                        textlist = [{'x': 0.56, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
                                    {'x': 0.56, 'y': 0.8,  'text': 'PFN'}])

# %%
resp_plot = ru.resolutionPlot(x=np.exp(y_test), y=preds[:,0]/np.exp(y_test),
                    figfile='',
                    statistic='std', xlabel='Particle Truth Energy', ylabel='Energy IQR over Median',
                    atlas_x=-1, atlas_y=-1, simulation=False,
                    textlist=[])

# %%
resid_DNN = preds[:,0] - np.exp(y_test)

n_bins = 500
plt.cla(); plt.clf()
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.hist(resid_DNN,bins = n_bins,alpha=0.75)
plt.yscale('log')
plt.xlabel('Learned - True Energy')
plt.ylabel('Clusters')
plt.xlim(-3000,3000)
plt.legend()

atlas_x = 0.55
atlas_y = 0.95
simulation = True
textlist = [{'x': 0.55, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
            {'x': 0.55, 'y': 0.8,  'text': 'keras_pfn'}]
pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

plt.show()
