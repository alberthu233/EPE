# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib.colors import LogNorm
import time as t
from time import perf_counter as cput
import scipy.constants as spc
import matplotlib.ticker as ticker

# %%
path_prefix = 'D:/Work/EPE/ML4pi/'
plotpath = path_prefix+'plots/'
modelpath_c = path_prefix+''
modelpath = path_prefix+''
ext_path = "H:/EPE_file_storage/"
ext_modelpath = ext_path + "Model/"
ext_datapath = ext_path + "data_storage/"
ext_plotpath = ext_path + "plots/"

# %%
def tvt_num(_data, _tvt=(75, 10, 15)):
    ''' Function designed to output appropriate numbers for traning validation and testing given
    a variable length input. TVT expressed as ratios and do not need to add to 100. '''
    _tot = len(_data)
    _train, _val, _test = _tvt
    _tvt_sum = _train + _val + _test
    
    _train_rtrn = round(_train*_tot/_tvt_sum)
    _val_rtrn = round(_val*_tot/_tvt_sum)
    _test_rtrn = _tot - _train_rtrn - _val_rtrn
    
    return _train_rtrn, _val_rtrn, _test_rtrn

def normalize_input1d(arr, mask):
    ''' Note that non masked values are left alone i.e. zeros if mask = arr != 0'''
    len_arr = arr.shape[0]
    mean = np.repeat(np.mean(arr, where=mask), len_arr)
    std_dev = np.repeat(np.std(arr, where=mask), len_arr)
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev!=0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

def normalize_input2d(arr, mask):
    ''' Truth value is where to perform the operation, exclude False vals.
    returns: Array with the shape of arr with normalization carried out with mask '''
    len_ax1 = arr.shape[1]
    mean = np.tile(np.mean(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    std_dev = np.tile(np.std(arr, axis=1, where=mask), (len_ax1,1)).transpose()
    norm_arr = np.subtract(arr, mean, out=arr, where=mask)
    std_mask = np.logical_and(std_dev != 0, mask)
    norm_arr = np.divide(norm_arr, std_dev, out=norm_arr, where=std_mask)
    return norm_arr

# %%
import sys
sys.path.append(path_prefix)
from util import resolution_util as ru
from util import plot_util as pu
from util import ml_util as mu
import uproot3 as ur

# %%
stmc = np.load(ext_datapath + "STMC_0.npz")

# %%
t0 = t.time()
# load data from NpzFile
Xraw = stmc.f.x
Yraw = stmc.f.y

# load spcific amount of events from raw
X = Xraw[:200000,:,:5]
Y = Yraw[:200000]
print(X.shape)
print(Y.shape)
t1 = t.time()
print('Time to load and copy arrays: '+str(t1-t0)+' (s)')
# Out:
# (41196, 1086, 5)
# (41196, 3)
# Time to load and copy arrays: 21.075153350830078 (s)

# %%
# for PFN approach Y normalization
# the target energy values
# target_zero_mask, Y : 0 for truthPartE, 1 for truthTrackPt, 2 for cluster_eng_clib_tot
target_zero_mask = Y[:,0] > .05
Ylog = np.log(Y[target_zero_mask,0])
print('Any targets below 50 GeV: '+str(np.count_nonzero(np.invert(target_zero_mask))))
print('Number of events: '+str(len(Y)))
# Out:
# Any targets below 50 GeV: 0
# Number of events: 41196

# %%
# for pfn approach X normalization
# X = [Energy, Eta, Phi, rPerp, Track Flag, Layer]

## Normalize rPerp to 1/3630
rPerp_mask = X[:,:,3] != 0
X[:,:,3][rPerp_mask] = X[:,:,3][rPerp_mask]/3630.

## Energy Values that are not zero!
E_nonZeroMask = X[:,:,0] != 0
X[:,:,0][E_nonZeroMask] = np.log(X[:,:,0][E_nonZeroMask])
cellE_mean = np.mean(X[:,:,0][E_nonZeroMask])
cellE_std = np.std(X[:,:,0][E_nonZeroMask])
X[:,:,0][E_nonZeroMask] = (X[:,:,0][E_nonZeroMask] - cellE_mean)/cellE_std

## Eta and Phi
# do nothing for now as a control and check performance
eta_mask = X[:,:,1] != 0
X[:,:,1][eta_mask] = X[:,:,1][eta_mask]/.7

phi_mask = X[:,:,2] != 0
cellPhi_std = np.std(X[:,:,2][phi_mask])
X[:,:,2][phi_mask] = X[:,:,2][phi_mask]/cellPhi_std

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import Sequential
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Lambda
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.models import load_model
import keras.backend as Kb
import tensorflow_probability as tfp

# %%
def convert_to_tensor(X):
    return tf.concat([tfp.distributions.Distribution.mean(X), tfp.distributions.Distribution.stddev(X)],1)

def ParticleFlow_MDN(num_compo,num_features, name="PFN_MDN_Network"):
    
    event_shape = [1]
    num_components = num_compo
    params_size = tfp.layers.MixtureNormal.params_size(num_components, event_shape)


    inputs = keras.Input(shape=(None, num_features), name='input')

    dense_0 = layers.Dense(100)
    t_dist_0 = layers.TimeDistributed(dense_0, name='t_dist_0')(inputs)
    activation_0 = layers.Activation('relu', name="activation_0")(t_dist_0)
    
    dense_1 = layers.Dense(100)
    t_dist_1 = layers.TimeDistributed(dense_1, name='t_dist_1')(activation_0)
    activation_1 = layers.Activation('relu', name='activation_1')(t_dist_1)
    
    dense_2 = layers.Dense(128)
    t_dist_2 = layers.TimeDistributed(dense_2, name='t_dist_2')(activation_1)
    activation_2 = layers.Activation('relu', name='activation_2')(t_dist_2)
    
    masking_layer = layers.Masking(mask_value=0.0)
    
    lambda_layer = layers.Lambda(lambda X: Kb.cast(Kb.any(Kb.not_equal(X, 0.0), axis=-1), Kb.dtype(X)), output_shape=(None, None),
                                mask=None,
                                name='mask')(inputs)

    sum_layer = layers.Dot(axes=(1,1), name='sum')([lambda_layer, activation_2])
    
    dense_3 = layers.Dense(100, name='dense_0')(sum_layer)
    activation_3 = layers.Activation('relu', name="activation_3")(dense_3)
    
    dense_4 = layers.Dense(100, name='dense_1')(activation_3)
    activation_4 = layers.Activation('relu', name="activation_4")(dense_4)
    
    dense_5 = layers.Dense(100, name='dense_2')(activation_4)
    activation_5 = layers.Activation('relu', name="activation_5")(dense_5)
    
    dense_6 = layers.Dense(units=params_size, activation=lambda x: tf.clip_by_value(x, -30., 30.))(activation_5)

    
    mdn_0 = tfp.layers.MixtureNormal(num_components, event_shape, validate_args=True,
                                          convert_to_tensor_fn=convert_to_tensor)(dense_6)
    
    return keras.Model(inputs=inputs, outputs=mdn_0, name=name)

# %%
# EFN regression example uses 75/10/15 split for 100,000 samples
train, val, test = tvt_num(X, _tvt=(90, 10, 0))
print('train -- val -- test')
print(str(train)+' -- '+str(val)+' -- '+str(test))

# network architecture parameters
Phi_sizes, F_sizes = (100, 100, 128), (100, 100, 100)
output_act, output_dim = 'linear', 1
loss = 'mse'

# network training parameters
num_epoch = 1500
batch_size = 1000

netOpt = tf.keras.optimizers.Adam(learning_rate=0.001)
RMS_prop = tf.keras.optimizers.RMSprop(learning_rate=0.001)
# Out:
# train -- val -- test
# 37076 -- 4120 -- 0

# %%
import energyflow as ef

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, Y))
(x_train, x_val, x_test,
 y_train, y_val, y_test) = ef.utils.data_split(X, Ylog, val=val, test=test)

# Print out tensor shapes
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (37076, 1086, 5)
# (37076,)

# %%
Kb.clear_session()

model = ParticleFlow_MDN(num_compo=5,num_features=5)
model.summary()
model.compile(optimizer = netOpt, loss="mse")
# Out:
# Model: "PFN_MDN_Network"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, 5)]    0
# __________________________________________________________________________________________________
# t_dist_0 (TimeDistributed)      (None, None, 100)    600         input[0][0]
# __________________________________________________________________________________________________
# activation_0 (Activation)       (None, None, 100)    0           t_dist_0[0][0]
# __________________________________________________________________________________________________
# t_dist_1 (TimeDistributed)      (None, None, 100)    10100       activation_0[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 100)    0           t_dist_1[0][0]
# __________________________________________________________________________________________________
# t_dist_2 (TimeDistributed)      (None, None, 128)    12928       activation_1[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 128)    0           t_dist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 15)           1515        activation_5[0][0]
# __________________________________________________________________________________________________
# mixture_normal (MixtureNormal)  multiple             0           dense_3[0][0]
# ==================================================================================================
# Total params: 58,243
# Trainable params: 58,243
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
chkpoint = tf.keras.callbacks.ModelCheckpoint('pfn_mdn_regressor0.h5', monitor='val_loss', verbose=0, save_best_only=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=500, verbose=0, restore_best_weights=True)
t0 = t.time()
history_ct = model.fit(x_train, y_train,
        epochs=1500,
        batch_size=200,
        validation_data=(x_val, y_val),
        verbose=1,
        callbacks=[chkpoint, earlystop])
t1 = t.time()
# Out:
# Epoch 1/1500
# 186/186 [==============================] - 3s 15ms/step - loss: 0.0368 - val_loss: 0.0372
# Epoch 2/1500
# 186/186 [==============================] - 3s 15ms/step - loss: 0.0338 - val_loss: 0.0350
# Epoch 3/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0290 - val_loss: 0.0353
# Epoch 4/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0268 - val_loss: 0.0256
# Epoch 5/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0243 - val_loss: 0.0246
# Epoch 6/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0214 - val_loss: 0.0242
# Epoch 7/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0227 - val_loss: 0.0264
# Epoch 8/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0216 - val_loss: 0.0215
# Epoch 9/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0199 - val_loss: 0.0188
# Epoch 10/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0224 - val_loss: 0.0261
# Epoch 11/1500
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0212 - val_loss: 0.0210
# Epoch 12/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0179 - val_loss: 0.0145
# Epoch 13/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0177 - val_loss: 0.0156
# Epoch 14/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0203 - val_loss: 0.0204
# Epoch 15/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0174 - val_loss: 0.0165
# Epoch 16/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0165 - val_loss: 0.0208
# Epoch 17/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0168 - val_loss: 0.0145
# Epoch 18/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0181 - val_loss: 0.0212
# Epoch 19/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0178 - val_loss: 0.0141
# Epoch 20/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0162 - val_loss: 0.0137
# Epoch 21/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0159 - val_loss: 0.0147
# Epoch 22/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0158 - val_loss: 0.0132
# Epoch 23/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0167 - val_loss: 0.0124
# Epoch 24/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0158 - val_loss: 0.0126
# Epoch 25/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0160 - val_loss: 0.0245
# Epoch 26/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0159 - val_loss: 0.0124
# Epoch 27/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0152 - val_loss: 0.0120
# Epoch 28/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0136 - val_loss: 0.0108
# Epoch 29/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0151 - val_loss: 0.0109
# Epoch 30/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0167 - val_loss: 0.0185
# Epoch 31/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0135 - val_loss: 0.0107
# Epoch 32/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0143
# Epoch 33/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0148 - val_loss: 0.0146
# Epoch 34/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0131 - val_loss: 0.0093
# Epoch 35/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0139 - val_loss: 0.0114
# Epoch 36/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 37/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0166 - val_loss: 0.0115
# Epoch 38/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0139 - val_loss: 0.0104
# Epoch 39/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0133 - val_loss: 0.0111
# Epoch 40/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0130 - val_loss: 0.0179
# Epoch 41/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0142 - val_loss: 0.0106
# Epoch 42/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0131 - val_loss: 0.0153
# Epoch 43/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 44/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0125 - val_loss: 0.0091
# Epoch 45/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0114 - val_loss: 0.0105
# Epoch 46/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0130 - val_loss: 0.0088
# Epoch 47/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0118 - val_loss: 0.0102
# Epoch 48/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0134 - val_loss: 0.0091
# Epoch 49/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 50/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0132 - val_loss: 0.0078
# Epoch 51/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0105 - val_loss: 0.0099
# Epoch 52/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0110 - val_loss: 0.0087
# Epoch 53/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0107 - val_loss: 0.0082
# Epoch 54/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0109 - val_loss: 0.0180
# Epoch 55/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0100 - val_loss: 0.0076
# Epoch 56/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0114 - val_loss: 0.0087
# Epoch 57/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0104 - val_loss: 0.0095
# Epoch 58/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0096 - val_loss: 0.0074
# Epoch 59/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0107 - val_loss: 0.0079
# Epoch 60/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0108 - val_loss: 0.0085
# Epoch 61/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0095 - val_loss: 0.0065
# Epoch 62/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0090 - val_loss: 0.0069
# Epoch 63/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0087 - val_loss: 0.0095
# Epoch 64/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0100 - val_loss: 0.0069
# Epoch 65/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0089 - val_loss: 0.0120
# Epoch 66/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0090 - val_loss: 0.0067
# Epoch 67/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0086 - val_loss: 0.0067
# Epoch 68/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0081 - val_loss: 0.0064
# Epoch 69/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0089 - val_loss: 0.0116
# Epoch 70/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0079 - val_loss: 0.0055
# Epoch 71/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 72/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0078 - val_loss: 0.0061
# Epoch 73/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0079 - val_loss: 0.0054
# Epoch 74/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 75/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0104 - val_loss: 0.0084
# Epoch 76/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0075 - val_loss: 0.0083
# Epoch 77/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0075 - val_loss: 0.0061
# Epoch 78/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0079 - val_loss: 0.0113
# Epoch 79/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0076 - val_loss: 0.0047
# Epoch 80/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 81/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0082 - val_loss: 0.0060
# Epoch 82/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 83/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 84/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 85/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0072 - val_loss: 0.0085
# Epoch 86/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 87/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 88/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 89/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0070 - val_loss: 0.0055
# Epoch 90/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 91/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 92/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0077 - val_loss: 0.0053
# Epoch 93/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 94/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 95/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0066 - val_loss: 0.0082
# Epoch 96/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0083 - val_loss: 0.0058
# Epoch 97/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0070 - val_loss: 0.0100
# Epoch 98/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0072 - val_loss: 0.0054
# Epoch 99/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0069 - val_loss: 0.0048
# Epoch 100/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0124
# Epoch 101/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0067 - val_loss: 0.0079
# Epoch 102/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 103/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 104/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 105/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 106/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 107/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0071 - val_loss: 0.0074
# Epoch 108/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 109/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 110/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 111/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 112/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 113/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 114/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 115/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 116/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 117/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 118/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 119/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0043
# Epoch 120/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 121/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 122/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 123/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 124/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0149
# Epoch 125/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 126/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0061 - val_loss: 0.0048
# Epoch 127/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 128/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0044
# Epoch 129/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 130/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 131/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 132/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0073 - val_loss: 0.0058
# Epoch 133/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 134/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0108
# Epoch 135/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 136/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0044
# Epoch 137/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 138/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 139/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0087
# Epoch 140/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 141/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0064
# Epoch 142/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 143/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 144/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 145/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 146/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 147/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 148/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 149/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 150/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0075
# Epoch 151/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 152/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 153/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 154/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 155/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 156/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 157/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 158/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 159/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 160/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0038
# Epoch 161/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 162/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0111
# Epoch 163/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 164/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 165/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 166/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0052 - val_loss: 0.0097
# Epoch 167/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 168/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 169/1500
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 170/1500
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 171/1500
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 172/1500
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 173/1500
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 174/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0057 - val_loss: 0.0068
# Epoch 175/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 176/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 177/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 178/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 179/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 180/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 181/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 182/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 183/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 184/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 185/1500
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 186/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 187/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 188/1500
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 189/1500
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0049 - val_loss: 0.0083
# Epoch 190/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 191/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 192/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 193/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 194/1500
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 195/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 196/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0075
# Epoch 197/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 198/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0062 - val_loss: 0.0050
# Epoch 199/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0050 - val_loss: 0.0085
# Epoch 200/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 201/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 202/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 203/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 204/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 205/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 206/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0046 - val_loss: 0.0083
# Epoch 207/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 208/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 209/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 210/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 211/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 212/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0043 - val_loss: 0.0057
# Epoch 213/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 214/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 215/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 216/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 217/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0069
# Epoch 218/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 219/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0090 - val_loss: 0.0050
# Epoch 220/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 221/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 222/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 223/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 224/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 225/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 226/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 227/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 228/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 229/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 230/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0066
# Epoch 231/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 232/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 233/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 234/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0043 - val_loss: 0.0059
# Epoch 235/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 236/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 237/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 238/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 239/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 240/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0090 - val_loss: 0.0800
# Epoch 241/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0116 - val_loss: 0.0054
# Epoch 242/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 243/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 244/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 245/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 246/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 247/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 248/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 249/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 250/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 251/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 252/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 253/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 254/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 255/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 256/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 257/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 258/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 259/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 260/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 261/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 262/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0062
# Epoch 263/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 264/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 265/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0056 - val_loss: 0.0079
# Epoch 266/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 267/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 268/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 269/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 270/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 271/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 272/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 273/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 274/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 275/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 276/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 277/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 278/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 279/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0064
# Epoch 280/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 281/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0068
# Epoch 282/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 283/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 284/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 285/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 286/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 287/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 288/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 289/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 290/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 291/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 292/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 293/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 294/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 295/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0061
# Epoch 296/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0059
# Epoch 297/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 298/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 299/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 300/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 301/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 302/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 303/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 304/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 305/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 306/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 307/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 308/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 309/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 310/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 311/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 312/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 313/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 314/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 315/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 316/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 317/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 318/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 319/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 320/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 321/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 322/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 323/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 324/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 325/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 326/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 327/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 328/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0045 - val_loss: 0.0058
# Epoch 329/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0041 - val_loss: 0.0064
# Epoch 330/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 331/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0043 - val_loss: 0.0083
# Epoch 332/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 333/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 334/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 335/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 336/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 337/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0080
# Epoch 338/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0068
# Epoch 339/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0107
# Epoch 340/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 341/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 342/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 343/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 344/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0062
# Epoch 345/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 346/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 347/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0051
# Epoch 348/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 349/1500
# 186/186 [==============================] - ETA: 0s - loss: 0.003 - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 350/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 351/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 352/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 353/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 354/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 355/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 356/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 357/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 358/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0053
# Epoch 359/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0037 - val_loss: 0.0061
# Epoch 360/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0033 - val_loss: 0.0070
# Epoch 361/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 362/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 363/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0034 - val_loss: 0.0053
# Epoch 364/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 365/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 366/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 367/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 368/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 369/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 370/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 371/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0083 - val_loss: 0.0055
# Epoch 372/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 373/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 374/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 375/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 376/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 377/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 378/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 379/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0055
# Epoch 380/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 381/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 382/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 383/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 384/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0066
# Epoch 385/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 386/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 387/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 388/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 389/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 390/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 391/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 392/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 393/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 394/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 395/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 396/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0050
# Epoch 397/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 398/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 399/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0050
# Epoch 400/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0072
# Epoch 401/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0050
# Epoch 402/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 403/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 404/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 405/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0053
# Epoch 406/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 407/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0036 - val_loss: 0.0058
# Epoch 408/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 409/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 410/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0069 - val_loss: 0.0045
# Epoch 411/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 412/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 413/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 414/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 415/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 416/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 417/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 418/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0045
# Epoch 419/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0113
# Epoch 420/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 421/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 422/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 423/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0042
# Epoch 424/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0036 - val_loss: 0.0054
# Epoch 425/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 426/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0031 - val_loss: 0.0051
# Epoch 427/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 428/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 429/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 430/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 431/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 432/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 433/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0029 - val_loss: 0.0053
# Epoch 434/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 435/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 436/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 437/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0060 - val_loss: 0.0072
# Epoch 438/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 439/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 440/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 441/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0033 - val_loss: 0.0051
# Epoch 442/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 443/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 444/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 445/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 446/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 447/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 448/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 449/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 450/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 451/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0029 - val_loss: 0.0057
# Epoch 452/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0031 - val_loss: 0.0053
# Epoch 453/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 454/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 455/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 456/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0039 - val_loss: 0.0051
# Epoch 457/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 458/1500
# ...
# Epoch 831/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 832/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 833/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 834/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 835/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 836/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 837/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 838/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 839/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 840/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0047
# Epoch 841/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 842/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 843/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 844/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 845/1500
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 846/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 847/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 848/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 849/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 850/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 851/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 852/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 853/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 854/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 855/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 856/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 857/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 858/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 859/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 860/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 861/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 862/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 863/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0032 - val_loss: 0.0056
# Epoch 864/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 865/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 866/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 867/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 868/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 869/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 870/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 871/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 872/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 873/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 874/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 875/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 876/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 877/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 878/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0062
# Epoch 879/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 880/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 881/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 882/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0059
# Epoch 883/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 884/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0042
# Epoch 885/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 886/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 887/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 888/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 889/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 890/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0044
# Epoch 891/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 892/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 893/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0054
# Epoch 894/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 895/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0046
# Epoch 896/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 897/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0045
# Epoch 898/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0044
# Epoch 899/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 900/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 901/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 902/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 903/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0034 - val_loss: 0.0046
# Epoch 904/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 905/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 906/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 907/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 908/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 909/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 910/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 911/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0050
# Epoch 912/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 913/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 914/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 915/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 916/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 917/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 918/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 919/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 920/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 921/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 922/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 923/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 924/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 925/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 926/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 927/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 928/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 929/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 930/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 931/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 932/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 933/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 934/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 935/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0059
# Epoch 936/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 937/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 938/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 939/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 940/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 941/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 942/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 943/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 944/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 945/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 946/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 947/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 948/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 949/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 950/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 951/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 952/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0042
# Epoch 953/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 954/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 955/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0056
# Epoch 956/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 957/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 958/1500
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 959/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 960/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 961/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 962/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0051
# Epoch 963/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 964/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 965/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 966/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 967/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 968/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 969/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 970/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 971/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 972/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 973/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 974/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 975/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 976/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 977/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 978/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 979/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 980/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0025 - val_loss: 0.0044
# Epoch 981/1500
# 186/186 [==============================] - 3s 17ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 982/1500
# 186/186 [==============================] - 3s 16ms/step - loss: 0.0023 - val_loss: 0.0041

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(history_ct.history['val_loss'], label="Validation")
plt.plot(history_ct.history['loss'], label="Training")
plt.yscale('log')
plt.ylim(.001,10)
plt.yticks(fontsize=13)
plt.xlim(0,1500)
plt.xticks(fontsize=13)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right', ncol=1)
plt.text(1500, 1.5, 'LR=1e-3', fontsize=13)
plt.text(1500, 1, 'Batch: 1500', fontsize=13)
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_lossCurves_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
stmc_test = np.load(ext_datapath + "STMC_10.npz")

# %%
t0 = t.time()
# load data from NpzFile
Xraw_test = stmc_test.f.x
Yraw_test = stmc_test.f.y

# load spcific amount of events from raw
X_test = Xraw_test[:200000,:,:5]
Y_test = Yraw_test[:200000]

# %%
def eval_generator(data, batch_size):
     batches = (len(data) + batch_size - 1)//batch_size
     for i in range(batches):
          X = data[i*batch_size : (i+1)*batch_size]
          yield (X)

# %%
# for pfn approach X normalization
# X = [Energy, Eta, Phi, rPerp, Track Flag, Layer]

## Normalize rPerp to 1/3630
rPerp_mask = X_test[:,:,3] != 0
X_test[:,:,3][rPerp_mask] = X_test[:,:,3][rPerp_mask]/3630.

## Energy Values that are not zero!
E_nonZeroMask = X_test[:,:,0] != 0
X_test[:,:,0][E_nonZeroMask] = np.log(X_test[:,:,0][E_nonZeroMask])
cellE_mean = np.mean(X_test[:,:,0][E_nonZeroMask])
cellE_std = np.std(X_test[:,:,0][E_nonZeroMask])
X_test[:,:,0][E_nonZeroMask] = (X_test[:,:,0][E_nonZeroMask] - cellE_mean)/cellE_std

## Eta and Phi
# do nothing for now as a control and check performance
eta_mask = X_test[:,:,1] != 0
X_test[:,:,1][eta_mask] = X_test[:,:,1][eta_mask]/.7

phi_mask = X_test[:,:,2] != 0
cellPhi_std = np.std(X_test[:,:,2][phi_mask])
X_test[:,:,2][phi_mask] = X_test[:,:,2][phi_mask]/cellPhi_std

# %%
preds = np.exp(model.predict(eval_generator(X_test,500)))
print(preds.shape)
# Out:
# (41196, 2)

# %%
Y_test = Y_test[:,0]

# %%
## PREDICTIONS AND TRUTH ##
bins = np.linspace(0,8,30, endpoint=True)
fig = plt.figure(figsize=(6,6))
plt.hist(Y_test, color='steelblue', bins=bins, density=True, alpha=.5, edgecolor='black', label='target')
plt.hist(preds[:,0], color='coral', bins=bins, density=True, alpha=.5, edgecolor='black', label='network')
plt.title('Regression Output and Target', fontsize=16)
plt.xlabel('Log(E [GeV])', fontsize=14)
plt.xlim(0,8)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend(loc='upper left')
# plt.tight_layout()
# plt.savefig('Regression_Plots/July/XY_STSC_targetPreds_3000batch_LR1e-2_2021-07-016.png', format='png')
plt.show()

# %%
xcenter, medDNN = ru.responsePlot(x=Y_test, y=preds[:,0]/Y_test,
                 atlas_x = 0.46, atlas_y = 0.95, simulation = True,
                 textlist = [{'x': 0.46, 'y': 0.85, 'text': 'Single $\pi^{+}$, Track+Clusters'},
                             {'x': 0.46, 'y': 0.8,  'text': 'keras_pfn_mdn'}])

# %%
import scipy.stats as stats
# from . import plot_util as pu
from util import plot_util as pu

def _iqrOverMed(x):
    # get the IQR via the percentile function
    # 84 is median + 1 sigma, 16 is median - 1 sigma
    q16, q84 = np.percentile(x, [16, 84])
    return (q84 - q16) / (2 * np.median(x))

def resolutionPlot(x, y, figfile='',
                   xlabel='True Energy [GeV]', ylabel='Response IQR / (2 x Median)',
                   atlas_x=-1, atlas_y=-1, simulation=False,
                   xlim=(0.3,1000), ylim=(0,1), 
                   textlist=[]):
    xbin = [10**exp for exp in  np.arange(-1.0, 3.1, 0.1)]
    xcenter = [(xbin[i] + xbin[i+1]) / 2 for i in range(len(xbin)-1)]

    resolution = stats.binned_statistic(x, y, bins=xbin, statistic=_iqrOverMed).statistic
    
    plt.cla(); plt.clf()
    fig = plt.figure()
    fig.patch.set_facecolor('white')
    plt.plot(xcenter, resolution)
    plt.xscale('log')
    plt.xlim(xlim)
    plt.ylim(ylim)
    pu.ampl.set_xlabel(xlabel)
    pu.ampl.set_ylabel(ylabel)

    pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

    if figfile != '':
        plt.savefig(figfile)
    plt.show()

    return xcenter, resolution

# %%
xcenter, iqrMDN3 = resolutionPlot(Y_test, preds[:,0],
                        atlas_x = 0.56, atlas_y = 0.95, simulation = True,
                        textlist = [{'x': 0.56, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
                                    {'x': 0.56, 'y': 0.8,  'text': 'keras_pfn'}])

# %%
resid_DNN = preds[:,0] - Y_test

n_bins = 500
plt.cla(); plt.clf()
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.hist(resid_DNN,bins = n_bins,alpha=0.75)
plt.yscale('log')
plt.xlabel('Learned - True Energy')
plt.ylabel('Clusters')
plt.xlim(-3000,3000)
plt.legend()

atlas_x = 0.55
atlas_y = 0.95
simulation = True
textlist = [{'x': 0.55, 'y': 0.85, 'text': 'Single $\pi^{+}$, All Clusters'},
            {'x': 0.55, 'y': 0.8,  'text': 'keras_pfn'}]
pu.drawLabels(fig, atlas_x, atlas_y, simulation, textlist)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
